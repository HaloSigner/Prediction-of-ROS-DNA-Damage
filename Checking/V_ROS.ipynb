# %% [raw]
# # ROS model formation & Prediction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings

# %%
warnings.filterwarnings(action = 'ignore')

# %% [markdown]
# ## 1. Preparing Cell Painting Data & Cell Health Data

# %% [markdown]
# ### Load IDR-0080 Data & Cell Health Data
# ### Reference : https://pubmed.ncbi.nlm.nih.gov/33534641/

# %%
x_df = pd.read_csv('x_df.csv', index_col = None)
x_df = x_df.iloc[:, 1:]
x_df
# Out:
#      Cells_AreaShape_Compactness  Cells_AreaShape_Eccentricity  \
# 0                      -0.155631                      0.014646
# 1                      -0.247842                     -0.030773
# 2                       0.794740                      0.743296
# 3                       0.480421                      0.821096
# 4                      -0.074895                      0.569377
# ..                           ...                           ...
# 352                     0.247953                      0.331462
# 353                     1.455427                      1.153796
# 354                     0.719510                      0.691270
# 355                    -0.255658                      0.075113
# 356                     0.075324                      0.268191
#
#      Cells_AreaShape_Extent  Cells_AreaShape_Orientation  \
# 0                  0.188053                     1.231056
# 1                  0.433778                     0.062456
# 2                 -0.438752                     0.827288
# 3                 -0.337898                     0.054479
# 4                  0.571678                     0.976504
# ..                      ...                          ...
# 352               -0.228694                     0.648857
# 353               -1.395398                     1.167778
# 354               -0.999921                     0.701489
# 355                0.999995                     0.251456
# 356                0.171536                    -0.295649
#
#      Cells_AreaShape_Zernike_0_0  Cells_AreaShape_Zernike_1_1  \
# 0                       0.031064                    -0.585477
# 1                       0.266860                     0.838679
# 2                      -0.728499                    -0.422394
# 3                      -0.662314                     0.067979
# 4                      -1.111947                     1.348542
# ..                           ...                          ...
# 352                    -0.394799                    -0.477804
# 353                    -1.413069                    -0.684198
# 354                    -0.965601                    -0.937154
# 355                     0.237111                     0.342004
# 356                     0.063491                    -0.284757
#
#      Cells_AreaShape_Zernike_2_0  Cells_AreaShape_Zernike_2_2  \
# 0                       0.467976                     0.254203
# 1                      -0.467417                     0.340793
# 2                      -0.147624                     0.083870
# 3                       0.025010                     0.158138
# 4                       0.584906                    -3.128483
# ..                           ...                          ...
# 352                    -0.203016                     0.387554
# 353                    -0.923160                    -0.145706
# 354                    -0.218680                     0.145943
# 355                     0.084765                     0.957639
# 356                    -0.231007                     0.914041
#
#      Cells_AreaShape_Zernike_3_3  Cells_AreaShape_Zernike_4_0  ...  \
# 0                       0.129446                     0.027104  ...
# 1                      -0.024450                     0.418928  ...
# 2                      -0.160722                    -0.363004  ...
# 3                      -0.342062                    -0.434783  ...
# 4                      -2.324773                     1.945741  ...
# ..                           ...                          ...  ...
# 352                     0.485502                    -0.302333  ...
# 353                    -0.535382                     0.224011  ...
# 354                    -0.149745                    -0.637266  ...
# 355                    -0.562746                    -0.409896  ...
# 356                    -0.863927                     0.023224  ...
#
#      Nuclei_Texture_SumEntropy_DNA_5_0  Nuclei_Texture_SumEntropy_ER_5_0  \
# 0                             0.882859                          0.841687
# 1                             0.513820                          0.344554
# 2                            -0.456539                          0.373750
# 3                             0.115466                          0.186411
# 4                             0.154802                          2.975785
# ..                                 ...                               ...
# 352                           0.305814                          0.952718
# 353                          -0.207834                         -0.280317
# 354                           0.011171                         -0.575574
# 355                           0.766721                          0.518347
# 356                           0.753911                          1.204849
#
#      Nuclei_Texture_SumEntropy_Mito_5_0  Nuclei_Texture_SumEntropy_RNA_5_0  \
# 0                              0.339831                           0.562585
# 1                              0.134318                           0.018933
# 2                             -0.111184                          -0.042733
# 3                              0.249292                           0.688435
# 4                              1.128414                          -0.638839
# ..                                  ...                                ...
# 352                            0.697652                           0.087784
# 353                           -0.422648                          -0.763835
# 354                           -0.272102                          -0.101586
# 355                            1.450779                           1.421830
# 356                            1.660608                           0.868990
#
#      Nuclei_Texture_SumVariance_AGP_5_0  Nuclei_Texture_SumVariance_DNA_10_0  \
# 0                              0.879950                             0.904785
# 1                              0.359496                             0.557998
# 2                             -0.840771                            -0.536215
# 3                             -0.521766                             0.124801
# 4                              0.753884                             0.808944
# ..                                  ...                                  ...
# 352                            0.266722                             0.254346
# 353                           -0.254697                            -0.380000
# 354                           -0.117305                            -0.083261
# 355                            1.483743                             0.639279
# 356                            0.752902                             0.883916
#
#      Nuclei_Texture_SumVariance_DNA_5_0  Nuclei_Texture_Variance_AGP_5_0  \
# 0                              0.923143                         0.944998
# 1                              0.504751                         0.407462
# 2                             -0.497296                        -0.748232
# 3                              0.063444                        -0.560178
# 4                              0.594059                         0.674015
# ..                                  ...                              ...
# 352                            0.367875                         0.191115
# 353                           -0.404530                        -0.266026
# 354                           -0.085342                        -0.213054
# 355                            0.614153                         1.624128
# 356                            0.989018                         0.830979
#
#      Nuclei_Texture_Variance_DNA_10_0  Nuclei_Texture_Variance_DNA_5_0
# 0                            0.984938                         0.961945
# 1                            0.522251                         0.519441
# 2                           -0.515240                        -0.526734
# 3                           -0.062851                         0.026056
# 4                            0.140325                         0.417465
# ..                                ...                              ...
# 352                          0.220894                         0.257950
# 353                         -0.341998                        -0.287431
# 354                         -0.126822                        -0.101668
# 355                          0.523767                         0.603819
# 356                          0.905580                         0.884586
#
# [357 rows x 736 columns]

# %%
# Load cell health data
y_all_df = pd.read_csv('cell_health_modz.tsv', sep = '\t')
y_df = y_all_df['vb_ros_mean']

# %% [markdown]
# ### Load Chemical Annotation Data
# ### Reference : https://gigadb.org/dataset/100351

# %%
# Chemical annotation 
chem_dat = pd.read_csv('chemical_annotations.csv')
chem_dat
# Out:
#                      BROAD_ID       CPD_NAME   CPD_NAME_TYPE CPD_SAMPLE_ID  \
# 0      BRD-A56675431-001-04-0       altizide             INN       SA82748
# 1      BRD-A51829654-001-01-4     BRL-15,572          common       SA82481
# 2      BRD-K04046242-001-03-6        equilin  primary-common       SA82922
# 3      BRD-K16508793-001-01-8       diazepam             INN       SA59660
# 4      BRD-K09397065-001-01-6      SR 57227A   to-be-curated       SA82504
# ...                       ...            ...             ...           ...
# 30611  BRD-K47092271-001-01-7  BRD-K47092271    BROAD_CPD_ID      SA799574
# 30612  BRD-K30358777-001-01-0  BRD-K30358777    BROAD_CPD_ID      SA800605
# 30613  BRD-K32423836-001-01-9  BRD-K32423836    BROAD_CPD_ID      SA799806
# 30614  BRD-K28250273-001-01-2  BRD-K28250273    BROAD_CPD_ID     SA1482018
# 30615  BRD-K72354054-001-01-2  BRD-K72354054    BROAD_CPD_ID     SA1481551
#
#                           DOS_LIBRARY                         SOURCE_NAME  \
# 0                                 NaN             Prestwick Chemical Inc.
# 1                                 NaN           Biomol International Inc.
# 2                                 NaN             Prestwick Chemical Inc.
# 3                                 NaN  MicroSource Discovery Systems Inc.
# 4                                 NaN           Biomol International Inc.
# ...                               ...                                 ...
# 30611              Benzofuran Library  Broad Institute of MIT and Harvard
# 30612              Benzofuran Library  Broad Institute of MIT and Harvard
# 30613              Benzofuran Library  Broad Institute of MIT and Harvard
# 30614  Azetidine Nitrile Full Library  Broad Institute of MIT and Harvard
# 30615  Azetidine Nitrile Full Library  Broad Institute of MIT and Harvard
#
#       CHEMIST_NAME VENDOR_CATALOG_ID  \
# 0              NaN        Prestw-721
# 1              NaN            AC-536
# 2              NaN        Prestw-850
# 3              NaN           1900003
# 4              NaN            AC-561
# ...            ...               ...
# 30611          NaN               NaN
# 30612          NaN               NaN
# 30613          NaN               NaN
# 30614          NaN               NaN
# 30615          NaN               NaN
#
#                                               CPD_SMILES USERCOMMENT
# 0             NS(=O)(=O)c1cc2c(NC(CSCC=C)NS2(=O)=O)cc1Cl         NaN
# 1         OC(CN1CCN(CC1)c1cccc(Cl)c1)C(c1ccccc1)c1ccccc1         NaN
# 2         C[C@]12CC[C@H]3C(=CCc4cc(O)ccc34)[C@@H]1CCC2=O         NaN
# 3                      CN1c2ccc(Cl)cc2C(=NCC1=O)c1ccccc1         NaN
# 4                                NC1CCN(CC1)c1cccc(Cl)n1         NaN
# ...                                                  ...         ...
# 30611  COCC(=O)Nc1ccc2O[C@@H]3[C@@H](C[C@H](CC(=O)NCC...         NaN
# 30612  COc1ccc(CNC(=O)C[C@@H]2C[C@H]3[C@H](Oc4ccc(NC(...         NaN
# 30613  COCCNC(=O)C[C@H]1C[C@@H]2[C@@H](Oc3ccc(NC(=O)C...         NaN
# 30614  OC[C@H]1[C@H]([C@H](C#N)N1C(=O)Nc1cccc(F)c1)c1...         NaN
# 30615  OC[C@H]1[C@@H]([C@H](C#N)N1C(=O)CN1CCOCC1)c1cc...         NaN
#
# [30616 rows x 10 columns]

# %%
# Load validation datasets
x_val_dat = pd.read_csv('x_val_df.csv')
x_val_meta = pd.read_csv('x_val_meta.csv')

# %%
# Check unique compound in validation dataset
compound = x_val_meta['Metadata_broad_sample'].unique()
len(compound)
# Out:
# 30617

# %% [markdown]
# # 2. Regression Model Formation & Accuracy Check

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
import random

# Fix random seeds for reproducibility
def set_seed(seed_value):
    np.random.seed(seed_value)
    random.seed(seed_value)
    tf.random.set_seed(seed_value)

# Set the seed
seed_value = 42
set_seed(seed_value)

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression, Ridge, Lasso, BayesianRidge, ElasticNet
from sklearn.ensemble import AdaBoostRegressor, RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.neural_network import MLPRegressor


# Data Split
X_train, X_test, y_train, y_test = train_test_split(x_df, y_df, test_size = 0.15, random_state = 42)

# Data Flatten
y_train = np.ravel(y_train)
y_test = np.ravel(y_test)

# Various Regression Models
models = {
    'Linear Regression' : LinearRegression(),
    'Ridge Regression' : Ridge(),
    'Lasso Regression' : Lasso(),
    'Decision Tree Regressor' : DecisionTreeRegressor(),
    'Random Forest Regressor' : RandomForestRegressor(),
    'Gradient Boosting Regressor' : GradientBoostingRegressor(),
    'Support Vector Regressor' : SVR(),
    'K-Nearest Neighbors Regressor' : KNeighborsRegressor(),
    'Bayesian Ridge' : BayesianRidge(),
    'Elastic Net' : ElasticNet(),
    'AdaBoost Regressor' : AdaBoostRegressor(),
    'MLP Regressor' : MLPRegressor(),
    'XGBoost Regressor' : XGBRegressor(),
    'LightGBM Regressor' : LGBMRegressor()
}



# Parameter grids for linear models and tree-based models
linear_param_grids = {
    'Ridge Regression' : {'alpha' : [0.1, 1.0, 10.0, 100.0]},
    'Lasso Regression' : {'alpha' : [0.1, 1.0, 10.0, 100.0]},
    'Support Vector Regression' : {'C' : [0.1, 1.0, 10.0], 'epsilon' : [0.01, 0.1, 1]},
    'K-Nearest Neighbors Regressor' : {'n_neighbors' : [3, 5, 7, 9]},
    'Bayesian Ridge' : {},
    'Elastic Net' : {'alpha' : [0.1, 1.0, 10.0], 'l1_ratio' : [0.1, 0.5, 0.9]}
}

tree_param_grids = {
    'Decision Tree Regressor' : {'max_depth' : [None, 10, 20, 30]},
    'Random Forest Regressor' : {'n_estimators' : [100, 200, 300], 'max_depth' : [None, 10, 20]},
    'Gradient Boosting Regressor' : {'n_estimators' : [50, 100, 200], 'learning_rate' : [0.01, 0.1, 0.2]},
    'AdaBoost Regressor' : {'n_estimators' : [50, 100, 200], 'learning_rate' : [0.01, 0.1, 1.0]},
    'MLP Regressor' : {'hidden_layer_sizes' : [(50,), (100,), (50, 50)], 'alpha' : [0.0001, 0.001, 0.01]},
    'XGBoost Regressor' : {'n_estimators' : [50, 100, 200], 'learning_rate' : [0.01, 0.1, 0.2]},
    'LightGBM Regressor' : {'n_estimators' : [50, 100, 200], 'learning_rate' : [0.01, 0.1, 0.2]}
}


# Results Save
best_models = {}
best_params = {}

# Model Class dict
model_classes = {
    'Ridge Regression' : Ridge,
    'Lasso Regression' : Lasso,
    'Support Vector Regression' : SVR,
    'K-Nearest Neighbors Regressor' : KNeighborsRegressor,
    'Decision Tree Regressor' : DecisionTreeRegressor,
    'Random Forest Regressor' : RandomForestRegressor,
    'Gradient Boosting Regressor' : GradientBoostingRegressor,
    'Bayesian Ridge' : BayesianRidge,
    'Elastic Net' : ElasticNet,
    'AdaBoost Regressor' : AdaBoostRegressor,
    'MLP Regressor' : MLPRegressor,
    'XGBoost Regressor' : XGBRegressor,
    'LightGBM Regressor' : LGBMRegressor    
}

# GridSearchCV and training loop for linear models
for model_name, param_grid in linear_param_grids.items():
    model = model_classes[model_name]()
    grid_search = GridSearchCV(estimator = model, param_grid = param_grid, cv = 5, scoring = 'r2')
    grid_search.fit(X_train, y_train)
    best_models[model_name] = grid_search.best_estimator_
    best_params[model_name] = grid_search.best_params_


    y_pred = grid_search.best_estimator_.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)

    print(f'{model_name} Best Parameters: {grid_search.best_params_}')
    print(f'{model_name} (After tuning):')
    print(f'  Mean Squared Error = {mse}')
    print(f'  Root Mean Squared Error = {rmse}')
    print(f'  R² Score = {r2}\n')

# GridSearchCV and training loop for tree-based models
for model_name, param_grid in tree_param_grids.items():
    model = model_classes[model_name]()
    grid_search = GridSearchCV(estimator = model, param_grid = param_grid, cv = 5, scoring = 'r2')
    grid_search.fit(X_train, y_train)
    best_models[model_name] = grid_search.best_estimator_
    best_params[model_name] = grid_search.best_params_

    y_pred = grid_search.best_estimator_.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)

    print(f'{model_name} Best Parameteres: {grid_search.best_params_}')
    print(f'{model_name} (After tuning):')
    print(f'  Mean Squared Error = {mse}')
    print(f'  Root Mean Squared Error = {rmse}')
    print(f'  R² Score = {r2}\n')



# Output the best parameters & r2 score for each model
print('Best parameters:')
for model_name, params in best_params.items():
    print(f'{model_name} : {params}')
# Out:
# Ridge Regression Best Parameters: {'alpha': 100.0}
# Ridge Regression (After tuning):
#   Mean Squared Error = 0.12285469118544619
#   Root Mean Squared Error = 0.3505063354426653
#   R² Score = 0.2658442625120433
#
# Lasso Regression Best Parameters: {'alpha': 0.1}
# Lasso Regression (After tuning):
#   Mean Squared Error = 0.16685983789349418
#   Root Mean Squared Error = 0.4084848074206606
#   R² Score = 0.002878065430105048
#
# Support Vector Regression Best Parameters: {'C': 10.0, 'epsilon': 0.01}
# Support Vector Regression (After tuning):
#   Mean Squared Error = 0.11453926337169291
#   Root Mean Squared Error = 0.33843649828541383
#   R² Score = 0.31553564165456893
#
# K-Nearest Neighbors Regressor Best Parameters: {'n_neighbors': 9}
# K-Nearest Neighbors Regressor (After tuning):
#   Mean Squared Error = 0.13147403976706432
#   Root Mean Squared Error = 0.36259349107101235
#   R² Score = 0.2143367119777968
#
# Bayesian Ridge Best Parameters: {}
# Bayesian Ridge (After tuning):
#   Mean Squared Error = 0.11716411759102335
#   Root Mean Squared Error = 0.34229244454270874
#   R² Score = 0.29985002341242883
#
# Elastic Net Best Parameters: {'alpha': 0.1, 'l1_ratio': 0.1}
# Elastic Net (After tuning):
#   Mean Squared Error = 0.13563125371454152
#   Root Mean Squared Error = 0.36828148706463854
#   R² Score = 0.18949401006665556
#
# Decision Tree Regressor Best Parameteres: {'max_depth': None}
# Decision Tree Regressor (After tuning):
#   Mean Squared Error = 0.3934902110415094
#   Root Mean Squared Error = 0.6272879809477537
#   R² Score = -1.351420961576542
#
# Random Forest Regressor Best Parameteres: {'max_depth': 10, 'n_estimators': 300}
# Random Forest Regressor (After tuning):
#   Mean Squared Error = 0.1859285581246098
#   Root Mean Squared Error = 0.43119433916113714
#   R² Score = -0.11107289752575311
#
# Gradient Boosting Regressor Best Parameteres: {'learning_rate': 0.1, 'n_estimators': 50}
# Gradient Boosting Regressor (After tuning):
#   Mean Squared Error = 0.12700510013837482
#   Root Mean Squared Error = 0.35637774921896404
#   R² Score = 0.2410422259246534
#
# AdaBoost Regressor Best Parameteres: {'learning_rate': 1.0, 'n_estimators': 200}
# AdaBoost Regressor (After tuning):
#   Mean Squared Error = 0.13223616408827826
#   Root Mean Squared Error = 0.3636429073806861
#   R² Score = 0.20978240527856173
#
# MLP Regressor Best Parameteres: {'alpha': 0.0001, 'hidden_layer_sizes': (50,)}
# MLP Regressor (After tuning):
#   Mean Squared Error = 0.3399332134709746
#   Root Mean Squared Error = 0.5830379176957315
#   R² Score = -1.0313747617152336
#
# XGBoost Regressor Best Parameteres: {'learning_rate': 0.01, 'n_estimators': 50}
# XGBoost Regressor (After tuning):
#   Mean Squared Error = 0.1375111954958637
#   Root Mean Squared Error = 0.3708250200510528
#   R² Score = 0.17825984365767678
#
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003200 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 60634
# [LightGBM] [Info] Number of data points in the train set: 242, number of used features: 736
# [LightGBM] [Info] Start training from score 0.069258
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002984 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 60588
# [LightGBM] [Info] Number of data points in the train set: 242, number of used features: 736
# [LightGBM] [Info] Start training from score -0.004403
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003339 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 60590
# [LightGBM] [Info] Number of data points in the train set: 242, number of used features: 736
# [LightGBM] [Info] Start training from score 0.024309
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003190 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 60835
# [LightGBM] [Info] Number of data points in the train set: 243, number of used features: 736
# [LightGBM] [Info] Start training from score 0.062582
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002623 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 60820
# [LightGBM] [Info] Number of data points in the train set: 243, number of used features: 736
# [LightGBM] [Info] Start training from score 0.064088
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003216 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 60634
# [LightGBM] [Info] Number of data points in the train set: 242, number of used features: 736
# [LightGBM] [Info] Start training from score 0.069258
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003203 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 60588
# [LightGBM] [Info] Number of data points in the train set: 242, number of used features: 736
# [LightGBM] [Info] Start training from score -0.004403
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002795 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 60590
# [LightGBM] [Info] Number of data points in the train set: 242, number of used features: 736
# [LightGBM] [Info] Start training from score 0.024309
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003174 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 60835
# [LightGBM] [Info] Number of data points in the train set: 243, number of used features: 736
# [LightGBM] [Info] Start training from score 0.062582
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003896 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 75058
# [LightGBM] [Info] Number of data points in the train set: 303, number of used features: 736
# [LightGBM] [Info] Start training from score 0.043200
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LightGBM Regressor Best Parameteres: {'learning_rate': 0.01, 'n_estimators': 100}
# LightGBM Regressor (After tuning):
#   Mean Squared Error = 0.1442676680251847
#   Root Mean Squared Error = 0.379825839069941
#   R² Score = 0.13788447805528947
#
# Best parameters:
# Ridge Regression : {'alpha': 100.0}
# Lasso Regression : {'alpha': 0.1}
# Support Vector Regression : {'C': 10.0, 'epsilon': 0.01}
# K-Nearest Neighbors Regressor : {'n_neighbors': 9}
# Bayesian Ridge : {}
# Elastic Net : {'alpha': 0.1, 'l1_ratio': 0.1}
# Decision Tree Regressor : {'max_depth': None}
# Random Forest Regressor : {'max_depth': 10, 'n_estimators': 300}
# Gradient Boosting Regressor : {'learning_rate': 0.1, 'n_estimators': 50}
# AdaBoost Regressor : {'learning_rate': 1.0, 'n_estimators': 200}
# MLP Regressor : {'alpha': 0.0001, 'hidden_layer_sizes': (50,)}
# XGBoost Regressor : {'learning_rate': 0.01, 'n_estimators': 50}
# LightGBM Regressor : {'learning_rate': 0.01, 'n_estimators': 100}

# %% [markdown]
# ## Regression Results

# %%
# Initialize lists to store evaluation metrics
model_names = []
mse_scores = []
rmse_scores = []
r2_scores = []


# Evaluate and collect scores for each model
for model_name, model in best_models.items():
    y_pred = model.predict(X_test)


    # Valculate evaluation metrics
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)

    # Store scores and model names
    model_names.append(model_name)
    mse_scores.append(mse)
    rmse_scores.append(rmse)
    r2_scores.append(r2)


# Plotting the scores
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 18))


# Mean Squared Error plot
ax1.barh(model_names, mse_scores, color='blue', alpha=0.7)
ax1.set_title('Mean Squared Error')
ax1.set_xlabel('MSE')
ax1.set_ylabel('Models')
ax1.xaxis.grid(True)

# Root Mean Squared Error plot
ax2.barh(model_names, rmse_scores, color='green', alpha=0.7)
ax2.set_title('Root Mean Squared Error')
ax2.set_xlabel('RMSE')
ax2.set_ylabel('Models')
ax2.xaxis.grid(True)

# R-squared plot
ax3.barh(model_names, r2_scores, color='orange', alpha=0.7)
for model_name, scores in zip(model_names, r2_scores):
    ax3.text(scores, model_name, f'{scores:.2f}')
ax3.set_title('R-squared Score')
ax3.set_xlabel('R² Score')
ax3.set_ylabel('Models')
ax3.axvline(x = 0.24, color = 'red', linestyle = '--', linewidth = 2)
ax3.xaxis.grid(True)

plt.tight_layout()
plt.savefig('accuracy_results.png')
plt.show()

# %% [markdown]
# # 3. Cell Health Labeling for Classification Model

# %%
from sklearn.cluster import KMeans

# Create an array to store SSE values for different cluster numbers
sse = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters = k, random_state=42)
    kmeans.fit(y_df.values.reshape(-1, 1))
    sse.append(kmeans.inertia_)


# Plotting the elbow curve
plt.figure(figsize = (8,6))
plt.plot(range(1, 11), sse, marker = 'o')
plt.title('Elbow Method for Optimal Cluster Number')
plt.xlabel('Number of clusters')
plt.ylabel('Sum of Squared Errors (SSE)')
plt.xticks(np.arange(1, 11, 1))
plt.grid(True)
plt.savefig('Elbow Method.png')
plt.show()

# %%
# y_df Categorized

kmeans = KMeans(n_clusters = 5, random_state = 42)
y_clusters = kmeans.fit_predict(y_df.values.reshape(-1, 1))

y_df_binarized = y_clusters

# %%
from collections import Counter

Counter(y_df_binarized)
# Out:
# Counter({0: 340, 1: 17})

# %%
#np.where(y_df_binarized == 3)
# Out:
# (array([  2,   3,   4,   8,  11,  13,  16,  17,  19,  20,  24,  27,  34,
#          38,  39,  41,  43,  44,  45,  46,  47,  52,  53,  56,  57,  58,
#          59,  65,  68,  70,  71,  73,  74,  76,  77,  79,  80,  81,  82,
#          83,  87,  92,  93,  97, 104, 108, 109, 119, 120, 121, 122, 123,
#         124, 125, 126, 127, 128, 130, 131, 132, 133, 134, 135, 136, 137,
#         138, 139, 141, 142, 143, 144, 145, 146, 148, 149, 150, 152, 153,
#         155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167,
#         168, 169, 170, 171, 172, 173, 174, 175, 176, 179, 181, 184, 187,
#         188, 189, 190, 191, 192, 193, 194, 195, 196, 198, 199, 200, 201,
#         202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214,
#         215, 216, 217, 218, 219, 220, 221, 223, 224, 225, 226, 227, 228,
#         229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 241, 245,
#         247, 249, 250, 252, 253, 258, 261, 268, 272, 274, 275, 276, 277,
#         280, 285, 288, 291, 292, 295, 298, 300, 301, 303, 304, 306, 307,
#         309, 316, 317, 322, 323, 326, 330, 334, 335, 336, 337, 338, 342,
#         343, 344, 351, 352, 353, 354, 355, 356], dtype=int64),)

# %%
#y_df.sort_values(ascending = False).to_excel('y_df.xlsx')

# %%
# Remapping
mapping = {1: 0, 0: 0, 3: 0, 5: 0, 2: 1, 4: 1} # 0 : Low, 1: High
y_df_binarized = np.vectorize(mapping.get)(y_df_binarized)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks

# %%
# Data Split
X_train, X_test, y_train, y_test = train_test_split(x_df, y_df_binarized, test_size = 0.15, stratify=y_df_binarized, random_state = 42)

# Data Flatten
y_train = np.ravel(y_train)
y_test = np.ravel(y_test)

# %%
# Check data stratified
print(Counter(y_train))
print(Counter(y_test))
# Out:
# Counter({0: 289, 1: 14})
# Counter({0: 51, 1: 3})

# %% [markdown]
# # 4. Classification Model Formation & Check Accuracy

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, mean_squared_error, r2_score
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split

# Models Dictionary
models = {
    'RandomForest': RandomForestClassifier(random_state=42),
    'GradientBoosting': GradientBoostingClassifier(random_state=42),
    'SVM': SVC(random_state=42),
    'LogisticRegression': LogisticRegression(random_state=42),
    'SGDClassifier': SGDClassifier(random_state=42),
    'KNeighbors': KNeighborsClassifier(),
    'GaussianNB': GaussianNB(),
    'DecisionTree': DecisionTreeClassifier(random_state=42)
}

# models parameters setting
param_grids = {
    'RandomForest': {
        'n_estimators': [50, 100, 200],
        'max_depth': [None, 10, 20, 30],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4],
        'max_features': ['auto', 'sqrt', 'log2']
    },
    'GradientBoosting': {
        'n_estimators': [50, 100, 200],
        'learning_rate': [0.1, 0.05, 0.01],
        'max_depth': [3, 5, 10],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4],
        'max_features': ['auto', 'sqrt', 'log2']
    },
    'SVM': {
        'C': [0.1, 1, 10],
        'gamma': ['scale', 'auto'],
        'kernel': ['linear', 'rbf', 'poly']
    },
    'LogisticRegression': {
        'C': [0.1, 1, 10],
        'penalty': ['l1','l2']
    },
    'SGDClassifier': {
        'alpha': [0.0001, 0.001, 0.01, 0.1],
        'penalty': ['l1', 'l2']
    },
    'KNeighbors': {
        'n_neighbors': [3, 5, 10],
        'weights': ['uniform', 'distance'],
        'metric': ['euclidean', 'manhattan']
    },
    'GaussianNB': {}, 
    'DecisionTree': {
        'max_depth': [None, 10, 20, 30],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4],
        'max_features': ['auto', 'sqrt', 'log2']
    }
}

# Best Parameter searching
results = {}
result = {}
fold_results = {}

# Setting Stratified K-Fold 
stratified_kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
for model_name, model in models.items():
    print(f"Training {model_name}...")
    grid_search = GridSearchCV(estimator=model, param_grid=param_grids[model_name], cv=stratified_kfold, scoring='accuracy', verbose=1, n_jobs=-1)
    grid_search.fit(X_train, y_train)
    
    # Show Best Parameters & cross val results
    cv_results = grid_search.cv_results_

    fold_r2_scores = []
    for i in range(5):
        fold_score = cv_results[f'split{i}_test_score'][grid_search.best_index_]
        fold_r2_scores.append(fold_score)
        print(f'Fold {i+1} Accuracy: {fold_score}')
    
    print(f"Best Parameters for {model_name}:")
    print(grid_search.best_params_)
    print(f"Best Cross-validation Accuracy for {model_name}: {grid_search.best_score_:.4f}")
    
    # Prediction with optimal model
    best_model = grid_search.best_estimator_
    y_pred = best_model.predict(X_test)
    test_accuracy = accuracy_score(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    
    # Store ersults in the dictionary
    results[model_name] = {
        'accuracy' : test_accuracy,
        'mse' : mse
    }
    
    # Assesment score present
    print(f"\nTest Accuracy for {model_name}: {test_accuracy:.4f}")
    print("Classification Report:")
    print(classification_report(y_test, y_pred))
    print("---------------------------------------")
    # Generate the classification report as a dictionary
    report = classification_report(y_test, y_pred, output_dict=True)

    # Store reulst 
    result[model_name] = {
        'f1_score' : report['weighted avg']['f1-score'],
        'accuracy' : report['accuracy']
    }

    
# Accuracy 
print("\nTest Accuracy Results:")
for model_name, metrics in results.items():
    print(f"{model_name} Accuracy : {metrics['accuracy']: .4f}, MSE : {metrics['mse']: .2f}")
# Out:
# Training RandomForest...
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# Fold 1 Accuracy: 0.9508196721311475
# Fold 2 Accuracy: 0.9508196721311475
# Fold 3 Accuracy: 0.9508196721311475
# Fold 4 Accuracy: 0.9666666666666667
# Fold 5 Accuracy: 0.95
# Best Parameters for RandomForest:
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# Best Cross-validation Accuracy for RandomForest: 0.9538
#
# Test Accuracy for RandomForest: 0.9444
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        51
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.94        54
#    macro avg       0.47      0.50      0.49        54
# weighted avg       0.89      0.94      0.92        54
#
# ---------------------------------------
# Training GradientBoosting...
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# Fold 1 Accuracy: 0.9508196721311475
# Fold 2 Accuracy: 0.9508196721311475
# Fold 3 Accuracy: 0.9508196721311475
# Fold 4 Accuracy: 0.9666666666666667
# Fold 5 Accuracy: 0.9666666666666667
# Best Parameters for GradientBoosting:
# {'learning_rate': 0.1, 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}
# Best Cross-validation Accuracy for GradientBoosting: 0.9572
#
# Test Accuracy for GradientBoosting: 0.9444
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        51
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.94        54
#    macro avg       0.47      0.50      0.49        54
# weighted avg       0.89      0.94      0.92        54
#
# ---------------------------------------
# Training SVM...
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# Fold 1 Accuracy: 0.9508196721311475
# Fold 2 Accuracy: 0.9508196721311475
# Fold 3 Accuracy: 0.9508196721311475
# Fold 4 Accuracy: 0.9666666666666667
# Fold 5 Accuracy: 0.95
# Best Parameters for SVM:
# {'C': 0.1, 'gamma': 'scale', 'kernel': 'rbf'}
# Best Cross-validation Accuracy for SVM: 0.9538
#
# Test Accuracy for SVM: 0.9444
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        51
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.94        54
#    macro avg       0.47      0.50      0.49        54
# weighted avg       0.89      0.94      0.92        54
#
# ---------------------------------------
# Training LogisticRegression...
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fold 1 Accuracy: 0.9508196721311475
# Fold 2 Accuracy: 0.9508196721311475
# Fold 3 Accuracy: 0.9180327868852459
# Fold 4 Accuracy: 0.9666666666666667
# Fold 5 Accuracy: 0.95
# Best Parameters for LogisticRegression:
# {'C': 0.1, 'penalty': 'l2'}
# Best Cross-validation Accuracy for LogisticRegression: 0.9473
#
# Test Accuracy for LogisticRegression: 0.9444
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        51
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.94        54
#    macro avg       0.47      0.50      0.49        54
# weighted avg       0.89      0.94      0.92        54
#
# ---------------------------------------
# Training SGDClassifier...
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# Fold 1 Accuracy: 0.9508196721311475
# Fold 2 Accuracy: 0.9508196721311475
# Fold 3 Accuracy: 0.9180327868852459
# Fold 4 Accuracy: 0.9666666666666667
# Fold 5 Accuracy: 0.95
# Best Parameters for SGDClassifier:
# {'alpha': 0.1, 'penalty': 'l2'}
# Best Cross-validation Accuracy for SGDClassifier: 0.9473
#
# Test Accuracy for SGDClassifier: 0.9259
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96        51
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.93        54
#    macro avg       0.47      0.49      0.48        54
# weighted avg       0.89      0.93      0.91        54
#
# ---------------------------------------
# Training KNeighbors...
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Fold 1 Accuracy: 0.9508196721311475
# Fold 2 Accuracy: 0.9508196721311475
# Fold 3 Accuracy: 0.9508196721311475
# Fold 4 Accuracy: 0.9666666666666667
# Fold 5 Accuracy: 0.95
# Best Parameters for KNeighbors:
# {'metric': 'euclidean', 'n_neighbors': 5, 'weights': 'uniform'}
# Best Cross-validation Accuracy for KNeighbors: 0.9538
#
# Test Accuracy for KNeighbors: 0.9444
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        51
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.94        54
#    macro avg       0.47      0.50      0.49        54
# weighted avg       0.89      0.94      0.92        54
#
# ---------------------------------------
# Training GaussianNB...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fold 1 Accuracy: 0.7540983606557377
# Fold 2 Accuracy: 0.8032786885245902
# Fold 3 Accuracy: 0.7868852459016393
# Fold 4 Accuracy: 0.6333333333333333
# Fold 5 Accuracy: 0.8666666666666667
# Best Parameters for GaussianNB:
# {}
# Best Cross-validation Accuracy for GaussianNB: 0.7689
#
# Test Accuracy for GaussianNB: 0.7222
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.73      0.83        51
#            1       0.12      0.67      0.21         3
#
#     accuracy                           0.72        54
#    macro avg       0.55      0.70      0.52        54
# weighted avg       0.93      0.72      0.80        54
#
# ---------------------------------------
# Training DecisionTree...
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Fold 1 Accuracy: 0.9180327868852459
# Fold 2 Accuracy: 0.9344262295081968
# Fold 3 Accuracy: 0.9508196721311475
# Fold 4 Accuracy: 0.9666666666666667
# Fold 5 Accuracy: 0.9333333333333333
# Best Parameters for DecisionTree:
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# Best Cross-validation Accuracy for DecisionTree: 0.9407
#
# Test Accuracy for DecisionTree: 0.9259
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96        51
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.93        54
#    macro avg       0.47      0.49      0.48        54
# weighted avg       0.89      0.93      0.91        54
#
# ---------------------------------------
#
# Test Accuracy Results:
# RandomForest Accuracy :  0.9444, MSE :  0.06
# GradientBoosting Accuracy :  0.9444, MSE :  0.06
# SVM Accuracy :  0.9444, MSE :  0.06
# LogisticRegression Accuracy :  0.9444, MSE :  0.06
# SGDClassifier Accuracy :  0.9259, MSE :  0.07
# KNeighbors Accuracy :  0.9444, MSE :  0.06
# GaussianNB Accuracy :  0.7222, MSE :  0.28
# DecisionTree Accuracy :  0.9259, MSE :  0.07

# %% [markdown]
# ## Classification Accuracy

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize = (12, 18))

for model, metrics in results.items():
    ax1.barh(model, metrics['mse'], color = 'blue', alpha = 0.7)
    ax1.text(metrics['mse'], model, f"{metrics['mse']:.3f}", va = 'center')
    ax2.barh(model, metrics['accuracy'], color = 'yellow', alpha = 0.7)
    ax2.text(metrics['accuracy'], model, f"{metrics['accuracy']: .3f}", va = 'center')



ax1.set_title('Mean Squared Error')
ax1.set_xlabel('MSE')
ax1.xaxis.grid(True)

ax2.set_title('Accuracy Score')
ax2.set_xlabel('Accuracy')
ax2.axvline(x = 0.24, color = 'red', linestyle = '--', linewidth = 2)
ax2.xaxis.grid(True)

plt.tight_layout()
plt.savefig('X.png')
plt.show()

# %% [markdown]
# # 5. Deep Learning Model Formation & Check Accuracy

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks
from tensorflow.keras.callbacks import ModelCheckpoint
import random
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam

# Fix random seeds for reproducibility
def set_seed(seed_value):
    np.random.seed(seed_value)
    random.seed(seed_value)
    tf.random.set_seed(seed_value)

# Set the seed
seed_value = 42
set_seed(seed_value)


# Define the cross-validation method
stratified_kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Store results
results = []
index = 1
# Cross-validation loop
for train_index, val_index in stratified_kfold.split(x_df, y_df_binarized):
    X_train, X_val = x_df.iloc[train_index], x_df.iloc[val_index]
    y_train, y_val = y_df_binarized[train_index], y_df_binarized[val_index]

    # Define the model
    model = models.Sequential([
        layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
        layers.Dense(64, activation='relu'),
        layers.Dense(32, activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(16, activation='relu'),
        layers.Dense(1, activation='sigmoid')
    ])

    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    print(f'\nValidation Steps:{index}-----------------------------------------------\n')

    early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=20)
    checkpoint_callback = ModelCheckpoint('best_model.keras', monitor='val_loss', save_best_only=True, mode='min')
    
    # Train the model
    history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_val, y_val), callbacks=[early_stopping, checkpoint_callback],
                        verbose=1)

    # Evaluate the model
    val_loss, val_accuracy = model.evaluate(X_val, y_val, verbose=0)
    results.append(val_accuracy)
    index+=1

print(f'Average cross-validation accuracy: {np.mean(results)}')
# Out:
# Validation Steps:1-----------------------------------------------
#
# Epoch 1/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.4228 - loss: 0.7484 - val_accuracy: 0.9306 - val_loss: 0.4388
# Epoch 2/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9396 - loss: 0.3182 - val_accuracy: 0.9444 - val_loss: 0.4463
# Epoch 3/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9562 - loss: 0.2441 - val_accuracy: 0.9444 - val_loss: 0.3476
# Epoch 4/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9643 - loss: 0.1735 - val_accuracy: 0.9444 - val_loss: 0.2488
# Epoch 5/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9547 - loss: 0.1534 - val_accuracy: 0.9444 - val_loss: 0.3026
# Epoch 6/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9643 - loss: 0.1144 - val_accuracy: 0.9444 - val_loss: 0.2830
# Epoch 7/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9562 - loss: 0.1045 - val_accuracy: 0.9444 - val_loss: 0.2910
# Epoch 8/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9578 - loss: 0.1038 - val_accuracy: 0.9444 - val_loss: 0.2555
# Epoch 9/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9775 - loss: 0.0746 - val_accuracy: 0.9444 - val_loss: 0.2959
# Epoch 10/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9710 - loss: 0.0743 - val_accuracy: 0.9444 - val_loss: 0.3230
#
# Validation Steps:2-----------------------------------------------
#
# Epoch 1/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9520 - loss: 0.2872 - val_accuracy: 0.9444 - val_loss: 0.2593
# Epoch 2/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9535 - loss: 0.1857 - val_accuracy: 0.9444 - val_loss: 0.2187
# Epoch 3/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9428 - loss: 0.1604 - val_accuracy: 0.9444 - val_loss: 0.1927
# Epoch 4/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9520 - loss: 0.1116 - val_accuracy: 0.9583 - val_loss: 0.1864
# Epoch 5/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9567 - loss: 0.1004 - val_accuracy: 0.9306 - val_loss: 0.1879
# Epoch 6/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9552 - loss: 0.0904 - val_accuracy: 0.9444 - val_loss: 0.1812
# Epoch 7/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9572 - loss: 0.0803 - val_accuracy: 0.9583 - val_loss: 0.2152
# Epoch 8/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9549 - loss: 0.0779 - val_accuracy: 0.9583 - val_loss: 0.1807
# Epoch 9/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9672 - loss: 0.0670 - val_accuracy: 0.9583 - val_loss: 0.2062
# Epoch 10/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9870 - loss: 0.0663 - val_accuracy: 0.9583 - val_loss: 0.1919
#
# Validation Steps:3-----------------------------------------------
#
# Epoch 1/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.5842 - loss: 0.7159 - val_accuracy: 0.9577 - val_loss: 0.2960
# Epoch 2/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9200 - loss: 0.3741 - val_accuracy: 0.9577 - val_loss: 0.2599
# Epoch 3/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9285 - loss: 0.3182 - val_accuracy: 0.9577 - val_loss: 0.2329
# Epoch 4/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9292 - loss: 0.3378 - val_accuracy: 0.9577 - val_loss: 0.1737
# Epoch 5/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9308 - loss: 0.2647 - val_accuracy: 0.9577 - val_loss: 0.1639
# Epoch 6/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9292 - loss: 0.2373 - val_accuracy: 0.9577 - val_loss: 0.1283
# Epoch 7/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9427 - loss: 0.1963 - val_accuracy: 0.9577 - val_loss: 0.1392
# Epoch 8/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9292 - loss: 0.1737 - val_accuracy: 0.9718 - val_loss: 0.1316
# Epoch 9/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9342 - loss: 0.1584 - val_accuracy: 0.9718 - val_loss: 0.1464
# Epoch 10/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9372 - loss: 0.1379 - val_accuracy: 0.9718 - val_loss: 0.1473
#
# Validation Steps:4-----------------------------------------------
#
# Epoch 1/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9388 - loss: 0.3809 - val_accuracy: 0.9577 - val_loss: 0.1581
# Epoch 2/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9480 - loss: 0.2006 - val_accuracy: 0.9577 - val_loss: 0.1238
# Epoch 3/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9480 - loss: 0.1947 - val_accuracy: 0.9577 - val_loss: 0.1113
# Epoch 4/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9518 - loss: 0.1501 - val_accuracy: 0.9577 - val_loss: 0.1094
# Epoch 5/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9518 - loss: 0.1379 - val_accuracy: 0.9577 - val_loss: 0.1028
# Epoch 6/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9518 - loss: 0.1046 - val_accuracy: 0.9577 - val_loss: 0.0999
# Epoch 7/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9610 - loss: 0.1000 - val_accuracy: 0.9577 - val_loss: 0.0919
# Epoch 8/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9617 - loss: 0.0929 - val_accuracy: 0.9718 - val_loss: 0.0936
# Epoch 9/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9422 - loss: 0.1149 - val_accuracy: 0.9577 - val_loss: 0.0958
# Epoch 10/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9518 - loss: 0.0741 - val_accuracy: 0.9437 - val_loss: 0.1011
#
# Validation Steps:5-----------------------------------------------
#
# Epoch 1/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.5295 - loss: 0.7395 - val_accuracy: 0.9577 - val_loss: 0.3287
# Epoch 2/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9560 - loss: 0.3469 - val_accuracy: 0.9577 - val_loss: 0.1977
# Epoch 3/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9560 - loss: 0.2365 - val_accuracy: 0.9577 - val_loss: 0.2106
# Epoch 4/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9560 - loss: 0.1843 - val_accuracy: 0.9577 - val_loss: 0.2423
# Epoch 5/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9663 - loss: 0.1304 - val_accuracy: 0.9577 - val_loss: 0.2637
# Epoch 6/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9560 - loss: 0.1187 - val_accuracy: 0.9577 - val_loss: 0.2859
# Epoch 7/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9663 - loss: 0.0958 - val_accuracy: 0.9577 - val_loss: 0.3087
# Epoch 8/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9652 - loss: 0.0794 - val_accuracy: 0.9577 - val_loss: 0.3344
# Epoch 9/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9652 - loss: 0.0663 - val_accuracy: 0.9437 - val_loss: 0.3726
# Epoch 10/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9686 - loss: 0.0585 - val_accuracy: 0.8873 - val_loss: 0.4411
# Average cross-validation accuracy: 0.9411189198493958

# %%
# Confusion Matirx & ROC Curve
from sklearn.metrics import confusion_matrix, roc_curve, auc
import seaborn as sns

# Load Best Model
best_model = keras.models.load_model('best_model.keras')

# Confusion Matrix
y_pred = best_model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)

conf_matrix = confusion_matrix(y_test, y_pred_classes)


# Annotation 
group_names = ['TN', 'FP (label 0 error)', 'FN (label 1 error)', 'TP']
group_counts = [value for value in conf_matrix.flatten()]
labels = [f'{v1}\n{v2}' for v1, v2 in zip(group_names, group_counts)]
labels = np.asarray(labels).reshape(2,2)

plt.figure(figsize = (6,6))
sns.heatmap(conf_matrix, annot = labels, fmt = '', cbar = False, color = 'Blue')
plt.title('Confusion Matrix', fontsize = 16)
plt.xlabel('Predicted Label', fontsize = 14)
plt.ylabel('True Label', fontsize = 14)
plt.tight_layout()
plt.savefig('Confusion Matrix.png', dpi = 300)
plt.show()


fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)


plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.legend(loc='lower right', fontsize=12)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16)
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.tight_layout()
plt.savefig('ROC_Curve.png', dpi=300)
plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000021C6BA0F920> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/stepWARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000021C6BA0F920> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step

# %%
print(classification_report(y_test, y_pred_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        51
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.94        54
#    macro avg       0.47      0.50      0.49        54
# weighted avg       0.89      0.94      0.92        54

# %% [markdown]
# # Oversampling(o) & Sample Weights(o)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from imblearn.over_sampling import SMOTE
from sklearn.utils.class_weight import compute_sample_weight

# Fix random seeds for reproducibility
def set_seed(seed_value):
    np.random.seed(seed_value)
    random.seed(seed_value)
    tf.random.set_seed(seed_value)

# Set the seed
seed_value = 42
set_seed(seed_value)



# Define the cross-validation method
stratified_kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Store results
results = []
index = 1
class_weights_dict = {0 : 3, 1 : 10}
# Cross-validation loop
for train_index, val_index in stratified_kfold.split(x_df, y_df_binarized):
    X_train, X_val = x_df.iloc[train_index], x_df.iloc[val_index]
    y_train, y_val = y_df_binarized[train_index], y_df_binarized[val_index]

    smote = SMOTE(random_state=42)

    X_train_s, y_train_s = smote.fit_resample(X_train, y_train)

    # Data flatten
    y_train_s = np.ravel(y_train_s)
    y_test = np.ravel(y_test)

    # Compute sample weights
    sample_weights = compute_sample_weight(class_weight=class_weights_dict, y=y_train_s)
    
    # Define the model
    model = models.Sequential([
        layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
        layers.Dense(64, activation='relu'),
        layers.Dense(32, activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(16, activation='relu'),
        layers.Dense(1, activation='sigmoid')
    ])

    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    print(f'\nValidation Steps:{index}-----------------------------------------------\n')

    early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=20)
    checkpoint_callback = ModelCheckpoint('best_model.keras', monitor='val_loss', save_best_only=True, mode='min')
    
    # Train the model
    history = model.fit(X_train_s, y_train_s, epochs=10, batch_size=32, validation_data=(X_val, y_val), callbacks=[early_stopping, checkpoint_callback],
                        verbose=1,
                       sample_weight=sample_weights)

    # Evaluate the model
    val_loss, val_accuracy = model.evaluate(X_val, y_val, verbose=0)
    results.append(val_accuracy)
    index+=1

print(f'Average cross-validation accuracy: {np.mean(results)}')
# Out:
# Validation Steps:1-----------------------------------------------
#
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.5598 - loss: 3.3882 - val_accuracy: 0.5833 - val_loss: 0.8703
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7903 - loss: 1.8610 - val_accuracy: 0.7222 - val_loss: 0.7848
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8994 - loss: 1.1714 - val_accuracy: 0.6944 - val_loss: 0.5732
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8960 - loss: 0.8266 - val_accuracy: 0.8056 - val_loss: 0.4255
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9397 - loss: 0.5194 - val_accuracy: 0.9028 - val_loss: 0.4405
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9703 - loss: 0.3142 - val_accuracy: 0.9167 - val_loss: 0.4290
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9807 - loss: 0.2458 - val_accuracy: 0.9444 - val_loss: 0.6351
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9684 - loss: 0.2750 - val_accuracy: 0.9444 - val_loss: 0.9039
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9710 - loss: 0.4575 - val_accuracy: 0.9306 - val_loss: 0.5489
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9783 - loss: 0.3409 - val_accuracy: 0.9444 - val_loss: 0.6341
#
# Validation Steps:2-----------------------------------------------
#
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6415 - loss: 4.4692 - val_accuracy: 0.5972 - val_loss: 0.6968
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8540 - loss: 1.9176 - val_accuracy: 0.7222 - val_loss: 0.7132
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8913 - loss: 1.3447 - val_accuracy: 0.7639 - val_loss: 0.5821
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9163 - loss: 0.8138 - val_accuracy: 0.8333 - val_loss: 0.4727
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9419 - loss: 0.5777 - val_accuracy: 0.8611 - val_loss: 0.4567
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9657 - loss: 0.4099 - val_accuracy: 0.8611 - val_loss: 0.4212
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9744 - loss: 0.2617 - val_accuracy: 0.8750 - val_loss: 0.4310
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9640 - loss: 0.4081 - val_accuracy: 0.9028 - val_loss: 0.3890
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9818 - loss: 0.2569 - val_accuracy: 0.8889 - val_loss: 0.4048
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9893 - loss: 0.1653 - val_accuracy: 0.9028 - val_loss: 0.3896
#
# Validation Steps:3-----------------------------------------------
#
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6453 - loss: 3.1696 - val_accuracy: 0.7324 - val_loss: 0.7666
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8463 - loss: 1.5829 - val_accuracy: 0.8592 - val_loss: 0.3435
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8975 - loss: 1.1926 - val_accuracy: 0.8592 - val_loss: 0.2729
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9382 - loss: 0.6940 - val_accuracy: 0.8732 - val_loss: 0.2706
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9625 - loss: 0.5812 - val_accuracy: 0.9155 - val_loss: 0.1835
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9601 - loss: 0.4654 - val_accuracy: 0.9577 - val_loss: 0.1430
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9727 - loss: 0.3815 - val_accuracy: 0.9155 - val_loss: 0.2281
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9697 - loss: 0.6028 - val_accuracy: 0.9437 - val_loss: 0.2151
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9655 - loss: 0.4777 - val_accuracy: 0.8732 - val_loss: 0.3851
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9718 - loss: 0.4490 - val_accuracy: 0.9014 - val_loss: 0.5944
#
# Validation Steps:4-----------------------------------------------
#
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5582 - loss: 4.2815 - val_accuracy: 0.6479 - val_loss: 0.6684
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7925 - loss: 2.1453 - val_accuracy: 0.8592 - val_loss: 0.4536
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8630 - loss: 1.4274 - val_accuracy: 0.9014 - val_loss: 0.3530
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8888 - loss: 1.1084 - val_accuracy: 0.8873 - val_loss: 0.3124
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9273 - loss: 0.8482 - val_accuracy: 0.9437 - val_loss: 0.2065
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9560 - loss: 0.5031 - val_accuracy: 0.9296 - val_loss: 0.3471
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9537 - loss: 0.5538 - val_accuracy: 0.9296 - val_loss: 0.2416
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9678 - loss: 0.4000 - val_accuracy: 0.9577 - val_loss: 0.1406
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9682 - loss: 0.4898 - val_accuracy: 0.9296 - val_loss: 0.2812
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9870 - loss: 0.2328 - val_accuracy: 0.9437 - val_loss: 0.2071
#
# Validation Steps:5-----------------------------------------------
#
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5932 - loss: 3.5031 - val_accuracy: 0.6056 - val_loss: 0.8801
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8504 - loss: 1.7057 - val_accuracy: 0.7746 - val_loss: 0.5885
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9181 - loss: 0.8743 - val_accuracy: 0.8592 - val_loss: 0.5125
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9683 - loss: 0.4412 - val_accuracy: 0.8451 - val_loss: 0.5809
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9867 - loss: 0.2253 - val_accuracy: 0.8873 - val_loss: 0.6266
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9924 - loss: 0.1680 - val_accuracy: 0.8451 - val_loss: 1.1486
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9647 - loss: 0.2959 - val_accuracy: 0.8451 - val_loss: 0.8490
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9983 - loss: 0.0739 - val_accuracy: 0.8873 - val_loss: 0.6802
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9938 - loss: 0.0964 - val_accuracy: 0.8873 - val_loss: 0.6632
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9939 - loss: 0.1309 - val_accuracy: 0.8732 - val_loss: 0.7549
# Average cross-validation accuracy: 0.9131064176559448

# %%
# Confusion Matirx & ROC Curve
from sklearn.metrics import confusion_matrix, roc_curve, auc
import seaborn as sns

# Load Best Model
best_model = keras.models.load_model('best_model.keras')

# Confusion Matrix
y_pred = best_model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)

conf_matrix = confusion_matrix(y_test, y_pred_classes)


# Annotation 
group_names = ['TN', 'FP (label 0 error)', 'FN (label 1 error)', 'TP']
group_counts = [value for value in conf_matrix.flatten()]
labels = [f'{v1}\n{v2}' for v1, v2 in zip(group_names, group_counts)]
labels = np.asarray(labels).reshape(2,2)

plt.figure(figsize = (6,6))
sns.heatmap(conf_matrix, annot = labels, fmt = '', cbar = False, color = 'Blue')
plt.title('Confusion Matrix', fontsize = 16)
plt.xlabel('Predicted Label', fontsize = 14)
plt.ylabel('True Label', fontsize = 14)
plt.tight_layout()
plt.savefig('Confusion Matrix.png', dpi = 300)
plt.show()


fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)


plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.legend(loc='lower right', fontsize=12)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16)
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.tight_layout()
plt.savefig('ROC_Curve.png', dpi=300)
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step

# %%
print(classification_report(y_test, y_pred_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.90      0.94        51
#            1       0.29      0.67      0.40         3
#
#     accuracy                           0.89        54
#    macro avg       0.63      0.78      0.67        54
# weighted avg       0.94      0.89      0.91        54

# %% [markdown]
# ## Oversampling(x) & Sample Weights(o)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from imblearn.over_sampling import SMOTE
from sklearn.utils.class_weight import compute_sample_weight

# Fix random seeds for reproducibility
def set_seed(seed_value):
    np.random.seed(seed_value)
    random.seed(seed_value)
    tf.random.set_seed(seed_value)

# Set the seed
seed_value = 42
set_seed(seed_value)



# Define the cross-validation method
stratified_kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Store results
results = []
index = 1
class_weights_dict = {0 : 3, 1 : 10}
# Cross-validation loop
for train_index, val_index in stratified_kfold.split(x_df, y_df_binarized):
    X_train, X_val = x_df.iloc[train_index], x_df.iloc[val_index]
    y_train, y_val = y_df_binarized[train_index], y_df_binarized[val_index]



    # Compute sample weights
    sample_weights = compute_sample_weight(class_weight=class_weights_dict, y=y_train)
    
    # Define the model
    model = models.Sequential([
        layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
        layers.Dense(64, activation='relu'),
        layers.Dense(32, activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(16, activation='relu'),
        layers.Dense(1, activation='sigmoid')
    ])

    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    print(f'\nValidation Steps:{index}-----------------------------------------------\n')

    early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=20)
    checkpoint_callback = ModelCheckpoint('best_model.keras', monitor='val_loss', save_best_only=True, mode='min')
    
    # Train the model
    history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_val, y_val), callbacks=[early_stopping, checkpoint_callback],
                        verbose=1,
                       sample_weight=sample_weights)

    # Evaluate the model
    val_loss, val_accuracy = model.evaluate(X_val, y_val, verbose=0)
    results.append(val_accuracy)
    index+=1

print(f'Average cross-validation accuracy: {np.mean(results)}')
# Out:
# Validation Steps:1-----------------------------------------------
#
# Epoch 1/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.3849 - loss: 2.5208 - val_accuracy: 0.9306 - val_loss: 0.4408
# Epoch 2/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9244 - loss: 1.5443 - val_accuracy: 0.9306 - val_loss: 0.3631
# Epoch 3/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9322 - loss: 1.2873 - val_accuracy: 0.9444 - val_loss: 0.2868
# Epoch 4/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9494 - loss: 1.0339 - val_accuracy: 0.9444 - val_loss: 0.2359
# Epoch 5/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9527 - loss: 0.8587 - val_accuracy: 0.9444 - val_loss: 0.2404
# Epoch 6/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9561 - loss: 0.6161 - val_accuracy: 0.9444 - val_loss: 0.1947
# Epoch 7/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9606 - loss: 0.5582 - val_accuracy: 0.9444 - val_loss: 0.3642
# Epoch 8/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9641 - loss: 0.5481 - val_accuracy: 0.9444 - val_loss: 0.2518
# Epoch 9/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9618 - loss: 0.4482 - val_accuracy: 0.9306 - val_loss: 0.3185
# Epoch 10/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9748 - loss: 0.3830 - val_accuracy: 0.9444 - val_loss: 0.3722
#
# Validation Steps:2-----------------------------------------------
#
# Epoch 1/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9456 - loss: 1.5845 - val_accuracy: 0.9167 - val_loss: 0.2298
# Epoch 2/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9552 - loss: 1.0754 - val_accuracy: 0.9028 - val_loss: 0.2092
# Epoch 3/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9199 - loss: 0.9752 - val_accuracy: 0.9444 - val_loss: 0.2051
# Epoch 4/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9518 - loss: 0.7300 - val_accuracy: 0.9167 - val_loss: 0.2145
# Epoch 5/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9682 - loss: 0.6236 - val_accuracy: 0.9167 - val_loss: 0.1854
# Epoch 6/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9799 - loss: 0.4980 - val_accuracy: 0.9028 - val_loss: 0.1688
# Epoch 7/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9699 - loss: 0.4110 - val_accuracy: 0.9444 - val_loss: 0.2004
# Epoch 8/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9768 - loss: 0.6964 - val_accuracy: 0.9028 - val_loss: 0.1668
# Epoch 9/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9745 - loss: 0.3818 - val_accuracy: 0.9306 - val_loss: 0.1592
# Epoch 10/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9863 - loss: 0.3331 - val_accuracy: 0.9306 - val_loss: 0.1662
#
# Validation Steps:3-----------------------------------------------
#
# Epoch 1/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5550 - loss: 2.5300 - val_accuracy: 0.9577 - val_loss: 0.3096
# Epoch 2/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9209 - loss: 1.8891 - val_accuracy: 0.9296 - val_loss: 0.3351
# Epoch 3/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9292 - loss: 1.9640 - val_accuracy: 0.9155 - val_loss: 0.2799
# Epoch 4/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9070 - loss: 1.8716 - val_accuracy: 0.9577 - val_loss: 0.2105
# Epoch 5/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9214 - loss: 1.4050 - val_accuracy: 0.8732 - val_loss: 0.2544
# Epoch 6/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9322 - loss: 0.9992 - val_accuracy: 0.9718 - val_loss: 0.1317
# Epoch 7/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9484 - loss: 1.2263 - val_accuracy: 0.8732 - val_loss: 0.2291
# Epoch 8/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9306 - loss: 0.8102 - val_accuracy: 0.9577 - val_loss: 0.1251
# Epoch 9/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9710 - loss: 0.8539 - val_accuracy: 0.9155 - val_loss: 0.1868
# Epoch 10/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9608 - loss: 0.6601 - val_accuracy: 0.9437 - val_loss: 0.1372
#
# Validation Steps:4-----------------------------------------------
#
# Epoch 1/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9327 - loss: 1.9993 - val_accuracy: 0.9577 - val_loss: 0.2086
# Epoch 2/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9465 - loss: 1.3247 - val_accuracy: 0.9577 - val_loss: 0.1806
# Epoch 3/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9533 - loss: 1.1024 - val_accuracy: 0.9577 - val_loss: 0.1442
# Epoch 4/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9632 - loss: 0.8166 - val_accuracy: 0.9577 - val_loss: 0.1184
# Epoch 5/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9647 - loss: 0.7312 - val_accuracy: 0.9577 - val_loss: 0.1224
# Epoch 6/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9254 - loss: 0.7993 - val_accuracy: 0.9437 - val_loss: 0.1088
# Epoch 7/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9578 - loss: 0.6117 - val_accuracy: 0.9437 - val_loss: 0.1184
# Epoch 8/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9469 - loss: 0.6369 - val_accuracy: 0.9577 - val_loss: 0.0918
# Epoch 9/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9375 - loss: 0.6376 - val_accuracy: 0.9577 - val_loss: 0.0952
# Epoch 10/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9463 - loss: 0.5644 - val_accuracy: 0.9296 - val_loss: 0.1125
#
# Validation Steps:5-----------------------------------------------
#
# Epoch 1/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.5329 - loss: 2.5047 - val_accuracy: 0.9577 - val_loss: 0.4093
# Epoch 2/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9531 - loss: 1.5237 - val_accuracy: 0.9577 - val_loss: 0.2923
# Epoch 3/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9465 - loss: 1.3215 - val_accuracy: 0.9577 - val_loss: 0.2323
# Epoch 4/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9551 - loss: 1.0696 - val_accuracy: 0.9577 - val_loss: 0.2702
# Epoch 5/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9723 - loss: 0.6457 - val_accuracy: 0.9296 - val_loss: 0.2972
# Epoch 6/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9573 - loss: 0.6369 - val_accuracy: 0.9437 - val_loss: 0.3009
# Epoch 7/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9648 - loss: 0.5507 - val_accuracy: 0.8451 - val_loss: 0.5470
# Epoch 8/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9112 - loss: 0.6862 - val_accuracy: 0.9577 - val_loss: 0.3358
# Epoch 9/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9721 - loss: 0.5294 - val_accuracy: 0.9014 - val_loss: 0.4235
# Epoch 10/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9468 - loss: 0.4570 - val_accuracy: 0.9014 - val_loss: 0.4156
# Average cross-validation accuracy: 0.9299295783042908

# %%
# Confusion Matirx & ROC Curve
from sklearn.metrics import confusion_matrix, roc_curve, auc
import seaborn as sns

# Load Best Model
best_model = keras.models.load_model('best_model.keras')

# Confusion Matrix
y_pred = best_model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)

conf_matrix = confusion_matrix(y_test, y_pred_classes)


# Annotation 
group_names = ['TN', 'FP (label 0 error)', 'FN (label 1 error)', 'TP']
group_counts = [value for value in conf_matrix.flatten()]
labels = [f'{v1}\n{v2}' for v1, v2 in zip(group_names, group_counts)]
labels = np.asarray(labels).reshape(2,2)

plt.figure(figsize = (6,6))
sns.heatmap(conf_matrix, annot = labels, fmt = '', cbar = False, color = 'Blue')
plt.title('Confusion Matrix', fontsize = 16)
plt.xlabel('Predicted Label', fontsize = 14)
plt.ylabel('True Label', fontsize = 14)
plt.tight_layout()
plt.savefig('Confusion Matrix.png', dpi = 300)
plt.show()


fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)


plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.legend(loc='lower right', fontsize=12)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16)
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.tight_layout()
plt.savefig('ROC_Curve.png', dpi=300)
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %%
print(classification_report(y_test, y_pred_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        51
#            1       1.00      0.33      0.50         3
#
#     accuracy                           0.96        54
#    macro avg       0.98      0.67      0.74        54
# weighted avg       0.96      0.96      0.95        54

# %% [markdown]
# ## Oversampling(o) & Sample Weights(x)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from imblearn.over_sampling import SMOTE
from sklearn.utils.class_weight import compute_sample_weight

# Fix random seeds for reproducibility
def set_seed(seed_value):
    np.random.seed(seed_value)
    random.seed(seed_value)
    tf.random.set_seed(seed_value)

# Set the seed
seed_value = 42
set_seed(seed_value)



# Define the cross-validation method
stratified_kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Store results
results = []
index = 1
class_weights_dict = {0 : 3, 1 : 10}
# Cross-validation loop
for train_index, val_index in stratified_kfold.split(x_df, y_df_binarized):
    X_train, X_val = x_df.iloc[train_index], x_df.iloc[val_index]
    y_train, y_val = y_df_binarized[train_index], y_df_binarized[val_index]

    smote = SMOTE(random_state=42)

    X_train_s, y_train_s = smote.fit_resample(X_train, y_train)

    # Data flatten
    y_train_s = np.ravel(y_train_s)
    y_test = np.ravel(y_test)

    
    # Define the model
    model = models.Sequential([
        layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
        layers.Dense(64, activation='relu'),
        layers.Dense(32, activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(16, activation='relu'),
        layers.Dense(1, activation='sigmoid')
    ])

    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    print(f'\nValidation Steps:{index}-----------------------------------------------\n')

    early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=20)
    checkpoint_callback = ModelCheckpoint('best_model.keras', monitor='val_loss', save_best_only=True, mode='min')
    
    # Train the model
    history = model.fit(X_train_s, y_train_s, epochs=10, batch_size=32, validation_data=(X_val, y_val), callbacks=[early_stopping, checkpoint_callback],
                        verbose=1)

    # Evaluate the model
    val_loss, val_accuracy = model.evaluate(X_val, y_val, verbose=0)
    results.append(val_accuracy)
    index+=1

print(f'Average cross-validation accuracy: {np.mean(results)}')
# Out:
# Validation Steps:1-----------------------------------------------
#
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6087 - loss: 0.6444 - val_accuracy: 0.7222 - val_loss: 0.6512
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8478 - loss: 0.4329 - val_accuracy: 0.7222 - val_loss: 0.5079
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9071 - loss: 0.2917 - val_accuracy: 0.7361 - val_loss: 0.3932
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9369 - loss: 0.1870 - val_accuracy: 0.8889 - val_loss: 0.2537
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9475 - loss: 0.1438 - val_accuracy: 0.9167 - val_loss: 0.2793
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9689 - loss: 0.0787 - val_accuracy: 0.9444 - val_loss: 0.3139
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9810 - loss: 0.0574 - val_accuracy: 0.9583 - val_loss: 0.3725
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9870 - loss: 0.0371 - val_accuracy: 0.9583 - val_loss: 0.4533
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9958 - loss: 0.0188 - val_accuracy: 0.9583 - val_loss: 0.6428
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9936 - loss: 0.0124 - val_accuracy: 0.9583 - val_loss: 0.6276
#
# Validation Steps:2-----------------------------------------------
#
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6684 - loss: 0.6098 - val_accuracy: 0.8056 - val_loss: 0.3635
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8979 - loss: 0.3028 - val_accuracy: 0.8333 - val_loss: 0.3373
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9290 - loss: 0.2113 - val_accuracy: 0.8611 - val_loss: 0.3246
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9495 - loss: 0.1267 - val_accuracy: 0.8750 - val_loss: 0.2763
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9637 - loss: 0.1051 - val_accuracy: 0.9167 - val_loss: 0.2573
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9684 - loss: 0.0840 - val_accuracy: 0.9306 - val_loss: 0.2586
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9700 - loss: 0.0679 - val_accuracy: 0.9306 - val_loss: 0.3017
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9747 - loss: 0.0625 - val_accuracy: 0.9306 - val_loss: 0.3169
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9743 - loss: 0.0594 - val_accuracy: 0.8611 - val_loss: 0.4563
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9479 - loss: 0.1010 - val_accuracy: 0.9167 - val_loss: 0.3179
#
# Validation Steps:3-----------------------------------------------
#
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7252 - loss: 0.6181 - val_accuracy: 0.8310 - val_loss: 0.4326
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8852 - loss: 0.3113 - val_accuracy: 0.8732 - val_loss: 0.3069
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9597 - loss: 0.1963 - val_accuracy: 0.9014 - val_loss: 0.1716
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9691 - loss: 0.1219 - val_accuracy: 0.9577 - val_loss: 0.1494
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9861 - loss: 0.0903 - val_accuracy: 0.9577 - val_loss: 0.1314
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9699 - loss: 0.0934 - val_accuracy: 0.9577 - val_loss: 0.1644
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9624 - loss: 0.0870 - val_accuracy: 0.9577 - val_loss: 0.2011
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9733 - loss: 0.0859 - val_accuracy: 0.9577 - val_loss: 0.2386
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9852 - loss: 0.0570 - val_accuracy: 0.9577 - val_loss: 0.2829
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9825 - loss: 0.0555 - val_accuracy: 0.9577 - val_loss: 0.3234
#
# Validation Steps:4-----------------------------------------------
#
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6407 - loss: 0.6508 - val_accuracy: 0.8592 - val_loss: 0.3244
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8829 - loss: 0.3393 - val_accuracy: 0.9014 - val_loss: 0.2219
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9293 - loss: 0.2150 - val_accuracy: 0.9577 - val_loss: 0.1616
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9614 - loss: 0.1371 - val_accuracy: 0.9437 - val_loss: 0.1567
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9777 - loss: 0.1037 - val_accuracy: 0.9437 - val_loss: 0.1804
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9822 - loss: 0.0625 - val_accuracy: 0.9437 - val_loss: 0.2207
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9819 - loss: 0.0621 - val_accuracy: 0.9296 - val_loss: 0.1994
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9808 - loss: 0.0581 - val_accuracy: 0.9437 - val_loss: 0.1518
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9825 - loss: 0.0585 - val_accuracy: 0.9437 - val_loss: 0.1604
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9928 - loss: 0.0417 - val_accuracy: 0.9718 - val_loss: 0.0673
#
# Validation Steps:5-----------------------------------------------
#
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6384 - loss: 0.6451 - val_accuracy: 0.7183 - val_loss: 0.5347
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8853 - loss: 0.3661 - val_accuracy: 0.8592 - val_loss: 0.3066
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9392 - loss: 0.1850 - val_accuracy: 0.8451 - val_loss: 0.4678
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9532 - loss: 0.1341 - val_accuracy: 0.9437 - val_loss: 0.2946
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9761 - loss: 0.0921 - val_accuracy: 0.9014 - val_loss: 0.3758
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9769 - loss: 0.0777 - val_accuracy: 0.9296 - val_loss: 0.3990
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9891 - loss: 0.0444 - val_accuracy: 0.9014 - val_loss: 0.4378
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9989 - loss: 0.0210 - val_accuracy: 0.9014 - val_loss: 0.6144
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9993 - loss: 0.0153 - val_accuracy: 0.8873 - val_loss: 0.7060
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9993 - loss: 0.0105 - val_accuracy: 0.8873 - val_loss: 0.7452
# Average cross-validation accuracy: 0.9383802771568298

# %%
# Confusion Matirx & ROC Curve
from sklearn.metrics import confusion_matrix, roc_curve, auc
import seaborn as sns

# Load Best Model
best_model = keras.models.load_model('best_model.keras')

# Confusion Matrix
y_pred = best_model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)

conf_matrix = confusion_matrix(y_test, y_pred_classes)


# Annotation 
group_names = ['TN', 'FP (label 0 error)', 'FN (label 1 error)', 'TP']
group_counts = [value for value in conf_matrix.flatten()]
labels = [f'{v1}\n{v2}' for v1, v2 in zip(group_names, group_counts)]
labels = np.asarray(labels).reshape(2,2)

plt.figure(figsize = (6,6))
sns.heatmap(conf_matrix, annot = labels, fmt = '', cbar = False, color = 'Blue')
plt.title('Confusion Matrix', fontsize = 16)
plt.xlabel('Predicted Label', fontsize = 14)
plt.ylabel('True Label', fontsize = 14)
plt.tight_layout()
plt.savefig('Confusion Matrix.png', dpi = 300)
plt.show()


fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)


plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.legend(loc='lower right', fontsize=12)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16)
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.tight_layout()
plt.savefig('ROC_Curve.png', dpi=300)
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %%
print(classification_report(y_test, y_pred_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        51
#            1       1.00      0.33      0.50         3
#
#     accuracy                           0.96        54
#    macro avg       0.98      0.67      0.74        54
# weighted avg       0.96      0.96      0.95        54
