# %% [markdown]
# ## Module Importing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings

# %%
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## Real Cell Painting Data Load

# %%
x_df = pd.read_csv('x_df.csv')
x_df = x_df.iloc[:, 1:]
x_df
# Out:
#      Cells_AreaShape_Compactness  Cells_AreaShape_Eccentricity  \
# 0                      -0.155631                      0.014646
# 1                      -0.247842                     -0.030773
# 2                       0.794740                      0.743296
# 3                       0.480421                      0.821096
# 4                      -0.074895                      0.569377
# ..                           ...                           ...
# 352                     0.247953                      0.331462
# 353                     1.455427                      1.153796
# 354                     0.719510                      0.691270
# 355                    -0.255658                      0.075113
# 356                     0.075324                      0.268191
#
#      Cells_AreaShape_Extent  Cells_AreaShape_Orientation  \
# 0                  0.188053                     1.231056
# 1                  0.433778                     0.062456
# 2                 -0.438752                     0.827288
# 3                 -0.337898                     0.054479
# 4                  0.571678                     0.976504
# ..                      ...                          ...
# 352               -0.228694                     0.648857
# 353               -1.395398                     1.167778
# 354               -0.999921                     0.701489
# 355                0.999995                     0.251456
# 356                0.171536                    -0.295649
#
#      Cells_AreaShape_Zernike_0_0  Cells_AreaShape_Zernike_1_1  \
# 0                       0.031064                    -0.585477
# 1                       0.266860                     0.838679
# 2                      -0.728499                    -0.422394
# 3                      -0.662314                     0.067979
# 4                      -1.111947                     1.348542
# ..                           ...                          ...
# 352                    -0.394799                    -0.477804
# 353                    -1.413069                    -0.684198
# 354                    -0.965601                    -0.937154
# 355                     0.237111                     0.342004
# 356                     0.063491                    -0.284757
#
#      Cells_AreaShape_Zernike_2_0  Cells_AreaShape_Zernike_2_2  \
# 0                       0.467976                     0.254203
# 1                      -0.467417                     0.340793
# 2                      -0.147624                     0.083870
# 3                       0.025010                     0.158138
# 4                       0.584906                    -3.128483
# ..                           ...                          ...
# 352                    -0.203016                     0.387554
# 353                    -0.923160                    -0.145706
# 354                    -0.218680                     0.145943
# 355                     0.084765                     0.957639
# 356                    -0.231007                     0.914041
#
#      Cells_AreaShape_Zernike_3_3  Cells_AreaShape_Zernike_4_0  ...  \
# 0                       0.129446                     0.027104  ...
# 1                      -0.024450                     0.418928  ...
# 2                      -0.160722                    -0.363004  ...
# 3                      -0.342062                    -0.434783  ...
# 4                      -2.324773                     1.945741  ...
# ..                           ...                          ...  ...
# 352                     0.485502                    -0.302333  ...
# 353                    -0.535382                     0.224011  ...
# 354                    -0.149745                    -0.637266  ...
# 355                    -0.562746                    -0.409896  ...
# 356                    -0.863927                     0.023224  ...
#
#      Nuclei_Texture_SumEntropy_DNA_5_0  Nuclei_Texture_SumEntropy_ER_5_0  \
# 0                             0.882859                          0.841687
# 1                             0.513820                          0.344554
# 2                            -0.456539                          0.373750
# 3                             0.115466                          0.186411
# 4                             0.154802                          2.975785
# ..                                 ...                               ...
# 352                           0.305814                          0.952718
# 353                          -0.207834                         -0.280317
# 354                           0.011171                         -0.575574
# 355                           0.766721                          0.518347
# 356                           0.753911                          1.204849
#
#      Nuclei_Texture_SumEntropy_Mito_5_0  Nuclei_Texture_SumEntropy_RNA_5_0  \
# 0                              0.339831                           0.562585
# 1                              0.134318                           0.018933
# 2                             -0.111184                          -0.042733
# 3                              0.249292                           0.688435
# 4                              1.128414                          -0.638839
# ..                                  ...                                ...
# 352                            0.697652                           0.087784
# 353                           -0.422648                          -0.763835
# 354                           -0.272102                          -0.101586
# 355                            1.450779                           1.421830
# 356                            1.660608                           0.868990
#
#      Nuclei_Texture_SumVariance_AGP_5_0  Nuclei_Texture_SumVariance_DNA_10_0  \
# 0                              0.879950                             0.904785
# 1                              0.359496                             0.557998
# 2                             -0.840771                            -0.536215
# 3                             -0.521766                             0.124801
# 4                              0.753884                             0.808944
# ..                                  ...                                  ...
# 352                            0.266722                             0.254346
# 353                           -0.254697                            -0.380000
# 354                           -0.117305                            -0.083261
# 355                            1.483743                             0.639279
# 356                            0.752902                             0.883916
#
#      Nuclei_Texture_SumVariance_DNA_5_0  Nuclei_Texture_Variance_AGP_5_0  \
# 0                              0.923143                         0.944998
# 1                              0.504751                         0.407462
# 2                             -0.497296                        -0.748232
# 3                              0.063444                        -0.560178
# 4                              0.594059                         0.674015
# ..                                  ...                              ...
# 352                            0.367875                         0.191115
# 353                           -0.404530                        -0.266026
# 354                           -0.085342                        -0.213054
# 355                            0.614153                         1.624128
# 356                            0.989018                         0.830979
#
#      Nuclei_Texture_Variance_DNA_10_0  Nuclei_Texture_Variance_DNA_5_0
# 0                            0.984938                         0.961945
# 1                            0.522251                         0.519441
# 2                           -0.515240                        -0.526734
# 3                           -0.062851                         0.026056
# 4                            0.140325                         0.417465
# ..                                ...                              ...
# 352                          0.220894                         0.257950
# 353                         -0.341998                        -0.287431
# 354                         -0.126822                        -0.101668
# 355                          0.523767                         0.603819
# 356                          0.905580                         0.884586
#
# [357 rows x 736 columns]

# %% [markdown]
# ## Label Data Loading

# %%
y_df_binarized = np.load('y_df_binarized.npy')

# %% [markdown]
# ## Data Merging for synthesize data

# %%
full_df = x_df
full_df['dna'] = y_df_binarized
full_df
# Out:
#      Cells_AreaShape_Compactness  Cells_AreaShape_Eccentricity  \
# 0                      -0.155631                      0.014646
# 1                      -0.247842                     -0.030773
# 2                       0.794740                      0.743296
# 3                       0.480421                      0.821096
# 4                      -0.074895                      0.569377
# ..                           ...                           ...
# 352                     0.247953                      0.331462
# 353                     1.455427                      1.153796
# 354                     0.719510                      0.691270
# 355                    -0.255658                      0.075113
# 356                     0.075324                      0.268191
#
#      Cells_AreaShape_Extent  Cells_AreaShape_Orientation  \
# 0                  0.188053                     1.231056
# 1                  0.433778                     0.062456
# 2                 -0.438752                     0.827288
# 3                 -0.337898                     0.054479
# 4                  0.571678                     0.976504
# ..                      ...                          ...
# 352               -0.228694                     0.648857
# 353               -1.395398                     1.167778
# 354               -0.999921                     0.701489
# 355                0.999995                     0.251456
# 356                0.171536                    -0.295649
#
#      Cells_AreaShape_Zernike_0_0  Cells_AreaShape_Zernike_1_1  \
# 0                       0.031064                    -0.585477
# 1                       0.266860                     0.838679
# 2                      -0.728499                    -0.422394
# 3                      -0.662314                     0.067979
# 4                      -1.111947                     1.348542
# ..                           ...                          ...
# 352                    -0.394799                    -0.477804
# 353                    -1.413069                    -0.684198
# 354                    -0.965601                    -0.937154
# 355                     0.237111                     0.342004
# 356                     0.063491                    -0.284757
#
#      Cells_AreaShape_Zernike_2_0  Cells_AreaShape_Zernike_2_2  \
# 0                       0.467976                     0.254203
# 1                      -0.467417                     0.340793
# 2                      -0.147624                     0.083870
# 3                       0.025010                     0.158138
# 4                       0.584906                    -3.128483
# ..                           ...                          ...
# 352                    -0.203016                     0.387554
# 353                    -0.923160                    -0.145706
# 354                    -0.218680                     0.145943
# 355                     0.084765                     0.957639
# 356                    -0.231007                     0.914041
#
#      Cells_AreaShape_Zernike_3_3  Cells_AreaShape_Zernike_4_0  ...  \
# 0                       0.129446                     0.027104  ...
# 1                      -0.024450                     0.418928  ...
# 2                      -0.160722                    -0.363004  ...
# 3                      -0.342062                    -0.434783  ...
# 4                      -2.324773                     1.945741  ...
# ..                           ...                          ...  ...
# 352                     0.485502                    -0.302333  ...
# 353                    -0.535382                     0.224011  ...
# 354                    -0.149745                    -0.637266  ...
# 355                    -0.562746                    -0.409896  ...
# 356                    -0.863927                     0.023224  ...
#
#      Nuclei_Texture_SumEntropy_ER_5_0  Nuclei_Texture_SumEntropy_Mito_5_0  \
# 0                            0.841687                            0.339831
# 1                            0.344554                            0.134318
# 2                            0.373750                           -0.111184
# 3                            0.186411                            0.249292
# 4                            2.975785                            1.128414
# ..                                ...                                 ...
# 352                          0.952718                            0.697652
# 353                         -0.280317                           -0.422648
# 354                         -0.575574                           -0.272102
# 355                          0.518347                            1.450779
# 356                          1.204849                            1.660608
#
#      Nuclei_Texture_SumEntropy_RNA_5_0  Nuclei_Texture_SumVariance_AGP_5_0  \
# 0                             0.562585                            0.879950
# 1                             0.018933                            0.359496
# 2                            -0.042733                           -0.840771
# 3                             0.688435                           -0.521766
# 4                            -0.638839                            0.753884
# ..                                 ...                                 ...
# 352                           0.087784                            0.266722
# 353                          -0.763835                           -0.254697
# 354                          -0.101586                           -0.117305
# 355                           1.421830                            1.483743
# 356                           0.868990                            0.752902
#
#      Nuclei_Texture_SumVariance_DNA_10_0  Nuclei_Texture_SumVariance_DNA_5_0  \
# 0                               0.904785                            0.923143
# 1                               0.557998                            0.504751
# 2                              -0.536215                           -0.497296
# 3                               0.124801                            0.063444
# 4                               0.808944                            0.594059
# ..                                   ...                                 ...
# 352                             0.254346                            0.367875
# 353                            -0.380000                           -0.404530
# 354                            -0.083261                           -0.085342
# 355                             0.639279                            0.614153
# 356                             0.883916                            0.989018
#
#      Nuclei_Texture_Variance_AGP_5_0  Nuclei_Texture_Variance_DNA_10_0  \
# 0                           0.944998                          0.984938
# 1                           0.407462                          0.522251
# 2                          -0.748232                         -0.515240
# 3                          -0.560178                         -0.062851
# 4                           0.674015                          0.140325
# ..                               ...                               ...
# 352                         0.191115                          0.220894
# 353                        -0.266026                         -0.341998
# 354                        -0.213054                         -0.126822
# 355                         1.624128                          0.523767
# 356                         0.830979                          0.905580
#
#      Nuclei_Texture_Variance_DNA_5_0  dna
# 0                           0.961945    0
# 1                           0.519441    0
# 2                          -0.526734    0
# 3                           0.026056    0
# 4                           0.417465    1
# ..                               ...  ...
# 352                         0.257950    0
# 353                        -0.287431    0
# 354                        -0.101668    0
# 355                         0.603819    0
# 356                         0.884586    0
#
# [357 rows x 737 columns]

# %% [markdown]
# ## Synthesize Data

# %%
# Metadata Detecting
from sdv.metadata import SingleTableMetadata

metadata = SingleTableMetadata()

metadata.detect_from_dataframe(full_df)

metadata.visualize(
    show_table_details='summarized'
)

# %%
# Synthesizer model setting
from sdv.single_table import GaussianCopulaSynthesizer


synthesizer = GaussianCopulaSynthesizer(
    metadata,
    enforce_min_max_values=True,
    enforce_rounding=True,
    default_distribution='norm'
)

synthesizer.fit(full_df)

# %%
# Sampling
from sdv.sampling import Condition

c_1 = Condition(
    num_rows = 0,
    column_values={'dna' : 0}
)

c_2 = Condition(
    num_rows = 263,
    column_values={'dna' : 1}
)


synthetic_data = synthesizer.sample_from_conditions(
    conditions=[c_1, c_2]
)
# Out:
# Sampling conditions: 100%|███████████████████████████████████████████████████████████| 263/263 [00:03<00:00, 82.44it/s]

# %%
#synthetic_data.to_csv('good_synthetic_data_1.csv')

# %%
synthetic_data = pd.read_csv('good_synthetic_data.csv')
synthetic_data = synthetic_data.iloc[:, 1:]

# %%
# Synthetic data value check
synthetic_data['dna'].value_counts()
# Out:
# dna
# 1    263
# Name: count, dtype: int64

# %%
# Syntehtic Data Structure Chekcing
from sdv.evaluation.single_table import run_diagnostic

diagnostic_report = run_diagnostic(
    real_data=full_df,
    synthetic_data=synthetic_data,
    metadata=metadata
)
# Out:
# Generating report ...
#
# (1/2) Evaluating Data Validity: |█████████████████████████████████████████████████| 737/737 [00:00<00:00, 3818.59it/s]|
# Data Validity Score: 99.85%
#
# (2/2) Evaluating Data Structure: |█████████████████████████████████████████████████████| 1/1 [00:00<00:00, 200.08it/s]|
# Data Structure Score: 99.73%
#
# Overall Score (Average): 99.79%

# %%
# Synthetic Data Quality Check (Feature Similarity & Row character Similarity)
from sdv.evaluation.single_table import evaluate_quality

quality_report = evaluate_quality(
    real_data=full_df,
    synthetic_data=synthetic_data,
    metadata=metadata
)
# Out:
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |█████████████████████████████████████████████████| 737/737 [00:00<00:00, 1354.77it/s]|
# Column Shapes Score: 80.3%
#
# (2/2) Evaluating Column Pair Trends: |███████████████████████████████████████| 271216/271216 [12:39<00:00, 356.98it/s]|
# Column Pair Trends Score: 97.79%
#
# Overall Score (Average): 89.04%

# %% [markdown]
# ## Sampling Real Data (Class 0 : 30 , Class 1 : 30) for evade data leakage

# %%
df_0 = full_df[full_df['dna'] == 0].sample(n=30, random_state=42)
df_1 = full_df[full_df['dna'] == 1].sample(n=30, random_state=42)


result_df = pd.concat([df_0, df_1])


full_df = full_df.drop(result_df.index)

# %%
# Combined Real data + Synthetic Data
combined_data = pd.concat([full_df, synthetic_data], axis=0)
combined_data
# Out:
#      Cells_AreaShape_Compactness  Cells_AreaShape_Eccentricity  \
# 0                      -0.155631                      0.014646
# 1                      -0.247842                     -0.030773
# 2                       0.794740                      0.743296
# 5                       1.146910                      2.257785
# 7                      -0.805225                      0.292041
# ..                           ...                           ...
# 258                     1.237935                      1.378160
# 259                    -0.705308                     -0.394858
# 260                     1.464615                      1.456702
# 261                     0.783803                     -0.110764
# 262                    -0.820494                     -1.312349
#
#      Cells_AreaShape_Extent  Cells_AreaShape_Orientation  \
# 0                  0.188053                     1.231056
# 1                  0.433778                     0.062456
# 2                 -0.438752                     0.827288
# 5                 -0.362795                     0.406701
# 7                  1.687698                     0.438888
# ..                      ...                          ...
# 258               -0.859401                    -0.500647
# 259                0.973909                     0.385349
# 260               -0.769688                    -0.291934
# 261               -1.487241                    -0.691953
# 262                0.007079                     0.620415
#
#      Cells_AreaShape_Zernike_0_0  Cells_AreaShape_Zernike_1_1  \
# 0                       0.031064                    -0.585477
# 1                       0.266860                     0.838679
# 2                      -0.728499                    -0.422394
# 5                      -2.313052                    -0.560777
# 7                       0.244263                    -0.729474
# ..                           ...                          ...
# 258                    -1.149965                    -0.701248
# 259                     0.730172                     2.018899
# 260                    -1.692511                     0.053091
# 261                    -1.300390                    -0.590516
# 262                     0.305033                    -0.512775
#
#      Cells_AreaShape_Zernike_2_0  Cells_AreaShape_Zernike_2_2  \
# 0                       0.467976                     0.254203
# 1                      -0.467417                     0.340793
# 2                      -0.147624                     0.083870
# 5                       0.082828                    -2.233997
# 7                       1.402427                     0.735846
# ..                           ...                          ...
# 258                     0.193761                     2.140719
# 259                     1.309000                     2.218595
# 260                    -0.892704                    -0.343368
# 261                    -1.134040                    -4.296381
# 262                     0.605070                    -2.537959
#
#      Cells_AreaShape_Zernike_3_3  Cells_AreaShape_Zernike_4_0  ...  \
# 0                       0.129446                     0.027104  ...
# 1                      -0.024450                     0.418928  ...
# 2                      -0.160722                    -0.363004  ...
# 5                      -2.419444                     1.099632  ...
# 7                      -2.207689                     0.902846  ...
# ..                           ...                          ...  ...
# 258                     0.922102                    -0.788603  ...
# 259                     0.803994                    -2.256084  ...
# 260                    -0.133810                    -0.134211  ...
# 261                    -1.728027                     1.845682  ...
# 262                    -0.871511                     0.620362  ...
#
#      Nuclei_Texture_SumEntropy_ER_5_0  Nuclei_Texture_SumEntropy_Mito_5_0  \
# 0                            0.841687                            0.339831
# 1                            0.344554                            0.134318
# 2                            0.373750                           -0.111184
# 5                            1.827650                            1.149970
# 7                            1.293113                           -0.151828
# ..                                ...                                 ...
# 258                         -0.890445                           -0.722950
# 259                         -1.304669                           -1.979371
# 260                          0.617394                            0.518451
# 261                          1.800674                            2.975673
# 262                         -1.440468                           -0.210626
#
#      Nuclei_Texture_SumEntropy_RNA_5_0  Nuclei_Texture_SumVariance_AGP_5_0  \
# 0                             0.562585                            0.879950
# 1                             0.018933                            0.359496
# 2                            -0.042733                           -0.840771
# 5                            -0.279042                            0.277700
# 7                            -1.025271                            0.115434
# ..                                 ...                                 ...
# 258                           0.154741                           -0.611375
# 259                          -2.501406                           -1.521123
# 260                           0.513476                            0.278972
# 261                           0.921354                            1.840861
# 262                           0.220640                            0.648304
#
#      Nuclei_Texture_SumVariance_DNA_10_0  Nuclei_Texture_SumVariance_DNA_5_0  \
# 0                               0.904785                            0.923143
# 1                               0.557998                            0.504751
# 2                              -0.536215                           -0.497296
# 5                               1.248636                            1.029453
# 7                              -0.039783                           -0.141104
# ..                                   ...                                 ...
# 258                            -0.944802                           -0.826020
# 259                            -1.686227                           -1.625810
# 260                             0.584292                            0.394386
# 261                             1.140327                            1.018381
# 262                            -0.460694                           -0.617643
#
#      Nuclei_Texture_Variance_AGP_5_0  Nuclei_Texture_Variance_DNA_10_0  \
# 0                           0.944998                          0.984938
# 1                           0.407462                          0.522251
# 2                          -0.748232                         -0.515240
# 5                           0.194965                          0.597816
# 7                           0.169655                         -0.573505
# ..                               ...                               ...
# 258                        -0.534173                         -0.860087
# 259                        -1.439182                         -1.980382
# 260                         0.484014                          0.400672
# 261                         1.929473                          1.028208
# 262                         0.588869                         -0.722585
#
#      Nuclei_Texture_Variance_DNA_5_0  dna
# 0                           0.961945    0
# 1                           0.519441    0
# 2                          -0.526734    0
# 5                           0.891515    0
# 7                          -0.389571    0
# ..                               ...  ...
# 258                        -0.784858    1
# 259                        -1.692631    1
# 260                         0.367056    1
# 261                         1.010313    1
# 262                        -0.599990    1
#
# [560 rows x 737 columns]

# %%
from sklearn.model_selection import train_test_split
from collections import Counter

x_df_s = combined_data.drop(columns='dna')
y_df_s = combined_data['dna']
#x_df = x_df.drop(columns='dna')


#from sklearn.preprocessing import MinMaxScaler

#scaler = MinMaxScaler()

# Data Split
X_train, X_test, y_train, y_test = train_test_split(x_df_s, y_df_s, stratify=y_df_s, test_size = 0.15, random_state = 42)

# Data Scailing
#X_train = scaler.fit_transform(X_train)
#X_test = scaler.transform(X_test)
#X_val = scaler.transform(x_df)

#X_train = pd.DataFrame(X_train, columns=x_df_s.columns)
#X_test = pd.DataFrame(X_test, columns=x_df_s.columns)
#X_val = pd.DataFrame(X_val, columns=x_df.columns)

#X_train = pd.concat([X_train, synthetic_data.drop(columns=['dna'])], ignore_index=True)
#y_train = pd.concat([pd.Series(y_train), synthetic_data['dna']], ignore_index=True)

# Data Flatten
y_train = np.ravel(y_train)
y_test = np.ravel(y_test)


# Check data stratified
print(Counter(y_train))
print(Counter(y_test))
# Out:
# Counter({1: 241, 0: 235})
# Counter({1: 43, 0: 41})

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.svm import SVC
from sklearn.metrics import f1_score, classification_report, roc_auc_score


# Class weight Setting
class_weight = {0: 2, 1: 1.7}

# SVM Model Setting
svm_model = SVC(random_state=42, class_weight=class_weight)

# SVM Parmeter Setting
svm_param_grid = {
    'C': [0.1, 1, 10],
    'gamma': ['scale', 'auto'],
    'kernel': ['linear', 'rbf', 'poly']
}

# Best Parameter Searching
results = {}
result = {}

# Stratified K-Fold Setting
stratified_kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

print("Training SVM...")
grid_search = GridSearchCV(estimator=svm_model, param_grid=svm_param_grid, cv=stratified_kfold, scoring='roc_auc_ovr', verbose=1, n_jobs=-1)
grid_search.fit(X_train, y_train)

# Best Parameters & 5 Fold-cross validation
cv_results = grid_search.cv_results_

fold_f1_scores = []
for i in range(5):
    print(f'Fold {i+1} Training ................')

print(f"Best Parameters for SVM:")
print(grid_search.best_params_)

# Prediction with best estimator
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# AUC ROC Calculation
auc_roc = roc_auc_score(y_test, best_model.decision_function(X_test))

# Assessment score present
print(f"\nTest Result for SVM:")
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Generate classification report as a dictionary
report = classification_report(y_test, y_pred, output_dict=True)

# Store result 
result['SVM'] = {
    'f1_score': report['weighted avg']['f1-score'],
    'accuracy': report['accuracy']
}

# Final Results Reporting
print("\nSVM Test Results:")
print(f"SVM F1-score : {result['SVM']['f1_score']: .4f}, AUC ROC : {auc_roc:.4f}, Accuracy : {result['SVM']['accuracy']:.4f}")
# Out:
# Training SVM...
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# Fold 1 Training ................
# Fold 2 Training ................
# Fold 3 Training ................
# Fold 4 Training ................
# Fold 5 Training ................
# Best Parameters for SVM:
# {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
#
# Test Result for SVM:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.68      0.78      0.73        41
#            1       0.76      0.65      0.70        43
#
#     accuracy                           0.71        84
#    macro avg       0.72      0.72      0.71        84
# weighted avg       0.72      0.71      0.71        84
#
#
# SVM Test Results:
# SVM F1-score :  0.7133, AUC ROC : 0.7930, Accuracy : 0.7143

# %%
# Validation with sampled Real Data
y_pred = grid_search.best_estimator_.predict(result_df.drop(columns = 'dna'))

print(classification_report(result_df['dna'], y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.77      0.82        30
#            1       0.79      0.90      0.84        30
#
#     accuracy                           0.83        60
#    macro avg       0.84      0.83      0.83        60
# weighted avg       0.84      0.83      0.83        60
