# %%
import os
import pandas as pd
import numpy as np

# %%
# Set Basic Dir
base_dir = r"C:\Users\USER\Desktop\profiles.dir"

# Start & End Plate number
start_plate = 24277
end_plate = 26795


combined_df = pd.DataFrame()

# Get .csv file
for plate_number in range(start_plate, end_plate):
    plate_dir = os.path.join(base_dir, f'Plate_{plate_number}', 'profiles')
    if os.path.exists(plate_dir):
        for file_name in os.listdir(plate_dir):
            if file_name.endswith('.csv'):
                file_path = os.path.join(plate_dir, file_name)
                df = pd.read_csv(file_path)
                combined_df = pd.concat([combined_df, df], ignore_index = True)

# Save combined datasets
combined_df.to_csv('cpg0012_combined_df.csv', index = False)

# %%
import matplotlib.pyplot as plt
import warnings
import pycytominer
from pycytominer.consensus import modz

# %%
warnings.filterwarnings(action = 'ignore')

# %%
# Check Number of compounds
compound = combined_df['Metadata_broad_sample'].unique()
len(compound)
# Out:
# 30617

# %%
# Load Chemical annotation data
chem_dat = pd.read_csv('chemical_annotations.csv')

# %%
# Validation Dataset
x_val_dat = pd.read_csv('cpg0012_combined_df.csv')

# Follow idr0080 normalization ways
x_val_norm_dat = pycytominer.normalize(
    profiles = x_val_dat,
    features = 'infer',
    method = 'mad_robustize',
    samples = 'Metadata_solvent == "DMSO"'
)

# Follow idr0080 feature selection ways
x_val_norm_dat = pycytominer.feature_select(
    profiles = x_val_norm_dat,
    features = 'infer',
    operation = [
        'drop_na_columns',
        'blocklist',
        'variance_threshold',
        'drop_outliers'
    ]
)

# Remove DMSO 
#x_val_norm_dat = x_val_norm_dat.query('Metadata_broad_sample != "DMSO"')

# Devied metadata & cell painting data
x_val_meta = x_val_norm_dat.iloc[:, :17]
x_val_df = x_val_norm_dat.iloc[:, 17:]

# %%
display(x_val_meta)
display(x_val_df)
# Out:
#         Metadata_Plate Metadata_Well  Metadata_Assay_Plate_Barcode  \
# 0                24277           a01                         24277
# 1                24277           a02                         24277
# 2                24277           a03                         24277
# 3                24277           a04                         24277
# 4                24277           a05                         24277
# ...                ...           ...                           ...
# 152981           26794           p20                         26794
# 152982           26794           p21                         26794
# 152983           26794           p22                         26794
# 152984           26794           p23                         26794
# 152985           26794           p24                         26794
#
#        Metadata_Plate_Map_Name Metadata_well_position  \
# 0                 H-BIOA-004-3                    a01
# 1                 H-BIOA-004-3                    a02
# 2                 H-BIOA-004-3                    a03
# 3                 H-BIOA-004-3                    a04
# 4                 H-BIOA-004-3                    a05
# ...                        ...                    ...
# 152981            H-CBLD-004-4                    p20
# 152982            H-CBLD-004-4                    p21
# 152983            H-CBLD-004-4                    p22
# 152984            H-CBLD-004-4                    p23
# 152985            H-CBLD-004-4                    p24
#
#        Metadata_ASSAY_WELL_ROLE   Metadata_broad_sample  \
# 0                       treated  BRD-K18250272-003-03-7
# 1                       treated  BRD-K18316707-001-01-9
# 2                       treated  BRD-K18438502-001-02-6
# 3                       treated  BRD-K18550767-001-02-8
# 4                       treated  BRD-K18574842-323-03-3
# ...                         ...                     ...
# 152981                  treated  BRD-K17405724-001-01-0
# 152982                  treated  BRD-K90170141-001-01-5
# 152983                  treated  BRD-K45307499-001-01-7
# 152984                  treated  BRD-K84521261-001-01-1
# 152985                  treated  BRD-K78922936-001-01-4
#
#         Metadata_mmoles_per_liter Metadata_solvent Metadata_pert_id  \
# 0                        3.022516             DMSO    BRD-K18250272
# 1                        5.000000             DMSO    BRD-K18316707
# 2                        5.000000             DMSO    BRD-K18438502
# 3                        5.000000             DMSO    BRD-K18550767
# 4                        2.195487             DMSO    BRD-K18574842
# ...                           ...              ...              ...
# 152981                   4.916061             DMSO    BRD-K17405724
# 152982                   4.859274             DMSO    BRD-K90170141
# 152983                   5.109445             DMSO    BRD-K45307499
# 152984                   4.958284             DMSO    BRD-K84521261
# 152985                   4.843713             DMSO    BRD-K78922936
#
#           Metadata_pert_mfc_id Metadata_pert_well  Metadata_pert_id_vendor  \
# 0       BRD-K18250272-003-03-7                a01                      NaN
# 1       BRD-K18316707-001-01-9                a02                      NaN
# 2       BRD-K18438502-001-02-6                a03                      NaN
# 3       BRD-K18550767-001-02-8                a04                      NaN
# 4       BRD-K18574842-323-03-3                a05                      NaN
# ...                        ...                ...                      ...
# 152981  BRD-K17405724-001-01-0                p20                      NaN
# 152982  BRD-K90170141-001-01-5                p21                      NaN
# 152983  BRD-K45307499-001-01-7                p22                      NaN
# 152984  BRD-K84521261-001-01-1                p23                      NaN
# 152985  BRD-K78922936-001-01-4                p24                      NaN
#
#        Metadata_cell_id Metadata_broad_sample_type Metadata_pert_vehicle  \
# 0                  U2OS                        trt                  DMSO
# 1                  U2OS                        trt                  DMSO
# 2                  U2OS                        trt                  DMSO
# 3                  U2OS                        trt                  DMSO
# 4                  U2OS                        trt                  DMSO
# ...                 ...                        ...                   ...
# 152981             U2OS                        trt                  DMSO
# 152982             U2OS                        trt                  DMSO
# 152983             U2OS                        trt                  DMSO
# 152984             U2OS                        trt                  DMSO
# 152985             U2OS                        trt                  DMSO
#
#        Metadata_pert_type
# 0                     trt
# 1                     trt
# 2                     trt
# 3                     trt
# 4                     trt
# ...                   ...
# 152981                trt
# 152982                trt
# 152983                trt
# 152984                trt
# 152985                trt
#
# [152986 rows x 17 columns]
#         Cells_AreaShape_Compactness  Cells_AreaShape_Eccentricity  \
# 0                          0.078926                      0.231064
# 1                         -0.737871                     -0.583983
# 2                         -1.329970                     -1.562149
# 3                          0.690337                      0.454657
# 4                          0.046566                      0.421291
# ...                             ...                           ...
# 152981                    -0.413052                     -0.609426
# 152982                    -0.288141                     -0.127330
# 152983                     0.530441                      0.526750
# 152984                     0.610588                      0.320274
# 152985                     1.376351                      1.490985
#
#         Cells_AreaShape_Extent  Cells_AreaShape_FormFactor  \
# 0                     0.448321                    1.532845
# 1                     1.598269                    2.110686
# 2                     1.550889                    2.674444
# 3                    -0.391188                    2.050017
# 4                     1.105781                    2.450260
# ...                        ...                         ...
# 152981               -0.295586                   -0.189501
# 152982                0.094676                   -0.061961
# 152983               -1.492881                   -0.233606
# 152984               -0.231764                   -0.584708
# 152985               -1.037901                   -1.576410
#
#         Cells_AreaShape_MajorAxisLength  Cells_AreaShape_MaxFeretDiameter  \
# 0                             -0.185984                         -0.346320
# 1                             -0.936617                         -0.906841
# 2                             -1.198363                         -1.330881
# 3                             -0.145173                         -0.217373
# 4                             -0.190306                         -0.243318
# ...                                 ...                               ...
# 152981                        -0.988800                         -0.960234
# 152982                        -0.503964                         -0.390436
# 152983                         0.302658                          0.283036
# 152984                         0.160784                          0.092512
# 152985                         0.301354                          0.308361
#
#         Cells_AreaShape_MaximumRadius  Cells_AreaShape_MeanRadius  \
# 0                           -0.239180                   -0.149234
# 1                           -0.951034                   -0.711634
# 2                           -1.037002                   -0.918266
# 3                           -0.302594                   -0.182427
# 4                           -0.010269                    0.243082
# ...                               ...                         ...
# 152981                      -1.135490                   -1.189179
# 152982                      -0.463064                   -0.528157
# 152983                      -0.186687                   -0.154979
# 152984                      -0.082504                   -0.211326
# 152985                      -0.082504                   -0.055898
#
#         Cells_AreaShape_MinFeretDiameter  Cells_AreaShape_MinorAxisLength  \
# 0                              -0.488817                        -0.357977
# 1                              -1.060913                        -0.905557
# 2                              -1.353497                        -1.236040
# 3                              -0.503169                        -0.388338
# 4                              -0.420993                        -0.225662
# ...                                  ...                              ...
# 152981                         -0.995642                        -1.162389
# 152982                         -0.212549                        -0.273132
# 152983                         -0.027540                        -0.024823
# 152984                         -0.013560                        -0.046903
# 152985                         -0.151058                        -0.171936
#
#         ...  Nuclei_Texture_Variance_DNA_5_0  Nuclei_Texture_Variance_ER_10_0  \
# 0       ...                         1.398067                         0.380859
# 1       ...                         0.937262                         0.762472
# 2       ...                         1.423467                         1.895575
# 3       ...                         2.044918                         1.694307
# 4       ...                         2.506612                         2.053573
# ...     ...                              ...                              ...
# 152981  ...                         0.171878                         1.380215
# 152982  ...                        -0.575383                         0.646172
# 152983  ...                         0.356225                         0.411284
# 152984  ...                         0.008328                         1.313826
# 152985  ...                         1.041323                         2.463292
#
#         Nuclei_Texture_Variance_ER_3_0  Nuclei_Texture_Variance_ER_5_0  \
# 0                             1.977683                        1.275858
# 1                             2.037728                        1.791103
# 2                             2.730612                        2.432356
# 3                             2.625837                        2.377287
# 4                             3.819272                        3.231044
# ...                                ...                             ...
# 152981                        1.393879                        1.514179
# 152982                        0.441900                        0.493021
# 152983                        0.601454                        0.435225
# 152984                        0.908012                        1.069683
# 152985                        2.499972                        2.152792
#
#         Nuclei_Texture_Variance_Mito_10_0  Nuclei_Texture_Variance_Mito_3_0  \
# 0                               -1.120772                         -0.279341
# 1                                0.117729                          0.064466
# 2                                0.624174                          0.403561
# 3                                0.734662                          0.126940
# 4                                0.457770                          0.576105
# ...                                   ...                               ...
# 152981                          -0.076942                         -0.764094
# 152982                          -0.495273                         -0.867406
# 152983                          -1.204046                         -1.117700
# 152984                          -1.028122                         -1.176572
# 152985                          -0.658633                         -1.161022
#
#         Nuclei_Texture_Variance_Mito_5_0  Nuclei_Texture_Variance_RNA_10_0  \
# 0                              -0.661429                          1.009858
# 1                               0.170203                          1.509152
# 2                               0.423846                          1.233723
# 3                               0.379882                          2.195334
# 4                               0.617578                          2.730167
# ...                                  ...                               ...
# 152981                         -0.640494                         -1.329555
# 152982                         -0.767550                         -1.028755
# 152983                         -1.133875                         -0.430496
# 152984                         -1.209701                         -1.089709
# 152985                         -1.085095                         -1.871556
#
#         Nuclei_Texture_Variance_RNA_3_0  Nuclei_Texture_Variance_RNA_5_0
# 0                              0.488186                         0.367526
# 1                              0.872437                         0.763217
# 2                              0.891833                         0.907474
# 3                              1.612173                         1.735053
# 4                              2.061351                         2.095849
# ...                                 ...                              ...
# 152981                        -1.360398                        -1.443945
# 152982                        -1.043241                        -0.954601
# 152983                        -0.745034                        -0.723075
# 152984                        -1.448997                        -1.293740
# 152985                        -2.211931                        -2.026593
#
# [152986 rows x 1400 columns]

# %%
# MODZ Scaling for validaiton dataset
x_val_df['Metadata_broad_sample'] = x_val_meta['Metadata_broad_sample']

x_df_modz = modz(
    x_val_df,
    replicate_columns = ['Metadata_broad_sample'],
    precision = 5
)


x_df_modz_f = x_df_modz
x_df_modz = x_df_modz.iloc[:, 1:]
display(x_df_modz)
display(x_df_modz_f)
# Out:
#        Cells_AreaShape_Compactness  Cells_AreaShape_Eccentricity  \
# 0                         0.001517                      0.277820
# 1                         0.034036                      0.090993
# 2                        -0.418352                     -0.452332
# 3                        -0.302987                     -0.107649
# 4                         1.015297                      0.971762
# ...                            ...                           ...
# 30612                    -0.265613                     -0.433268
# 30613                    -0.210157                     -0.305976
# 30614                     0.597644                      0.486508
# 30615                     0.806925                      0.851465
# 30616                    -0.167642                     -0.352726
#
#        Cells_AreaShape_Extent  Cells_AreaShape_FormFactor  \
# 0                    0.504330                   -0.065387
# 1                    0.306434                    0.656347
# 2                    0.874477                    1.169239
# 3                    0.926159                    0.248480
# 4                   -0.344257                    0.225323
# ...                       ...                         ...
# 30612                0.493264                    0.043408
# 30613                0.503456                   -0.080167
# 30614               -0.388333                    0.915099
# 30615               -0.373886                    0.429034
# 30616                0.175404                   -0.056488
#
#        Cells_AreaShape_MajorAxisLength  Cells_AreaShape_MaxFeretDiameter  \
# 0                             0.062889                          0.075443
# 1                             0.169470                          0.097680
# 2                            -0.875260                         -0.897311
# 3                             0.374914                          0.375433
# 4                             0.981853                          1.036833
# ...                                ...                               ...
# 30612                        -0.420174                         -0.448928
# 30613                        -0.609581                         -0.617716
# 30614                         0.624892                          0.577874
# 30615                         1.313307                          1.253971
# 30616                        -0.126315                         -0.119864
#
#        Cells_AreaShape_MaximumRadius  Cells_AreaShape_MeanRadius  \
# 0                           0.054113                    0.188722
# 1                           0.273494                    0.223999
# 2                          -0.907200                   -0.869241
# 3                           0.827529                    0.768058
# 4                           0.848087                    0.872655
# ...                              ...                         ...
# 30612                      -0.318385                   -0.310333
# 30613                      -0.591531                   -0.604536
# 30614                       0.631964                    0.754461
# 30615                       1.375236                    1.400515
# 30616                      -0.065805                   -0.092746
#
#        Cells_AreaShape_MinFeretDiameter  Cells_AreaShape_MinorAxisLength  ...  \
# 0                             -0.130858                        -0.136382  ...
# 1                              0.274959                         0.263713  ...
# 2                             -1.096682                        -1.076988  ...
# 3                              0.554810                         0.682450  ...
# 4                              0.825637                         0.816335  ...
# ...                                 ...                              ...  ...
# 30612                         -0.296333                        -0.272400  ...
# 30613                         -0.566016                        -0.557393  ...
# 30614                          0.850882                         0.836880  ...
# 30615                          1.388219                         1.416915  ...
# 30616                         -0.028472                        -0.020770  ...
#
#        Nuclei_Texture_Variance_DNA_5_0  Nuclei_Texture_Variance_ER_10_0  \
# 0                             0.150347                        -0.582148
# 1                             0.263372                        -0.718833
# 2                             1.200041                         1.311100
# 3                             0.527436                        -0.664602
# 4                             1.502258                        -0.996452
# ...                                ...                              ...
# 30612                        -0.130101                        -0.145140
# 30613                        -0.343942                         0.760601
# 30614                         0.132184                        -1.306855
# 30615                         0.618390                        -1.604463
# 30616                         0.187355                         0.216017
#
#        Nuclei_Texture_Variance_ER_3_0  Nuclei_Texture_Variance_ER_5_0  \
# 0                           -0.476835                       -0.599079
# 1                           -0.380045                       -0.425015
# 2                            1.775256                        1.558439
# 3                           -0.484909                       -0.514862
# 4                           -0.988205                       -1.186983
# ...                               ...                             ...
# 30612                        0.013093                        0.052746
# 30613                        0.402465                        0.596649
# 30614                       -1.365039                       -1.293119
# 30615                       -1.515319                       -1.582861
# 30616                        0.351055                        0.304754
#
#        Nuclei_Texture_Variance_Mito_10_0  Nuclei_Texture_Variance_Mito_3_0  \
# 0                              -0.378143                         -0.289351
# 1                              -0.320584                         -0.054972
# 2                               0.854839                          0.777536
# 3                              -0.452709                         -0.296196
# 4                              -0.710340                         -0.500895
# ...                                  ...                               ...
# 30612                          -0.828810                         -0.877587
# 30613                          -0.304898                         -0.682755
# 30614                          -0.470069                         -0.236536
# 30615                          -0.668558                         -0.681813
# 30616                           0.463504                          0.341548
#
#        Nuclei_Texture_Variance_Mito_5_0  Nuclei_Texture_Variance_RNA_10_0  \
# 0                             -0.312277                          1.013788
# 1                             -0.143702                          0.078715
# 2                              0.807036                          3.170317
# 3                             -0.325485                          1.374789
# 4                             -0.613318                          0.537547
# ...                                 ...                               ...
# 30612                         -0.837383                         -0.535416
# 30613                         -0.636920                         -0.487289
# 30614                         -0.253907                         -0.178110
# 30615                         -0.753128                          0.523788
# 30616                          0.377033                          0.295657
#
#        Nuclei_Texture_Variance_RNA_3_0  Nuclei_Texture_Variance_RNA_5_0
# 0                             1.052467                         1.207051
# 1                             0.138940                         0.073614
# 2                             2.884533                         3.037351
# 3                             1.315783                         1.310991
# 4                             0.145562                         0.217822
# ...                                ...                              ...
# 30612                        -0.393819                        -0.292694
# 30613                        -0.547894                        -0.561567
# 30614                        -0.096819                        -0.159071
# 30615                         0.115707                         0.128306
# 30616                         0.352141                         0.321417
#
# [30617 rows x 1400 columns]
#         Metadata_broad_sample  Cells_AreaShape_Compactness  \
# 0      BRD-A00037023-001-05-1                     0.001517
# 1      BRD-A00051892-001-05-0                     0.034036
# 2      BRD-A00100033-001-04-8                    -0.418352
# 3      BRD-A00214921-001-04-2                    -0.302987
# 4      BRD-A00250346-001-05-0                     1.015297
# ...                       ...                          ...
# 30612  BRD-M97925630-001-01-1                    -0.265613
# 30613  BRD-M98484762-001-01-8                    -0.210157
# 30614  BRD-U48977771-000-01-3                     0.597644
# 30615  BRD-U62737497-000-01-5                     0.806925
# 30616                    DMSO                    -0.167642
#
#        Cells_AreaShape_Eccentricity  Cells_AreaShape_Extent  \
# 0                          0.277820                0.504330
# 1                          0.090993                0.306434
# 2                         -0.452332                0.874477
# 3                         -0.107649                0.926159
# 4                          0.971762               -0.344257
# ...                             ...                     ...
# 30612                     -0.433268                0.493264
# 30613                     -0.305976                0.503456
# 30614                      0.486508               -0.388333
# 30615                      0.851465               -0.373886
# 30616                     -0.352726                0.175404
#
#        Cells_AreaShape_FormFactor  Cells_AreaShape_MajorAxisLength  \
# 0                       -0.065387                         0.062889
# 1                        0.656347                         0.169470
# 2                        1.169239                        -0.875260
# 3                        0.248480                         0.374914
# 4                        0.225323                         0.981853
# ...                           ...                              ...
# 30612                    0.043408                        -0.420174
# 30613                   -0.080167                        -0.609581
# 30614                    0.915099                         0.624892
# 30615                    0.429034                         1.313307
# 30616                   -0.056488                        -0.126315
#
#        Cells_AreaShape_MaxFeretDiameter  Cells_AreaShape_MaximumRadius  \
# 0                              0.075443                       0.054113
# 1                              0.097680                       0.273494
# 2                             -0.897311                      -0.907200
# 3                              0.375433                       0.827529
# 4                              1.036833                       0.848087
# ...                                 ...                            ...
# 30612                         -0.448928                      -0.318385
# 30613                         -0.617716                      -0.591531
# 30614                          0.577874                       0.631964
# 30615                          1.253971                       1.375236
# 30616                         -0.119864                      -0.065805
#
#        Cells_AreaShape_MeanRadius  Cells_AreaShape_MinFeretDiameter  ...  \
# 0                        0.188722                         -0.130858  ...
# 1                        0.223999                          0.274959  ...
# 2                       -0.869241                         -1.096682  ...
# 3                        0.768058                          0.554810  ...
# 4                        0.872655                          0.825637  ...
# ...                           ...                               ...  ...
# 30612                   -0.310333                         -0.296333  ...
# 30613                   -0.604536                         -0.566016  ...
# 30614                    0.754461                          0.850882  ...
# 30615                    1.400515                          1.388219  ...
# 30616                   -0.092746                         -0.028472  ...
#
#        Nuclei_Texture_Variance_DNA_5_0  Nuclei_Texture_Variance_ER_10_0  \
# 0                             0.150347                        -0.582148
# 1                             0.263372                        -0.718833
# 2                             1.200041                         1.311100
# 3                             0.527436                        -0.664602
# 4                             1.502258                        -0.996452
# ...                                ...                              ...
# 30612                        -0.130101                        -0.145140
# 30613                        -0.343942                         0.760601
# 30614                         0.132184                        -1.306855
# 30615                         0.618390                        -1.604463
# 30616                         0.187355                         0.216017
#
#        Nuclei_Texture_Variance_ER_3_0  Nuclei_Texture_Variance_ER_5_0  \
# 0                           -0.476835                       -0.599079
# 1                           -0.380045                       -0.425015
# 2                            1.775256                        1.558439
# 3                           -0.484909                       -0.514862
# 4                           -0.988205                       -1.186983
# ...                               ...                             ...
# 30612                        0.013093                        0.052746
# 30613                        0.402465                        0.596649
# 30614                       -1.365039                       -1.293119
# 30615                       -1.515319                       -1.582861
# 30616                        0.351055                        0.304754
#
#        Nuclei_Texture_Variance_Mito_10_0  Nuclei_Texture_Variance_Mito_3_0  \
# 0                              -0.378143                         -0.289351
# 1                              -0.320584                         -0.054972
# 2                               0.854839                          0.777536
# 3                              -0.452709                         -0.296196
# 4                              -0.710340                         -0.500895
# ...                                  ...                               ...
# 30612                          -0.828810                         -0.877587
# 30613                          -0.304898                         -0.682755
# 30614                          -0.470069                         -0.236536
# 30615                          -0.668558                         -0.681813
# 30616                           0.463504                          0.341548
#
#        Nuclei_Texture_Variance_Mito_5_0  Nuclei_Texture_Variance_RNA_10_0  \
# 0                             -0.312277                          1.013788
# 1                             -0.143702                          0.078715
# 2                              0.807036                          3.170317
# 3                             -0.325485                          1.374789
# 4                             -0.613318                          0.537547
# ...                                 ...                               ...
# 30612                         -0.837383                         -0.535416
# 30613                         -0.636920                         -0.487289
# 30614                         -0.253907                         -0.178110
# 30615                         -0.753128                          0.523788
# 30616                          0.377033                          0.295657
#
#        Nuclei_Texture_Variance_RNA_3_0  Nuclei_Texture_Variance_RNA_5_0
# 0                             1.052467                         1.207051
# 1                             0.138940                         0.073614
# 2                             2.884533                         3.037351
# 3                             1.315783                         1.310991
# 4                             0.145562                         0.217822
# ...                                ...                              ...
# 30612                        -0.393819                        -0.292694
# 30613                        -0.547894                        -0.561567
# 30614                        -0.096819                        -0.159071
# 30615                         0.115707                         0.128306
# 30616                         0.352141                         0.321417
#
# [30617 rows x 1401 columns]

# %%
# Load IDR0080 Cell Painting Data
x_df = pd.read_csv('cell_painting_modz.tsv', sep = '\t')
x_meta = x_df.iloc[:, :3]
x_df = x_df.iloc[:, 3:]

# %%
# Filter except same features in idr0080 in dir0080 & cpg0012
x_cols = x_df.columns
x_val_cols = x_df_modz.columns

filt_cols = x_cols.intersection(x_val_cols)

x_df = x_df[filt_cols]
x_val_df = x_df_modz[filt_cols]

display(x_df)
display(x_val_df)
# Out:
#      Cells_AreaShape_Compactness  Cells_AreaShape_Eccentricity  \
# 0                      -0.155631                      0.014646
# 1                      -0.247842                     -0.030773
# 2                       0.794740                      0.743296
# 3                       0.480421                      0.821096
# 4                      -0.074895                      0.569377
# ..                           ...                           ...
# 352                     0.247953                      0.331462
# 353                     1.455427                      1.153796
# 354                     0.719510                      0.691270
# 355                    -0.255658                      0.075113
# 356                     0.075324                      0.268191
#
#      Cells_AreaShape_Extent  Cells_AreaShape_Orientation  \
# 0                  0.188053                     1.231056
# 1                  0.433778                     0.062456
# 2                 -0.438752                     0.827288
# 3                 -0.337898                     0.054479
# 4                  0.571678                     0.976504
# ..                      ...                          ...
# 352               -0.228694                     0.648857
# 353               -1.395398                     1.167778
# 354               -0.999921                     0.701489
# 355                0.999995                     0.251456
# 356                0.171536                    -0.295649
#
#      Cells_AreaShape_Zernike_0_0  Cells_AreaShape_Zernike_1_1  \
# 0                       0.031064                    -0.585477
# 1                       0.266860                     0.838679
# 2                      -0.728499                    -0.422394
# 3                      -0.662314                     0.067979
# 4                      -1.111947                     1.348542
# ..                           ...                          ...
# 352                    -0.394799                    -0.477804
# 353                    -1.413069                    -0.684198
# 354                    -0.965601                    -0.937154
# 355                     0.237111                     0.342004
# 356                     0.063491                    -0.284757
#
#      Cells_AreaShape_Zernike_2_0  Cells_AreaShape_Zernike_2_2  \
# 0                       0.467976                     0.254203
# 1                      -0.467417                     0.340793
# 2                      -0.147624                     0.083870
# 3                       0.025010                     0.158138
# 4                       0.584906                    -3.128483
# ..                           ...                          ...
# 352                    -0.203016                     0.387554
# 353                    -0.923160                    -0.145706
# 354                    -0.218680                     0.145943
# 355                     0.084765                     0.957639
# 356                    -0.231007                     0.914041
#
#      Cells_AreaShape_Zernike_3_3  Cells_AreaShape_Zernike_4_0  ...  \
# 0                       0.129446                     0.027104  ...
# 1                      -0.024450                     0.418928  ...
# 2                      -0.160722                    -0.363004  ...
# 3                      -0.342062                    -0.434783  ...
# 4                      -2.324773                     1.945741  ...
# ..                           ...                          ...  ...
# 352                     0.485502                    -0.302333  ...
# 353                    -0.535382                     0.224011  ...
# 354                    -0.149745                    -0.637266  ...
# 355                    -0.562746                    -0.409896  ...
# 356                    -0.863927                     0.023224  ...
#
#      Nuclei_Texture_SumEntropy_DNA_5_0  Nuclei_Texture_SumEntropy_ER_5_0  \
# 0                             0.882859                          0.841687
# 1                             0.513820                          0.344554
# 2                            -0.456539                          0.373750
# 3                             0.115466                          0.186411
# 4                             0.154802                          2.975785
# ..                                 ...                               ...
# 352                           0.305814                          0.952718
# 353                          -0.207834                         -0.280317
# 354                           0.011171                         -0.575574
# 355                           0.766721                          0.518347
# 356                           0.753911                          1.204849
#
#      Nuclei_Texture_SumEntropy_Mito_5_0  Nuclei_Texture_SumEntropy_RNA_5_0  \
# 0                              0.339831                           0.562585
# 1                              0.134318                           0.018933
# 2                             -0.111184                          -0.042733
# 3                              0.249292                           0.688435
# 4                              1.128414                          -0.638839
# ..                                  ...                                ...
# 352                            0.697652                           0.087784
# 353                           -0.422648                          -0.763835
# 354                           -0.272102                          -0.101586
# 355                            1.450779                           1.421830
# 356                            1.660608                           0.868990
#
#      Nuclei_Texture_SumVariance_AGP_5_0  Nuclei_Texture_SumVariance_DNA_10_0  \
# 0                              0.879950                             0.904785
# 1                              0.359496                             0.557998
# 2                             -0.840771                            -0.536215
# 3                             -0.521766                             0.124801
# 4                              0.753884                             0.808944
# ..                                  ...                                  ...
# 352                            0.266722                             0.254346
# 353                           -0.254697                            -0.380000
# 354                           -0.117305                            -0.083261
# 355                            1.483743                             0.639279
# 356                            0.752902                             0.883916
#
#      Nuclei_Texture_SumVariance_DNA_5_0  Nuclei_Texture_Variance_AGP_5_0  \
# 0                              0.923143                         0.944998
# 1                              0.504751                         0.407462
# 2                             -0.497296                        -0.748232
# 3                              0.063444                        -0.560178
# 4                              0.594059                         0.674015
# ..                                  ...                              ...
# 352                            0.367875                         0.191115
# 353                           -0.404530                        -0.266026
# 354                           -0.085342                        -0.213054
# 355                            0.614153                         1.624128
# 356                            0.989018                         0.830979
#
#      Nuclei_Texture_Variance_DNA_10_0  Nuclei_Texture_Variance_DNA_5_0
# 0                            0.984938                         0.961945
# 1                            0.522251                         0.519441
# 2                           -0.515240                        -0.526734
# 3                           -0.062851                         0.026056
# 4                            0.140325                         0.417465
# ..                                ...                              ...
# 352                          0.220894                         0.257950
# 353                         -0.341998                        -0.287431
# 354                         -0.126822                        -0.101668
# 355                          0.523767                         0.603819
# 356                          0.905580                         0.884586
#
# [357 rows x 736 columns]
#        Cells_AreaShape_Compactness  Cells_AreaShape_Eccentricity  \
# 0                         0.001517                      0.277820
# 1                         0.034036                      0.090993
# 2                        -0.418352                     -0.452332
# 3                        -0.302987                     -0.107649
# 4                         1.015297                      0.971762
# ...                            ...                           ...
# 30612                    -0.265613                     -0.433268
# 30613                    -0.210157                     -0.305976
# 30614                     0.597644                      0.486508
# 30615                     0.806925                      0.851465
# 30616                    -0.167642                     -0.352726
#
#        Cells_AreaShape_Extent  Cells_AreaShape_Orientation  \
# 0                    0.504330                     0.872770
# 1                    0.306434                     0.485507
# 2                    0.874477                    -0.128444
# 3                    0.926159                     0.397246
# 4                   -0.344257                     0.236280
# ...                       ...                          ...
# 30612                0.493264                    -0.545809
# 30613                0.503456                    -0.028201
# 30614               -0.388333                    -0.393189
# 30615               -0.373886                     0.048235
# 30616                0.175404                     0.006627
#
#        Cells_AreaShape_Zernike_0_0  Cells_AreaShape_Zernike_1_1  \
# 0                        -0.062229                    -0.097463
# 1                         0.052555                    -0.031708
# 2                         0.677804                     0.464805
# 3                         0.287252                    -0.666721
# 4                        -0.908705                     0.246192
# ...                            ...                          ...
# 30612                     0.505944                    -0.235360
# 30613                     0.453887                     0.195480
# 30614                    -0.434949                     0.348865
# 30615                    -0.452466                    -0.217211
# 30616                     0.245803                     0.200575
#
#        Cells_AreaShape_Zernike_2_0  Cells_AreaShape_Zernike_2_2  \
# 0                        -0.136418                     1.363021
# 1                        -0.116941                     0.108810
# 2                         0.139284                     0.689670
# 3                         0.485750                     0.286509
# 4                        -1.322807                     0.577879
# ...                            ...                          ...
# 30612                     0.530636                     0.305867
# 30613                     0.276551                     0.262468
# 30614                    -0.739404                    -0.280500
# 30615                    -0.818209                     0.555877
# 30616                     0.140865                    -0.090486
#
#        Cells_AreaShape_Zernike_3_3  Cells_AreaShape_Zernike_4_0  ...  \
# 0                        -0.121675                     0.111071  ...
# 1                        -0.257286                     0.182884  ...
# 2                         0.092896                    -0.396120  ...
# 3                        -0.249060                     0.851031  ...
# 4                        -0.200651                     0.544807  ...
# ...                            ...                          ...  ...
# 30612                    -0.243942                    -0.247084  ...
# 30613                     0.886899                    -0.258701  ...
# 30614                     0.231109                    -0.160809  ...
# 30615                     0.007761                     0.535272  ...
# 30616                     0.222532                    -0.230299  ...
#
#        Nuclei_Texture_SumEntropy_DNA_5_0  Nuclei_Texture_SumEntropy_ER_5_0  \
# 0                               0.012441                         -0.515965
# 1                               0.148373                         -0.708293
# 2                               1.174464                          1.873223
# 3                               0.402387                         -0.358765
# 4                               1.195175                         -0.566205
# ...                                  ...                               ...
# 30612                          -0.166256                         -0.606686
# 30613                          -0.326757                         -0.692443
# 30614                           0.281298                         -0.558976
# 30615                           0.762975                         -1.044746
# 30616                           0.167862                          0.177851
#
#        Nuclei_Texture_SumEntropy_Mito_5_0  Nuclei_Texture_SumEntropy_RNA_5_0  \
# 0                               -0.125886                           0.378361
# 1                               -0.168461                           0.159921
# 2                                0.559107                           1.438213
# 3                               -0.296739                           0.925500
# 4                               -0.462147                           0.560941
# ...                                   ...                                ...
# 30612                           -1.410230                          -1.127026
# 30613                           -1.197271                          -1.103457
# 30614                           -0.394671                          -0.123102
# 30615                           -0.611885                           0.340107
# 30616                            0.061965                           0.170837
#
#        Nuclei_Texture_SumVariance_AGP_5_0  \
# 0                               -0.192612
# 1                                0.005949
# 2                                1.659821
# 3                               -0.294972
# 4                               -0.435885
# ...                                   ...
# 30612                           -0.063554
# 30613                            0.064433
# 30614                           -0.271379
# 30615                           -0.832198
# 30616                            0.388981
#
#        Nuclei_Texture_SumVariance_DNA_10_0  \
# 0                                 0.263924
# 1                                 0.278903
# 2                                 1.049936
# 3                                 0.741252
# 4                                 1.580252
# ...                                    ...
# 30612                            -0.134207
# 30613                            -0.189828
# 30614                             0.429285
# 30615                             0.986590
# 30616                             0.166736
#
#        Nuclei_Texture_SumVariance_DNA_5_0  Nuclei_Texture_Variance_AGP_5_0  \
# 0                                0.134799                        -0.065563
# 1                                0.181974                         0.119256
# 2                                1.254289                         0.822218
# 3                                0.544289                        -0.375331
# 4                                1.477814                        -0.779816
# ...                                   ...                              ...
# 30612                           -0.174389                         0.904218
# 30613                           -0.262928                         0.950440
# 30614                            0.213798                        -0.222311
# 30615                            0.869581                        -1.017756
# 30616                            0.203871                         0.266327
#
#        Nuclei_Texture_Variance_DNA_10_0  Nuclei_Texture_Variance_DNA_5_0
# 0                              0.159910                         0.150347
# 1                              0.289176                         0.263372
# 2                              1.143912                         1.200041
# 3                              0.497514                         0.527436
# 4                              1.448586                         1.502258
# ...                                 ...                              ...
# 30612                         -0.093846                        -0.130101
# 30613                         -0.374726                        -0.343942
# 30614                          0.061249                         0.132184
# 30615                          0.612146                         0.618390
# 30616                          0.153103                         0.187355
#
# [30617 rows x 736 columns]

# %%
# Save File
x_df.to_csv('x_df.csv')
x_val_df.to_csv('x_val_df.csv')
x_val_meta.to_csv('x_val_meta.csv')
x_df_modz_f.to_csv('x_val_dff.csv')
