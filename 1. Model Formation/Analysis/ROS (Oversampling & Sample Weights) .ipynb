# %% [markdown]
# # DNA Damage model formation & Prediction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings

# %%
warnings.filterwarnings(action = 'ignore')

# %% [markdown]
# ## 1. Preparing Cell Painting Data & Cell Health Data

# %% [markdown]
# ### Load IDR-0080 Data & Cell Health Data
# ### Reference : https://pubmed.ncbi.nlm.nih.gov/33534641/

# %%
x_df = pd.read_csv('x_df.csv', index_col = None)
x_df = x_df.iloc[:, 1:]
x_df
# Out:
#      Cells_AreaShape_Compactness  Cells_AreaShape_Eccentricity  \
# 0                      -0.155631                      0.014646
# 1                      -0.247842                     -0.030773
# 2                       0.794740                      0.743296
# 3                       0.480421                      0.821096
# 4                      -0.074895                      0.569377
# ..                           ...                           ...
# 352                     0.247953                      0.331462
# 353                     1.455427                      1.153796
# 354                     0.719510                      0.691270
# 355                    -0.255658                      0.075113
# 356                     0.075324                      0.268191
#
#      Cells_AreaShape_Extent  Cells_AreaShape_Orientation  \
# 0                  0.188053                     1.231056
# 1                  0.433778                     0.062456
# 2                 -0.438752                     0.827288
# 3                 -0.337898                     0.054479
# 4                  0.571678                     0.976504
# ..                      ...                          ...
# 352               -0.228694                     0.648857
# 353               -1.395398                     1.167778
# 354               -0.999921                     0.701489
# 355                0.999995                     0.251456
# 356                0.171536                    -0.295649
#
#      Cells_AreaShape_Zernike_0_0  Cells_AreaShape_Zernike_1_1  \
# 0                       0.031064                    -0.585477
# 1                       0.266860                     0.838679
# 2                      -0.728499                    -0.422394
# 3                      -0.662314                     0.067979
# 4                      -1.111947                     1.348542
# ..                           ...                          ...
# 352                    -0.394799                    -0.477804
# 353                    -1.413069                    -0.684198
# 354                    -0.965601                    -0.937154
# 355                     0.237111                     0.342004
# 356                     0.063491                    -0.284757
#
#      Cells_AreaShape_Zernike_2_0  Cells_AreaShape_Zernike_2_2  \
# 0                       0.467976                     0.254203
# 1                      -0.467417                     0.340793
# 2                      -0.147624                     0.083870
# 3                       0.025010                     0.158138
# 4                       0.584906                    -3.128483
# ..                           ...                          ...
# 352                    -0.203016                     0.387554
# 353                    -0.923160                    -0.145706
# 354                    -0.218680                     0.145943
# 355                     0.084765                     0.957639
# 356                    -0.231007                     0.914041
#
#      Cells_AreaShape_Zernike_3_3  Cells_AreaShape_Zernike_4_0  ...  \
# 0                       0.129446                     0.027104  ...
# 1                      -0.024450                     0.418928  ...
# 2                      -0.160722                    -0.363004  ...
# 3                      -0.342062                    -0.434783  ...
# 4                      -2.324773                     1.945741  ...
# ..                           ...                          ...  ...
# 352                     0.485502                    -0.302333  ...
# 353                    -0.535382                     0.224011  ...
# 354                    -0.149745                    -0.637266  ...
# 355                    -0.562746                    -0.409896  ...
# 356                    -0.863927                     0.023224  ...
#
#      Nuclei_Texture_SumEntropy_DNA_5_0  Nuclei_Texture_SumEntropy_ER_5_0  \
# 0                             0.882859                          0.841687
# 1                             0.513820                          0.344554
# 2                            -0.456539                          0.373750
# 3                             0.115466                          0.186411
# 4                             0.154802                          2.975785
# ..                                 ...                               ...
# 352                           0.305814                          0.952718
# 353                          -0.207834                         -0.280317
# 354                           0.011171                         -0.575574
# 355                           0.766721                          0.518347
# 356                           0.753911                          1.204849
#
#      Nuclei_Texture_SumEntropy_Mito_5_0  Nuclei_Texture_SumEntropy_RNA_5_0  \
# 0                              0.339831                           0.562585
# 1                              0.134318                           0.018933
# 2                             -0.111184                          -0.042733
# 3                              0.249292                           0.688435
# 4                              1.128414                          -0.638839
# ..                                  ...                                ...
# 352                            0.697652                           0.087784
# 353                           -0.422648                          -0.763835
# 354                           -0.272102                          -0.101586
# 355                            1.450779                           1.421830
# 356                            1.660608                           0.868990
#
#      Nuclei_Texture_SumVariance_AGP_5_0  Nuclei_Texture_SumVariance_DNA_10_0  \
# 0                              0.879950                             0.904785
# 1                              0.359496                             0.557998
# 2                             -0.840771                            -0.536215
# 3                             -0.521766                             0.124801
# 4                              0.753884                             0.808944
# ..                                  ...                                  ...
# 352                            0.266722                             0.254346
# 353                           -0.254697                            -0.380000
# 354                           -0.117305                            -0.083261
# 355                            1.483743                             0.639279
# 356                            0.752902                             0.883916
#
#      Nuclei_Texture_SumVariance_DNA_5_0  Nuclei_Texture_Variance_AGP_5_0  \
# 0                              0.923143                         0.944998
# 1                              0.504751                         0.407462
# 2                             -0.497296                        -0.748232
# 3                              0.063444                        -0.560178
# 4                              0.594059                         0.674015
# ..                                  ...                              ...
# 352                            0.367875                         0.191115
# 353                           -0.404530                        -0.266026
# 354                           -0.085342                        -0.213054
# 355                            0.614153                         1.624128
# 356                            0.989018                         0.830979
#
#      Nuclei_Texture_Variance_DNA_10_0  Nuclei_Texture_Variance_DNA_5_0
# 0                            0.984938                         0.961945
# 1                            0.522251                         0.519441
# 2                           -0.515240                        -0.526734
# 3                           -0.062851                         0.026056
# 4                            0.140325                         0.417465
# ..                                ...                              ...
# 352                          0.220894                         0.257950
# 353                         -0.341998                        -0.287431
# 354                         -0.126822                        -0.101668
# 355                          0.523767                         0.603819
# 356                          0.905580                         0.884586
#
# [357 rows x 736 columns]

# %%
# Load cell health data
y_all_df = pd.read_csv('cell_health_modz.tsv', sep = '\t')
y_df = y_all_df['vb_ros_mean']

# %% [markdown]
# ### Load Chemical Annotation Data
# ### Reference : https://gigadb.org/dataset/100351

# %%
# Chemical annotation 
chem_dat = pd.read_csv('chemical_annotations.csv')
chem_dat
# Out:
#                      BROAD_ID       CPD_NAME   CPD_NAME_TYPE CPD_SAMPLE_ID  \
# 0      BRD-A56675431-001-04-0       altizide             INN       SA82748
# 1      BRD-A51829654-001-01-4     BRL-15,572          common       SA82481
# 2      BRD-K04046242-001-03-6        equilin  primary-common       SA82922
# 3      BRD-K16508793-001-01-8       diazepam             INN       SA59660
# 4      BRD-K09397065-001-01-6      SR 57227A   to-be-curated       SA82504
# ...                       ...            ...             ...           ...
# 30611  BRD-K47092271-001-01-7  BRD-K47092271    BROAD_CPD_ID      SA799574
# 30612  BRD-K30358777-001-01-0  BRD-K30358777    BROAD_CPD_ID      SA800605
# 30613  BRD-K32423836-001-01-9  BRD-K32423836    BROAD_CPD_ID      SA799806
# 30614  BRD-K28250273-001-01-2  BRD-K28250273    BROAD_CPD_ID     SA1482018
# 30615  BRD-K72354054-001-01-2  BRD-K72354054    BROAD_CPD_ID     SA1481551
#
#                           DOS_LIBRARY                         SOURCE_NAME  \
# 0                                 NaN             Prestwick Chemical Inc.
# 1                                 NaN           Biomol International Inc.
# 2                                 NaN             Prestwick Chemical Inc.
# 3                                 NaN  MicroSource Discovery Systems Inc.
# 4                                 NaN           Biomol International Inc.
# ...                               ...                                 ...
# 30611              Benzofuran Library  Broad Institute of MIT and Harvard
# 30612              Benzofuran Library  Broad Institute of MIT and Harvard
# 30613              Benzofuran Library  Broad Institute of MIT and Harvard
# 30614  Azetidine Nitrile Full Library  Broad Institute of MIT and Harvard
# 30615  Azetidine Nitrile Full Library  Broad Institute of MIT and Harvard
#
#       CHEMIST_NAME VENDOR_CATALOG_ID  \
# 0              NaN        Prestw-721
# 1              NaN            AC-536
# 2              NaN        Prestw-850
# 3              NaN           1900003
# 4              NaN            AC-561
# ...            ...               ...
# 30611          NaN               NaN
# 30612          NaN               NaN
# 30613          NaN               NaN
# 30614          NaN               NaN
# 30615          NaN               NaN
#
#                                               CPD_SMILES USERCOMMENT
# 0             NS(=O)(=O)c1cc2c(NC(CSCC=C)NS2(=O)=O)cc1Cl         NaN
# 1         OC(CN1CCN(CC1)c1cccc(Cl)c1)C(c1ccccc1)c1ccccc1         NaN
# 2         C[C@]12CC[C@H]3C(=CCc4cc(O)ccc34)[C@@H]1CCC2=O         NaN
# 3                      CN1c2ccc(Cl)cc2C(=NCC1=O)c1ccccc1         NaN
# 4                                NC1CCN(CC1)c1cccc(Cl)n1         NaN
# ...                                                  ...         ...
# 30611  COCC(=O)Nc1ccc2O[C@@H]3[C@@H](C[C@H](CC(=O)NCC...         NaN
# 30612  COc1ccc(CNC(=O)C[C@@H]2C[C@H]3[C@H](Oc4ccc(NC(...         NaN
# 30613  COCCNC(=O)C[C@H]1C[C@@H]2[C@@H](Oc3ccc(NC(=O)C...         NaN
# 30614  OC[C@H]1[C@H]([C@H](C#N)N1C(=O)Nc1cccc(F)c1)c1...         NaN
# 30615  OC[C@H]1[C@@H]([C@H](C#N)N1C(=O)CN1CCOCC1)c1cc...         NaN
#
# [30616 rows x 10 columns]

# %%
# Load validation datasets
x_val_dat = pd.read_csv('x_val_df.csv')
x_val_meta = pd.read_csv('x_val_meta.csv')

# %%
# Check unique compound in validation dataset
compound = x_val_meta['Metadata_broad_sample'].unique()
len(compound)
# Out:
# 30617

# %% [markdown]
# # 2. Cell Health Labeling for Classification Model

# %%
from sklearn.cluster import KMeans

# Create an array to store SSE values for different cluster numbers
sse = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters = k, random_state=42)
    kmeans.fit(y_df.values.reshape(-1, 1))
    sse.append(kmeans.inertia_)


# Plotting the elbow curve
plt.figure(figsize = (8,6))
plt.plot(range(1, 11), sse, marker = 'o')
plt.title('Elbow Method for Optimal Cluster Number')
plt.xlabel('Number of clusters')
plt.ylabel('Sum of Squared Errors (SSE)')
plt.xticks(np.arange(1, 11, 1))
plt.grid(True)
plt.savefig('Elbow Method.png', dpi = 300)
plt.show()

# %%
# y_df Categorized

kmeans = KMeans(n_clusters = 5, random_state = 42)
y_clusters = kmeans.fit_predict(y_df.values.reshape(-1, 1))

y_df_binarized = y_clusters

# %%
from collections import Counter

Counter(y_df_binarized)
# Out:
# Counter({3: 203, 1: 82, 0: 55, 4: 15, 2: 2})

# %%
#y_df.sort_values(ascending = False).to_excel('y_df.xlsx')

# %%
# Remapping
mapping = {1: 0, 0: 0, 3: 0, 5: 0, 2: 1, 4: 1} # 0 : Low, 1: High
y_df_binarized = np.vectorize(mapping.get)(y_df_binarized)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks

# %% [markdown]
# # 3. Oversampling (SMOTE)

# %%
from imblearn.over_sampling import SMOTE
from sklearn.utils.class_weight import compute_sample_weight

# Data Split
X_train, X_test, y_train, y_test = train_test_split(x_df, y_df_binarized, test_size = 0.3, random_state = 42, shuffle  = True)


# Over Sampleing
smote = SMOTE(random_state = 42)

X_train_s, y_train_s = smote.fit_resample(X_train, y_train)

# Data Flatten
y_train_s = np.ravel(y_train_s)
y_test = np.ravel(y_test)

# %% [markdown]
# # 4. Classification Model Formation & Check Accuracy

# %% [markdown]
# ## Oversampling (o) / Model weights (o)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, mean_squared_error, r2_score
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split

class_weights = {0: 1.0, 1: 7.0}

# Models Dictionary
models = {
    'RandomForest': RandomForestClassifier(random_state=42, class_weight= class_weights),
    'GradientBoosting': GradientBoostingClassifier(random_state=42),
    'SVM': SVC(random_state=42, class_weight= class_weights),
    'LogisticRegression': LogisticRegression(random_state=42, class_weight= class_weights),
    'SGDClassifier': SGDClassifier(random_state=42, class_weight= class_weights),
    'KNeighbors': KNeighborsClassifier(),
    'GaussianNB': GaussianNB(),
    'DecisionTree': DecisionTreeClassifier(random_state=42, class_weight= class_weights)
}

# models parameters setting
param_grids = {
    'RandomForest': {
        'n_estimators': [50, 100, 200],
        'max_depth': [None, 10, 20, 30],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4],
        'max_features': ['auto', 'sqrt', 'log2']
    },
    'GradientBoosting': {
        'n_estimators': [50, 100, 200],
        'learning_rate': [0.1, 0.05, 0.01],
        'max_depth': [3, 5, 10],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4],
        'max_features': ['auto', 'sqrt', 'log2']
    },
    'SVM': {
        'C': [0.1, 1, 10],
        'gamma': ['scale', 'auto'],
        'kernel': ['linear', 'rbf', 'poly']
    },
    'LogisticRegression': {
        'C': [0.1, 1, 10],
        'penalty': ['l1','l2']
    },
    'SGDClassifier': {
        'alpha': [0.0001, 0.001, 0.01, 0.1],
        'penalty': ['l1', 'l2']
    },
    'KNeighbors': {
        'n_neighbors': [3, 5, 10],
        'weights': ['uniform', 'distance'],
        'metric': ['euclidean', 'manhattan']
    },
    'GaussianNB': {}, 
    'DecisionTree': {
        'max_depth': [None, 10, 20, 30],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4],
        'max_features': ['auto', 'sqrt', 'log2']
    }
}

# Best Parameter searching
results = {}

for model_name, model in models.items():
    print(f"Training {model_name}...")
    grid_search = GridSearchCV(estimator=model, param_grid=param_grids[model_name], cv=5, scoring='accuracy', verbose=1, n_jobs=-1)
    grid_search.fit(X_train_s, y_train_s)
    
    # Show Best Parameters
    print(f"Best Parameters for {model_name}:")
    print(grid_search.best_params_)
    print(f"Best Cross-validation Accuracy for {model_name}: {grid_search.best_score_:.4f}")
    
    # Prediction with optimal model
    best_model = grid_search.best_estimator_
    y_pred = best_model.predict(X_test)
    test_accuracy = accuracy_score(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    
    # Store ersults in the dictionary
    results[model_name] = {
        'accuracy' : test_accuracy,
        'mse' : mse
    }
    
    # Assesment score present
    print(f"\nTest Accuracy for {model_name}: {test_accuracy:.4f}")
    print("Classification Report:")
    print(classification_report(y_test, y_pred))
    print("---------------------------------------")

# Accuracy 
print("\nTest Accuracy Results:")
for model_name, metrics in results.items():
    print(f"{model_name} Accuracy : {metrics['accuracy']: .4f}, MSE : {metrics['mse']: .2f}")
# Out:
# Training RandomForest...
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# Best Parameters for RandomForest:
# {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# Best Cross-validation Accuracy for RandomForest: 0.9787
#
# Test Accuracy for RandomForest: 0.9444
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       105
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.94       108
#    macro avg       0.49      0.49      0.49       108
# weighted avg       0.94      0.94      0.94       108
#
# ---------------------------------------
# Training GradientBoosting...
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# Best Parameters for GradientBoosting:
# {'learning_rate': 0.1, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 50}
# Best Cross-validation Accuracy for GradientBoosting: 1.0000
#
# Test Accuracy for GradientBoosting: 0.9537
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98       105
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.95       108
#    macro avg       0.49      0.49      0.49       108
# weighted avg       0.94      0.95      0.95       108
#
# ---------------------------------------
# Training SVM...
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# Best Parameters for SVM:
# {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# Best Cross-validation Accuracy for SVM: 0.9851
#
# Test Accuracy for SVM: 0.9352
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.97       105
#            1       0.17      0.33      0.22         3
#
#     accuracy                           0.94       108
#    macro avg       0.57      0.64      0.59       108
# weighted avg       0.96      0.94      0.95       108
#
# ---------------------------------------
# Training LogisticRegression...
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best Parameters for LogisticRegression:
# {'C': 10, 'penalty': 'l2'}
# Best Cross-validation Accuracy for LogisticRegression: 0.9681
#
# Test Accuracy for LogisticRegression: 0.9074
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.91      0.95       105
#            1       0.18      0.67      0.29         3
#
#     accuracy                           0.91       108
#    macro avg       0.59      0.79      0.62       108
# weighted avg       0.97      0.91      0.93       108
#
# ---------------------------------------
# Training SGDClassifier...
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# Best Parameters for SGDClassifier:
# {'alpha': 0.0001, 'penalty': 'l1'}
# Best Cross-validation Accuracy for SGDClassifier: 0.9426
#
# Test Accuracy for SGDClassifier: 0.9074
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.91      0.95       105
#            1       0.18      0.67      0.29         3
#
#     accuracy                           0.91       108
#    macro avg       0.59      0.79      0.62       108
# weighted avg       0.97      0.91      0.93       108
#
# ---------------------------------------
# Training KNeighbors...
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Best Parameters for KNeighbors:
# {'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}
# Best Cross-validation Accuracy for KNeighbors: 0.8957
#
# Test Accuracy for KNeighbors: 0.7593
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.77      0.86       105
#            1       0.04      0.33      0.07         3
#
#     accuracy                           0.76       108
#    macro avg       0.51      0.55      0.47       108
# weighted avg       0.95      0.76      0.84       108
#
# ---------------------------------------
# Training GaussianNB...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Best Parameters for GaussianNB:
# {}
# Best Cross-validation Accuracy for GaussianNB: 0.6957
#
# Test Accuracy for GaussianNB: 0.6574
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.66      0.79       105
#            1       0.05      0.67      0.10         3
#
#     accuracy                           0.66       108
#    macro avg       0.52      0.66      0.44       108
# weighted avg       0.96      0.66      0.77       108
#
# ---------------------------------------
# Training DecisionTree...
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Best Parameters for DecisionTree:
# {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# Best Cross-validation Accuracy for DecisionTree: 0.9617
#
# Test Accuracy for DecisionTree: 0.8981
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.92      0.95       105
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.90       108
#    macro avg       0.48      0.46      0.47       108
# weighted avg       0.94      0.90      0.92       108
#
# ---------------------------------------
#
# Test Accuracy Results:
# RandomForest Accuracy :  0.9444, MSE :  0.06
# GradientBoosting Accuracy :  0.9537, MSE :  0.05
# SVM Accuracy :  0.9352, MSE :  0.06
# LogisticRegression Accuracy :  0.9074, MSE :  0.09
# SGDClassifier Accuracy :  0.9074, MSE :  0.09
# KNeighbors Accuracy :  0.7593, MSE :  0.24
# GaussianNB Accuracy :  0.6574, MSE :  0.34
# DecisionTree Accuracy :  0.8981, MSE :  0.10

# %% [markdown]
# ## Oversampling (x) / Model Weights (o)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, mean_squared_error, r2_score
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split


# Models Dictionary
models = {
    'RandomForest': RandomForestClassifier(random_state=42, class_weight= class_weights),
    'GradientBoosting': GradientBoostingClassifier(random_state=42),
    'SVM': SVC(random_state=42, class_weight= class_weights),
    'LogisticRegression': LogisticRegression(random_state=42, class_weight= class_weights),
    'SGDClassifier': SGDClassifier(random_state=42, class_weight= class_weights),
    'KNeighbors': KNeighborsClassifier(),
    'GaussianNB': GaussianNB(),
    'DecisionTree': DecisionTreeClassifier(random_state=42, class_weight= class_weights)
}

# models parameters setting
param_grids = {
    'RandomForest': {
        'n_estimators': [50, 100, 200],
        'max_depth': [None, 10, 20, 30],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4],
        'max_features': ['auto', 'sqrt', 'log2']
    },
    'GradientBoosting': {
        'n_estimators': [50, 100, 200],
        'learning_rate': [0.1, 0.05, 0.01],
        'max_depth': [3, 5, 10],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4],
        'max_features': ['auto', 'sqrt', 'log2']
    },
    'SVM': {
        'C': [0.1, 1, 10],
        'gamma': ['scale', 'auto'],
        'kernel': ['linear', 'rbf', 'poly']
    },
    'LogisticRegression': {
        'C': [0.1, 1, 10],
        'penalty': ['l1','l2']
    },
    'SGDClassifier': {
        'alpha': [0.0001, 0.001, 0.01, 0.1],
        'penalty': ['l1', 'l2']
    },
    'KNeighbors': {
        'n_neighbors': [3, 5, 10],
        'weights': ['uniform', 'distance'],
        'metric': ['euclidean', 'manhattan']
    },
    'GaussianNB': {}, 
    'DecisionTree': {
        'max_depth': [None, 10, 20, 30],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4],
        'max_features': ['auto', 'sqrt', 'log2']
    }
}

# Best Parameter searching
results = {}

for model_name, model in models.items():
    print(f"Training {model_name}...")
    grid_search = GridSearchCV(estimator=model, param_grid=param_grids[model_name], cv=5, scoring='accuracy', verbose=1, n_jobs=-1)
    grid_search.fit(X_train, y_train)
    
    # Show Best Parameters
    print(f"Best Parameters for {model_name}:")
    print(grid_search.best_params_)
    print(f"Best Cross-validation Accuracy for {model_name}: {grid_search.best_score_:.4f}")
    
    # Prediction with optimal model
    best_model = grid_search.best_estimator_
    y_pred = best_model.predict(X_test)
    test_accuracy = accuracy_score(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    
    # Store ersults in the dictionary
    results[model_name] = {
        'accuracy' : test_accuracy,
        'mse' : mse
    }
    
    # Assesment score present
    print(f"\nTest Accuracy for {model_name}: {test_accuracy:.4f}")
    print("Classification Report:")
    print(classification_report(y_test, y_pred))
    print("---------------------------------------")

# Accuracy 
print("\nTest Accuracy Results:")
for model_name, metrics in results.items():
    print(f"{model_name} Accuracy : {metrics['accuracy']: .4f}, MSE : {metrics['mse']: .2f}")
# Out:
# Training RandomForest...
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# Best Parameters for RandomForest:
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 100}
# Best Cross-validation Accuracy for RandomForest: 0.9518
#
# Test Accuracy for RandomForest: 0.9722
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       105
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.97       108
#    macro avg       0.49      0.50      0.49       108
# weighted avg       0.95      0.97      0.96       108
#
# ---------------------------------------
# Training GradientBoosting...
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# Best Parameters for GradientBoosting:
# {'learning_rate': 0.1, 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Best Cross-validation Accuracy for GradientBoosting: 0.9518
#
# Test Accuracy for GradientBoosting: 0.9722
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       105
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.97       108
#    macro avg       0.49      0.50      0.49       108
# weighted avg       0.95      0.97      0.96       108
#
# ---------------------------------------
# Training SVM...
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# Best Parameters for SVM:
# {'C': 0.1, 'gamma': 'scale', 'kernel': 'rbf'}
# Best Cross-validation Accuracy for SVM: 0.9438
#
# Test Accuracy for SVM: 0.9722
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       105
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.97       108
#    macro avg       0.49      0.50      0.49       108
# weighted avg       0.95      0.97      0.96       108
#
# ---------------------------------------
# Training LogisticRegression...
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best Parameters for LogisticRegression:
# {'C': 10, 'penalty': 'l2'}
# Best Cross-validation Accuracy for LogisticRegression: 0.9276
#
# Test Accuracy for LogisticRegression: 0.9259
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96       105
#            1       0.22      0.67      0.33         3
#
#     accuracy                           0.93       108
#    macro avg       0.61      0.80      0.65       108
# weighted avg       0.97      0.93      0.94       108
#
# ---------------------------------------
# Training SGDClassifier...
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# Best Parameters for SGDClassifier:
# {'alpha': 0.1, 'penalty': 'l1'}
# Best Cross-validation Accuracy for SGDClassifier: 0.9155
#
# Test Accuracy for SGDClassifier: 0.7130
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.71      0.83       105
#            1       0.06      0.67      0.11         3
#
#     accuracy                           0.71       108
#    macro avg       0.52      0.69      0.47       108
# weighted avg       0.96      0.71      0.81       108
#
# ---------------------------------------
# Training KNeighbors...
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Best Parameters for KNeighbors:
# {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'distance'}
# Best Cross-validation Accuracy for KNeighbors: 0.9478
#
# Test Accuracy for KNeighbors: 0.9722
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       105
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.97       108
#    macro avg       0.49      0.50      0.49       108
# weighted avg       0.95      0.97      0.96       108
#
# ---------------------------------------
# Training GaussianNB...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Best Parameters for GaussianNB:
# {}
# Best Cross-validation Accuracy for GaussianNB: 0.8837
#
# Test Accuracy for GaussianNB: 0.9167
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96       105
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.92       108
#    macro avg       0.49      0.47      0.48       108
# weighted avg       0.94      0.92      0.93       108
#
# ---------------------------------------
# Training DecisionTree...
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Best Parameters for DecisionTree:
# {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# Best Cross-validation Accuracy for DecisionTree: 0.9078
#
# Test Accuracy for DecisionTree: 0.9537
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       105
#            1       0.25      0.33      0.29         3
#
#     accuracy                           0.95       108
#    macro avg       0.62      0.65      0.63       108
# weighted avg       0.96      0.95      0.96       108
#
# ---------------------------------------
#
# Test Accuracy Results:
# RandomForest Accuracy :  0.9722, MSE :  0.03
# GradientBoosting Accuracy :  0.9722, MSE :  0.03
# SVM Accuracy :  0.9722, MSE :  0.03
# LogisticRegression Accuracy :  0.9259, MSE :  0.07
# SGDClassifier Accuracy :  0.7130, MSE :  0.29
# KNeighbors Accuracy :  0.9722, MSE :  0.03
# GaussianNB Accuracy :  0.9167, MSE :  0.08
# DecisionTree Accuracy :  0.9537, MSE :  0.05

# %% [markdown]
# ## Oversampling(o) / Model Weights (x)

# %%
# Models Dictionary
models = {
    'RandomForest': RandomForestClassifier(random_state=42),
    'GradientBoosting': GradientBoostingClassifier(random_state=42),
    'SVM': SVC(random_state=42),
    'LogisticRegression': LogisticRegression(random_state=42),
    'SGDClassifier': SGDClassifier(random_state=42),
    'KNeighbors': KNeighborsClassifier(),
    'GaussianNB': GaussianNB(),
    'DecisionTree': DecisionTreeClassifier(random_state=42)
}

# models parameters setting
param_grids = {
    'RandomForest': {
        'n_estimators': [50, 100, 200],
        'max_depth': [None, 10, 20, 30],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4],
        'max_features': ['auto', 'sqrt', 'log2']
    },
    'GradientBoosting': {
        'n_estimators': [50, 100, 200],
        'learning_rate': [0.1, 0.05, 0.01],
        'max_depth': [3, 5, 10],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4],
        'max_features': ['auto', 'sqrt', 'log2']
    },
    'SVM': {
        'C': [0.1, 1, 10],
        'gamma': ['scale', 'auto'],
        'kernel': ['linear', 'rbf', 'poly']
    },
    'LogisticRegression': {
        'C': [0.1, 1, 10],
        'penalty': ['l1','l2']
    },
    'SGDClassifier': {
        'alpha': [0.0001, 0.001, 0.01, 0.1],
        'penalty': ['l1', 'l2']
    },
    'KNeighbors': {
        'n_neighbors': [3, 5, 10],
        'weights': ['uniform', 'distance'],
        'metric': ['euclidean', 'manhattan']
    },
    'GaussianNB': {}, 
    'DecisionTree': {
        'max_depth': [None, 10, 20, 30],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4],
        'max_features': ['auto', 'sqrt', 'log2']
    }
}

# Best Parameter searching
results = {}

for model_name, model in models.items():
    print(f"Training {model_name}...")
    grid_search = GridSearchCV(estimator=model, param_grid=param_grids[model_name], cv=5, scoring='accuracy', verbose=1, n_jobs=-1)
    grid_search.fit(X_train_s, y_train_s)
    
    # Show Best Parameters
    print(f"Best Parameters for {model_name}:")
    print(grid_search.best_params_)
    print(f"Best Cross-validation Accuracy for {model_name}: {grid_search.best_score_:.4f}")
    
    # Prediction with optimal model
    best_model = grid_search.best_estimator_
    y_pred = best_model.predict(X_test)
    test_accuracy = accuracy_score(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    
    # Store ersults in the dictionary
    results[model_name] = {
        'accuracy' : test_accuracy,
        'mse' : mse
    }
    
    # Assesment score present
    print(f"\nTest Accuracy for {model_name}: {test_accuracy:.4f}")
    print("Classification Report:")
    print(classification_report(y_test, y_pred))
    print("---------------------------------------")

# Accuracy 
print("\nTest Accuracy Results:")
for model_name, metrics in results.items():
    print(f"{model_name} Accuracy : {metrics['accuracy']: .4f}, MSE : {metrics['mse']: .2f}")
# Out:
# Training RandomForest...
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# Best Parameters for RandomForest:
# {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# Best Cross-validation Accuracy for RandomForest: 0.9957
#
# Test Accuracy for RandomForest: 0.9537
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98       105
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.95       108
#    macro avg       0.49      0.49      0.49       108
# weighted avg       0.94      0.95      0.95       108
#
# ---------------------------------------
# Training GradientBoosting...
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# Best Parameters for GradientBoosting:
# {'learning_rate': 0.1, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 50}
# Best Cross-validation Accuracy for GradientBoosting: 1.0000
#
# Test Accuracy for GradientBoosting: 0.9537
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98       105
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.95       108
#    macro avg       0.49      0.49      0.49       108
# weighted avg       0.94      0.95      0.95       108
#
# ---------------------------------------
# Training SVM...
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# Best Parameters for SVM:
# {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
# Best Cross-validation Accuracy for SVM: 0.9851
#
# Test Accuracy for SVM: 0.9352
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.97       105
#            1       0.17      0.33      0.22         3
#
#     accuracy                           0.94       108
#    macro avg       0.57      0.64      0.59       108
# weighted avg       0.96      0.94      0.95       108
#
# ---------------------------------------
# Training LogisticRegression...
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best Parameters for LogisticRegression:
# {'C': 10, 'penalty': 'l2'}
# Best Cross-validation Accuracy for LogisticRegression: 0.9787
#
# Test Accuracy for LogisticRegression: 0.9259
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96       105
#            1       0.22      0.67      0.33         3
#
#     accuracy                           0.93       108
#    macro avg       0.61      0.80      0.65       108
# weighted avg       0.97      0.93      0.94       108
#
# ---------------------------------------
# Training SGDClassifier...
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# Best Parameters for SGDClassifier:
# {'alpha': 0.0001, 'penalty': 'l1'}
# Best Cross-validation Accuracy for SGDClassifier: 0.9660
#
# Test Accuracy for SGDClassifier: 0.9167
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.92      0.96       105
#            1       0.20      0.67      0.31         3
#
#     accuracy                           0.92       108
#    macro avg       0.59      0.80      0.63       108
# weighted avg       0.97      0.92      0.94       108
#
# ---------------------------------------
# Training KNeighbors...
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Best Parameters for KNeighbors:
# {'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}
# Best Cross-validation Accuracy for KNeighbors: 0.8957
#
# Test Accuracy for KNeighbors: 0.7593
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.77      0.86       105
#            1       0.04      0.33      0.07         3
#
#     accuracy                           0.76       108
#    macro avg       0.51      0.55      0.47       108
# weighted avg       0.95      0.76      0.84       108
#
# ---------------------------------------
# Training GaussianNB...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Best Parameters for GaussianNB:
# {}
# Best Cross-validation Accuracy for GaussianNB: 0.6957
#
# Test Accuracy for GaussianNB: 0.6574
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.66      0.79       105
#            1       0.05      0.67      0.10         3
#
#     accuracy                           0.66       108
#    macro avg       0.52      0.66      0.44       108
# weighted avg       0.96      0.66      0.77       108
#
# ---------------------------------------
# Training DecisionTree...
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Best Parameters for DecisionTree:
# {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# Best Cross-validation Accuracy for DecisionTree: 0.9298
#
# Test Accuracy for DecisionTree: 0.9074
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.92      0.95       105
#            1       0.11      0.33      0.17         3
#
#     accuracy                           0.91       108
#    macro avg       0.55      0.63      0.56       108
# weighted avg       0.96      0.91      0.93       108
#
# ---------------------------------------
#
# Test Accuracy Results:
# RandomForest Accuracy :  0.9537, MSE :  0.05
# GradientBoosting Accuracy :  0.9537, MSE :  0.05
# SVM Accuracy :  0.9352, MSE :  0.06
# LogisticRegression Accuracy :  0.9259, MSE :  0.07
# SGDClassifier Accuracy :  0.9167, MSE :  0.08
# KNeighbors Accuracy :  0.7593, MSE :  0.24
# GaussianNB Accuracy :  0.6574, MSE :  0.34
# DecisionTree Accuracy :  0.9074, MSE :  0.09

# %% [markdown]
# # 5. Deep Learning Model Formation & Check Accuracy

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks

# %%
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam

# Setting same seed number
tf.random.set_seed(42)


# Compute sample weights
class_weights_dict = {0: 1, 1: 7}
sample_weights = compute_sample_weight(class_weight = class_weights_dict, y = y_train_s)

# Optimizer
optimizer = Adam(learning_rate=0.001)

# Model define
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape = (X_train.shape[1],)),
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(16, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

# Model Compile
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Model Summary
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_5 (Dense)                 │ (None, 128)            │        94,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 105,217 (411.00 KB)
#  Trainable params: 105,217 (411.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Oversampling(o) / Sample Weights(o)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# Early Stopping 
early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=20)

# Best model save
checkpoint_callback = ModelCheckpoint('best_model.keras', monitor='val_accuracy', save_best_only=True, mode='max')

tf.random.set_seed(42)
# Model FIT
history = model.fit(X_train_s, y_train_s,
                    epochs=100, 
                    batch_size=32, 
                    validation_data=(X_test, y_test), 
                    callbacks=[early_stopping, checkpoint_callback],
                    sample_weight=sample_weights)
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5807 - loss: 2.1557 - val_accuracy: 0.5463 - val_loss: 1.0916
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7378 - loss: 0.9735 - val_accuracy: 0.7037 - val_loss: 0.8370
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8295 - loss: 0.7173 - val_accuracy: 0.7778 - val_loss: 0.4861
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9067 - loss: 0.4208 - val_accuracy: 0.7870 - val_loss: 0.5454
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9084 - loss: 0.3376 - val_accuracy: 0.8889 - val_loss: 0.3344
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9460 - loss: 0.2600 - val_accuracy: 0.8981 - val_loss: 0.2519
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9502 - loss: 0.2814 - val_accuracy: 0.8704 - val_loss: 0.3636
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9743 - loss: 0.1483 - val_accuracy: 0.8426 - val_loss: 0.6117
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9544 - loss: 0.1670 - val_accuracy: 0.9074 - val_loss: 0.3443
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9714 - loss: 0.1006 - val_accuracy: 0.9074 - val_loss: 0.3314
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9779 - loss: 0.0859 - val_accuracy: 0.9167 - val_loss: 0.3248
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9735 - loss: 0.1282 - val_accuracy: 0.9167 - val_loss: 0.3730
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9802 - loss: 0.0612 - val_accuracy: 0.9074 - val_loss: 0.3880
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0612 - val_accuracy: 0.8519 - val_loss: 0.8199
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9766 - loss: 0.1240 - val_accuracy: 0.9259 - val_loss: 0.3943
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9861 - loss: 0.0806 - val_accuracy: 0.9074 - val_loss: 0.3753
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9538 - loss: 0.1956 - val_accuracy: 0.8981 - val_loss: 0.4085
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9575 - loss: 0.1786 - val_accuracy: 0.8611 - val_loss: 0.4506
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9747 - loss: 0.0898 - val_accuracy: 0.9074 - val_loss: 0.3886
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9810 - loss: 0.0702 - val_accuracy: 0.9167 - val_loss: 0.3798
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9761 - loss: 0.0954 - val_accuracy: 0.9444 - val_loss: 0.2722
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9841 - loss: 0.0648 - val_accuracy: 0.9259 - val_loss: 0.3111
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9873 - loss: 0.0534 - val_accuracy: 0.8796 - val_loss: 0.6252
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9787 - loss: 0.0629 - val_accuracy: 0.9259 - val_loss: 0.3477
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9838 - loss: 0.0877 - val_accuracy: 0.9167 - val_loss: 0.4182
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9982 - loss: 0.0258 - val_accuracy: 0.9259 - val_loss: 0.4066

# %% [markdown]
# ## Oversampling(x) / Sample Weights (o)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint


# Compute sample weights
class_weights_dict = {0: 3, 1: 10}
sample_weights = compute_sample_weight(class_weight = class_weights_dict, y = y_train)
# Early Stopping 
early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=20)

# Best model save
checkpoint_callback = ModelCheckpoint('best_model.keras', monitor='val_accuracy', save_best_only=True, mode='max')

tf.random.set_seed(42)
# Model FIT
history = model.fit(X_train, y_train,
                    epochs=100, 
                    batch_size=32, 
                    validation_data=(X_test, y_test), 
                    callbacks=[early_stopping, checkpoint_callback],
                    sample_weight=sample_weights)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9973 - loss: 0.0614 - val_accuracy: 0.9259 - val_loss: 0.4073
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9951 - loss: 0.3655 - val_accuracy: 0.9074 - val_loss: 0.4555
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9753 - loss: 0.2147 - val_accuracy: 0.9352 - val_loss: 0.3456
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9903 - loss: 0.1272 - val_accuracy: 0.9352 - val_loss: 0.3557
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9980 - loss: 0.0657 - val_accuracy: 0.9259 - val_loss: 0.3938
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9909 - loss: 0.0981 - val_accuracy: 0.9352 - val_loss: 0.4149
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9924 - loss: 0.0936 - val_accuracy: 0.9259 - val_loss: 0.4509
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9954 - loss: 0.0999 - val_accuracy: 0.9352 - val_loss: 0.4463
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0354 - val_accuracy: 0.9444 - val_loss: 0.4624
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9938 - loss: 0.0710 - val_accuracy: 0.9259 - val_loss: 0.4862
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9889 - loss: 0.0711 - val_accuracy: 0.9259 - val_loss: 0.4815
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9909 - loss: 0.0410 - val_accuracy: 0.9444 - val_loss: 0.4575
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9973 - loss: 0.0305 - val_accuracy: 0.9444 - val_loss: 0.4616
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9938 - loss: 0.0536 - val_accuracy: 0.9167 - val_loss: 0.5815
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9863 - loss: 0.1598 - val_accuracy: 0.9444 - val_loss: 0.5091
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9938 - loss: 0.2401 - val_accuracy: 0.9259 - val_loss: 0.5074
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9863 - loss: 0.0759 - val_accuracy: 0.9259 - val_loss: 0.5101
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9862 - loss: 0.0904 - val_accuracy: 0.9444 - val_loss: 0.4740
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0287 - val_accuracy: 0.9444 - val_loss: 0.5001
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9947 - loss: 0.0420 - val_accuracy: 0.9259 - val_loss: 0.4836
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9909 - loss: 0.0922 - val_accuracy: 0.9537 - val_loss: 0.3412
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9953 - loss: 1.0646 - val_accuracy: 0.9167 - val_loss: 0.4059
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9925 - loss: 0.0760 - val_accuracy: 0.9259 - val_loss: 0.4459
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9945 - loss: 0.0792 - val_accuracy: 0.9074 - val_loss: 0.4565
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9863 - loss: 0.2260 - val_accuracy: 0.9352 - val_loss: 0.4359
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9936 - loss: 0.1321 - val_accuracy: 0.9352 - val_loss: 0.5291
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9973 - loss: 0.0467 - val_accuracy: 0.9444 - val_loss: 0.3868
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9712 - loss: 0.2037 - val_accuracy: 0.8889 - val_loss: 0.7316
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9630 - loss: 0.3144 - val_accuracy: 0.9352 - val_loss: 0.5177
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9929 - loss: 0.1213 - val_accuracy: 0.9259 - val_loss: 0.5825
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9863 - loss: 0.0868 - val_accuracy: 0.8889 - val_loss: 0.5480
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9909 - loss: 0.0780 - val_accuracy: 0.9074 - val_loss: 0.5693
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0443 - val_accuracy: 0.9167 - val_loss: 0.5829
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9938 - loss: 0.1062 - val_accuracy: 0.9074 - val_loss: 0.6024
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9909 - loss: 0.0372 - val_accuracy: 0.9259 - val_loss: 0.5738
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9973 - loss: 0.0163 - val_accuracy: 0.9259 - val_loss: 0.5601
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9965 - loss: 0.0809 - val_accuracy: 0.9167 - val_loss: 0.5751
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9973 - loss: 0.0306 - val_accuracy: 0.9259 - val_loss: 0.5554
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9973 - loss: 0.0241 - val_accuracy: 0.9352 - val_loss: 0.5427
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0180 - val_accuracy: 0.9259 - val_loss: 0.5555
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9965 - loss: 0.0391 - val_accuracy: 0.8981 - val_loss: 0.5984

# %% [markdown]
# ## Oversampling(o) / Sample Weights(x)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# Early Stopping 
early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=20)

# Best model save
checkpoint_callback = ModelCheckpoint('best_model.keras', monitor='val_accuracy', save_best_only=True, mode='max')

tf.random.set_seed(42)
# Model FIT
history = model.fit(X_train_s, y_train_s,
                    epochs=100, 
                    batch_size=32, 
                    validation_data=(X_test, y_test), 
                    callbacks=[early_stopping, checkpoint_callback])
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 3.3430e-04 - val_accuracy: 0.8981 - val_loss: 0.9281
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.0918e-04 - val_accuracy: 0.8981 - val_loss: 0.9319
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 7.9747e-04 - val_accuracy: 0.8981 - val_loss: 0.9366
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 6.1148e-04 - val_accuracy: 0.8981 - val_loss: 0.9389
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 7.3659e-04 - val_accuracy: 0.8981 - val_loss: 0.9420
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.6039e-04 - val_accuracy: 0.8981 - val_loss: 0.9445
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.8128e-04 - val_accuracy: 0.8981 - val_loss: 0.9456
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.6103e-04 - val_accuracy: 0.8981 - val_loss: 0.9449
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 9.8263e-04 - val_accuracy: 0.8981 - val_loss: 0.9385
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.8981 - val_loss: 0.9354
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.5779e-04 - val_accuracy: 0.8981 - val_loss: 0.9402
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 7.4918e-04 - val_accuracy: 0.8981 - val_loss: 0.9472
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.9287e-04 - val_accuracy: 0.8981 - val_loss: 0.9505
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 5.3549e-04 - val_accuracy: 0.8981 - val_loss: 0.9557
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.5346e-04 - val_accuracy: 0.8981 - val_loss: 0.9601
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.0204e-04 - val_accuracy: 0.8981 - val_loss: 0.9649
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.8335e-04 - val_accuracy: 0.8981 - val_loss: 0.9711
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.5808e-04 - val_accuracy: 0.8981 - val_loss: 0.9791
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 7.7892e-04 - val_accuracy: 0.8981 - val_loss: 0.9934
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 9.5792e-04 - val_accuracy: 0.8981 - val_loss: 1.0019
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.4729e-04 - val_accuracy: 0.8981 - val_loss: 1.0015

# %% [markdown]
# ## Deep Learning Model Results

# %%
# Save Best Model
best_model = keras.models.load_model('best_model.keras')

# Test data evaluation
test_loss, test_accuracy = best_model.evaluate(X_test, y_test)

print(f'Test Accuracy of the Best Model: {test_accuracy:.4f}')
print(f'Test loss of the Best Model : {test_loss: .4f}')

# Assesment scores
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs = range(1, len(train_loss) + 1)

# plotting
plt.figure(figsize=(12, 6))

# Loss plot
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, 'bo-', label='Training loss')
plt.plot(epochs, val_loss, 'ro-', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Accuracy plot
plt.subplot(1, 2, 2)
plt.plot(epochs, train_acc, 'bo-', label='Training accuracy')
plt.plot(epochs, val_acc, 'ro-', label='Validation accuracy')
plt.axhline(y=test_accuracy, color='g', linestyle='--', label='Test Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.savefig('Deep learning results.png')
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9020 - loss: 0.7710
# Test Accuracy of the Best Model: 0.8981
# Test loss of the Best Model :  0.9281

# %%
# Confusion Matirx & ROC Curve
from sklearn.metrics import confusion_matrix, roc_curve, auc
import seaborn as sns

# Load Best Model
best_model = keras.models.load_model('best_model.keras')

# Confusion Matrix
y_pred = best_model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)

conf_matrix = confusion_matrix(y_test, y_pred_classes)


# Annotation 
group_names = ['TN', 'FP (label 0 error)', 'FN (label 1 error)', 'TP']
group_counts = [value for value in conf_matrix.flatten()]
labels = [f'{v1}\n{v2}' for v1, v2 in zip(group_names, group_counts)]
labels = np.asarray(labels).reshape(2,2)

plt.figure(figsize = (6,6))
sns.heatmap(conf_matrix, annot = labels, fmt = '', cbar = False, color = 'Blue')
plt.title('Confusion Matrix', fontsize = 16)
plt.xlabel('Predicted Label', fontsize = 14)
plt.ylabel('True Label', fontsize = 14)
plt.tight_layout()
plt.savefig('Confusion Matrix.png', dpi = 300)
plt.show()


fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)


plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.legend(loc='lower right', fontsize=12)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16)
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.tight_layout()
plt.savefig('ROC_Curve.png', dpi=300)
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       105
#            1       1.00      0.33      0.50         3
#
#     accuracy                           0.98       108
#    macro avg       0.99      0.67      0.75       108
# weighted avg       0.98      0.98      0.98       108

# %% [markdown]
# # 6. Prediction with validation dataset

# %%
# Load Validation Data
x_val_df = pd.read_csv('x_val_df.csv')
x_val_df = x_val_df.iloc[:, 1:]
x_val_df
# Out:
#        Cells_AreaShape_Compactness  Cells_AreaShape_Eccentricity  \
# 0                         0.001517                      0.277820
# 1                         0.034036                      0.090993
# 2                        -0.418352                     -0.452332
# 3                        -0.302987                     -0.107649
# 4                         1.015297                      0.971762
# ...                            ...                           ...
# 30612                    -0.265613                     -0.433268
# 30613                    -0.210157                     -0.305976
# 30614                     0.597644                      0.486508
# 30615                     0.806925                      0.851465
# 30616                    -0.167642                     -0.352726
#
#        Cells_AreaShape_Extent  Cells_AreaShape_Orientation  \
# 0                    0.504330                     0.872770
# 1                    0.306434                     0.485507
# 2                    0.874477                    -0.128444
# 3                    0.926159                     0.397246
# 4                   -0.344257                     0.236280
# ...                       ...                          ...
# 30612                0.493264                    -0.545809
# 30613                0.503456                    -0.028201
# 30614               -0.388333                    -0.393189
# 30615               -0.373886                     0.048235
# 30616                0.175404                     0.006627
#
#        Cells_AreaShape_Zernike_0_0  Cells_AreaShape_Zernike_1_1  \
# 0                        -0.062229                    -0.097463
# 1                         0.052555                    -0.031708
# 2                         0.677804                     0.464805
# 3                         0.287252                    -0.666721
# 4                        -0.908705                     0.246192
# ...                            ...                          ...
# 30612                     0.505944                    -0.235360
# 30613                     0.453887                     0.195480
# 30614                    -0.434949                     0.348865
# 30615                    -0.452466                    -0.217211
# 30616                     0.245803                     0.200575
#
#        Cells_AreaShape_Zernike_2_0  Cells_AreaShape_Zernike_2_2  \
# 0                        -0.136418                     1.363021
# 1                        -0.116941                     0.108810
# 2                         0.139284                     0.689670
# 3                         0.485750                     0.286509
# 4                        -1.322807                     0.577879
# ...                            ...                          ...
# 30612                     0.530636                     0.305867
# 30613                     0.276551                     0.262468
# 30614                    -0.739404                    -0.280500
# 30615                    -0.818209                     0.555877
# 30616                     0.140865                    -0.090486
#
#        Cells_AreaShape_Zernike_3_3  Cells_AreaShape_Zernike_4_0  ...  \
# 0                        -0.121675                     0.111071  ...
# 1                        -0.257286                     0.182884  ...
# 2                         0.092896                    -0.396120  ...
# 3                        -0.249060                     0.851031  ...
# 4                        -0.200651                     0.544807  ...
# ...                            ...                          ...  ...
# 30612                    -0.243942                    -0.247084  ...
# 30613                     0.886899                    -0.258701  ...
# 30614                     0.231109                    -0.160809  ...
# 30615                     0.007761                     0.535272  ...
# 30616                     0.222532                    -0.230299  ...
#
#        Nuclei_Texture_SumEntropy_DNA_5_0  Nuclei_Texture_SumEntropy_ER_5_0  \
# 0                               0.012441                         -0.515965
# 1                               0.148373                         -0.708293
# 2                               1.174464                          1.873223
# 3                               0.402387                         -0.358765
# 4                               1.195175                         -0.566205
# ...                                  ...                               ...
# 30612                          -0.166256                         -0.606686
# 30613                          -0.326757                         -0.692443
# 30614                           0.281298                         -0.558976
# 30615                           0.762975                         -1.044746
# 30616                           0.167862                          0.177851
#
#        Nuclei_Texture_SumEntropy_Mito_5_0  Nuclei_Texture_SumEntropy_RNA_5_0  \
# 0                               -0.125886                           0.378361
# 1                               -0.168461                           0.159921
# 2                                0.559107                           1.438213
# 3                               -0.296739                           0.925500
# 4                               -0.462147                           0.560941
# ...                                   ...                                ...
# 30612                           -1.410230                          -1.127026
# 30613                           -1.197271                          -1.103457
# 30614                           -0.394671                          -0.123102
# 30615                           -0.611885                           0.340107
# 30616                            0.061965                           0.170837
#
#        Nuclei_Texture_SumVariance_AGP_5_0  \
# 0                               -0.192612
# 1                                0.005949
# 2                                1.659821
# 3                               -0.294972
# 4                               -0.435885
# ...                                   ...
# 30612                           -0.063554
# 30613                            0.064433
# 30614                           -0.271379
# 30615                           -0.832198
# 30616                            0.388981
#
#        Nuclei_Texture_SumVariance_DNA_10_0  \
# 0                                 0.263924
# 1                                 0.278903
# 2                                 1.049936
# 3                                 0.741252
# 4                                 1.580252
# ...                                    ...
# 30612                            -0.134207
# 30613                            -0.189828
# 30614                             0.429285
# 30615                             0.986590
# 30616                             0.166736
#
#        Nuclei_Texture_SumVariance_DNA_5_0  Nuclei_Texture_Variance_AGP_5_0  \
# 0                                0.134799                        -0.065563
# 1                                0.181974                         0.119256
# 2                                1.254289                         0.822218
# 3                                0.544289                        -0.375331
# 4                                1.477814                        -0.779816
# ...                                   ...                              ...
# 30612                           -0.174389                         0.904218
# 30613                           -0.262928                         0.950440
# 30614                            0.213798                        -0.222311
# 30615                            0.869581                        -1.017756
# 30616                            0.203871                         0.266327
#
#        Nuclei_Texture_Variance_DNA_10_0  Nuclei_Texture_Variance_DNA_5_0
# 0                              0.159910                         0.150347
# 1                              0.289176                         0.263372
# 2                              1.143912                         1.200041
# 3                              0.497514                         0.527436
# 4                              1.448586                         1.502258
# ...                                 ...                              ...
# 30612                         -0.093846                        -0.130101
# 30613                         -0.374726                        -0.343942
# 30614                          0.061249                         0.132184
# 30615                          0.612146                         0.618390
# 30616                          0.153103                         0.187355
#
# [30617 rows x 736 columns]

# %%
# Validation metadata
x_val_meta = pd.read_csv('x_val_meta.csv')
x_val_meta = x_val_meta.iloc[:, 1:]

# %%
# Validation
y_pred_prob = best_model.predict(x_val_df)

# prediction rate cutoff x > 0.5 : 1
y_pred = (y_pred_prob > 0.5).astype(int)
# Out:
# 957/957 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step

# %%
# Check location of DNA Damage High Labeld Data
hit_comp = np.flatnonzero(y_pred != 0)

# %%
comp_name = []
for idx in hit_comp:
    value = x_val_meta.loc[idx, 'Metadata_broad_sample']
    name = chem_dat[chem_dat['BROAD_ID'] == value]['CPD_NAME'].tolist()
    comp_name.append(name)


# Remove DMSO
comp_name = [v for v in comp_name if v]

comp_name = [item for sublist in comp_name for item in sublist]

print(len(set(comp_name)))
print(display(comp_name))
# Out:
# 2160
# ['GYKI-52466',
#  '3-BROMO-7-NITROINDAZOLE',
#  'skimmianine',
#  'quinpirole',
#  'Ici 185282',
#  '1-Naphthyl PP1',
#  'clomifene',
#  "N-[3-(2-dimethylamino) ethoxy-4-methoxyphenyl]-2'-methyl-4'-(5-methyl-1,2,4-oxadiazol-3-yl)-(1,1'-biphenyl)-4-carboxamide) and BRL-15572 3-[4-(3-chlorophenyl) piperazin-1-yl]-1,1-diphenyl-2-propanol",
#  'DCEBIO',
#  'tilorone',
#  'ABT-702',
#  'FPL-64176',
#  'estrone',
#  'obliquin',
#  'doxorubicin',
#  'mammea A/BA',
#  'BMS-191011',
#  'scopoletin',
#  'methanandamide',
#  'R(+)-SKF-81297',
#  'Beta CCP',
#  'RS 102221',
#  'RS 504393',
#  'EMD 41000',
#  '3-hydroxycoumarin',
#  '5-carboxamidotryptamine',
#  '2-CHLORO-11-(4-METHYLPIPERAZINO)DIBENZ[B,F]OXEPIN',
#  'mevastatin',
#  'BMS-191011',
#  'PP2',
#  'citropten',
#  'Boc-GVV-CHO',
#  'tolmetin',
#  'GR 135531',
#  'L-693,403',
#  'strophanthidin',
#  'RS 79948',
#  '2-[1-(4-PIPERONYL)PIPERAZINYL]BENZOTHIAZOLE',
#  'ronidazole',
#  'MAZ51',
#  'trapidil',
#  'resveratrol',
#  'herniarin',
#  'EMD 66684',
#  'alverine',
#  'trifluoperazine',
#  '1,5-isoquinolinediol',
#  '2-CHLORO-11-(4-METHYLPIPERAZINO)DIBENZ[B,F]OXEPIN',
#  'paeonol',
#  'Y 134',
#  'BMS-191011',
#  'quercetin',
#  'deoxyandirobin',
#  'ICI-89406',
#  'procaterol',
#  'homochlorcyclizine',
#  'cantharidin',
#  'homatropine methylbromide',
#  'CGP 52432',
#  '(+/-)-abscisic acid',
#  '7-hydroxy-2-N,N-dipropylaminotetralin',
#  'tolperisone',
#  'BRL 52537',
#  'OMDM-2',
#  'estradiol valerate',
#  'sulmazole',
#  'pencillic acid',
#  'pentobarbital',
#  'bergenin',
#  'U-46619',
#  '2-[5-[3-(4-methylsulphonylamino)benzyl-1,2,4-oxadiazol-5-yl]-1H-indole-3-yl]ethylamine',
#  'neostigmine bromide',
#  'MK-212',
#  'riluzole',
#  'phenamil',
#  '3-deshydroxysappanol trimethyl ether',
#  'chloramphenicol',
#  'dizocilpine',
#  'paraxanthine',
#  '3-acetyl-coumarin',
#  'phenylpropanolamine',
#  'proguanil',
#  'benzydamine',
#  'L-750,667',
#  'hypericin',
#  'BMY-7,378',
#  'devazepide',
#  'CGP 71683',
#  'sulfachlorpyridazine',
#  'lonchocarpic acid',
#  'BML-257',
#  'chelidonine',
#  'sphondin',
#  'A-68930',
#  'ethionamide',
#  'tilorone',
#  'GP 2a',
#  '6-chloromelatonin',
#  'SU1498',
#  'ceforanide',
#  'bumetanide',
#  'farnesylcysteine methyl ester',
#  'amthamine',
#  'doconexent',
#  'bisacodyl',
#  'baeomycesic acid',
#  '2-[(4-Phenylpiperazin-1-yl)methyl]-2,3-dihydroimidazo[1,2-c]quinazolin-5(6H)-one',
#  'cilnidipine',
#  'dihydro-obliquin',
#  'SB-205607',
#  'wortmannin',
#  'AM 92016 hydrochloride',
#  '1,7-dideacetoxy-1,7-dioxo-3-deacetylkhivorin',
#  'mesoridazine',
#  'BMY-14802',
#  'BADGE',
#  'brefeldin A',
#  'ondansetron',
#  'clindamycin',
#  'estradiol',
#  'thiamylal',
#  'CGP 361A',
#  'tolperisone',
#  'nomifensine',
#  'LFM-A13',
#  'oleanoic acid',
#  'aceclidine',
#  'BRL 52537',
#  'oleanolic acid acetate',
#  'practolol',
#  'naloxone',
#  'reboxetine',
#  'LFM-A12',
#  'proglumide',
#  'meptazinol',
#  'dihydrodeoxygedunin',
#  'chlorphenamine',
#  'tridesacetoxykhivorin',
#  'dichlorobenzimidazole riboside',
#  '8-M-PDOT',
#  'verapamil',
#  'SKF 81297',
#  'telithromycin',
#  'idazoxan',
#  'ondansetron',
#  'atenolol',
#  'procaterol',
#  'vinblastine sulfate',
#  'pheniramine',
#  'taxol',
#  'F-met-leu-phe',
#  '2-Hydroxysaclofen',
#  'trichlormethiazide',
#  'canrenoic acid',
#  'diperodon',
#  'SDZ WAG 994',
#  '3-amino-beta-pinene',
#  'timolol',
#  'oxfendazole',
#  'metixene',
#  'anabasamine',
#  'BRL 52537',
#  'anthothecol',
#  'epibatidine',
#  'cantharidin',
#  'LFM-A12',
#  'boldine',
#  'crustecdysone',
#  '2-methoxyestradiol',
#  'salsoline',
#  'meclozine',
#  'yohimbine hydrochloride',
#  'gallopamil',
#  'KF 38789',
#  '(-)-terreic acid',
#  'DIHYDROERGOCRISTINE',
#  '2-methoxyidazoxan',
#  'furaltadone',
#  'azelastine',
#  'BH3I-1',
#  'spiroxatrine',
#  'GW 6471',
#  'S-Trityl-L-cysteine',
#  'U 18666A',
#  'bemesetron',
#  'flurbiprofen',
#  'naproxen',
#  'dihydro-7-desacetyldeoxygedunin',
#  'calyculin A',
#  '8-hydroxy-2-(di-n-propylamino)tetralin',
#  'ajmaline',
#  '16-deoxomexicanolide 16-methyl ether',
#  'IB-MECA',
#  'lansoprazole',
#  'trimeprazine tartrate',
#  'clobenztropine',
#  'tianeptine',
#  'testosterone',
#  'lobelanidine',
#  'bromocriptine',
#  'mirtazapine',
#  'ramipril',
#  'REV-5901',
#  'minocycline',
#  'lufenuron',
#  'glycodesoxycholic acid',
#  'homatropine hydrobromide',
#  'deoxysappanone B trimethyl ether',
#  'salubrinal',
#  'hyoscyamine',
#  'meloxicam',
#  'naproxen',
#  'delcorine',
#  'cilastatin',
#  'isradipine',
#  'scopoline',
#  '17-PA',
#  'NTNCB',
#  'metaxalone',
#  'ethyl 1-benzyl-4,5-dioxopyrrolidine-3-carboxylate',
#  'L-732,138',
#  'metrizamide',
#  '8-hydroxy-2-(di-n-propylamino)tetralin',
#  'PHCCC',
#  'metacycline',
#  'ciprofibrate',
#  'foliosidine',
#  'BRL-15,572',
#  'SKF-83566',
#  'pipenzolate bromide',
#  'pirlindole',
#  '6-oxoprogesterone',
#  'altizide',
#  'tremulacin',
#  'methyl-ergometrine',
#  '5-hydroxyiminoisocaryophyllene',
#  'nemonapride',
#  'REV-5901',
#  'brompheniramine',
#  'eucatropine',
#  'PG-9',
#  'fendiline',
#  'L-stepholidine',
#  '8-hydroxycarapinic acid',
#  'salubrinal',
#  'bendroflumethiazide',
#  'KN-62',
#  'miconazole',
#  '3-beta-acetoxydeoxyangolensic acid methyl ester',
#  'SKF-38393',
#  'sarmentogenin',
#  'mefloquine',
#  'scopoline',
#  'isoconazole',
#  'bifonazole',
#  'bucladesine',
#  'FPL 55712',
#  'crustecdysone',
#  'flumethasone pivalate',
#  'fipronil',
#  'chrysanthemic acid',
#  'IRL-2500',
#  '6-oxoprogesterone',
#  'cytisine',
#  'primaquine',
#  'altizide',
#  'amisulpride',
#  'prednisone',
#  'rimcazole',
#  'mexicanolide',
#  'ATPA',
#  'zacopride',
#  'pheneticillin',
#  'medetomidine',
#  'betamethasone 17,21-dipropionate',
#  'brompheniramine',
#  'diltiazem',
#  'lufenuron',
#  'BH3I-1',
#  'spiroxatrine',
#  'SK&F 96365',
#  'homatropine hydrobromide',
#  'isoxicam',
#  'SDM25N',
#  'SYM 2206',
#  'nefopam',
#  'bromocriptine',
#  'budesonide',
#  'miconazole',
#  'naltrexone',
#  'mephenytoin',
#  'L-655,708',
#  'dehydrorotenone',
#  'bemesetron',
#  'flurbiprofen',
#  '(?)-1-(1,2-Diphenylethyl)piperidine maleate',
#  'tenidap',
#  'cladribine',
#  '5,7-dimethoxyflavanone',
#  'ancitabine',
#  'siguazodan',
#  'SM-21 maleate',
#  'clopidogrel',
#  'bifonazole',
#  'naringenin',
#  'dehydro(11,12)ursolic acid lactone',
#  'dubinidine',
#  'famotidine',
#  'cefoperazone',
#  'minaprine',
#  '7-nitroindazole',
#  'clemizole',
#  'YS-035',
#  'AM-580',
#  'hispidin',
#  'GSK-3b inhibitor VI',
#  'pipemidic acid',
#  'vincristine',
#  '5,7,8-trimethoxy-3-(4-methoxyphenyl)chromen-4-one',
#  'sulfaphenazole',
#  'gemfibrozil',
#  'norfloxacin',
#  'aminophenazone',
#  'carbenoxolone',
#  'valdecoxib',
#  'hydrochlorothiazide',
#  'artemisinin',
#  'bemegride',
#  'BAY 11-7082',
#  'SDZ-205557',
#  'mocetinostat',
#  '2-pyridylethylamine',
#  'hexylcaine',
#  'deltaline',
#  'MT-21',
#  'P1075',
#  'colchicine',
#  'finasteride',
#  '1,3-dipropyl-8-cyclopentylxanthine',
#  'RS-23597-190',
#  'cefotiam',
#  'alochlor',
#  'protein tyrosine phosphatase inhibitor IV',
#  'JX-401',
#  'N-Methylanthranilic acid',
#  'corynanthine',
#  'LE-135',
#  'selinidin',
#  'curcumin',
#  'propanil',
#  'zolantidine',
#  'vincristine',
#  'CDC',
#  'rutilantinone',
#  'ZD 7155',
#  'phenformin',
#  'NBQX',
#  'propranolol',
#  '9,21-dehydroryanodine',
#  'vesamicol',
#  '40 (DMCM)',
#  'bemegride',
#  'apoptosis activator II',
#  'GPR109b Agonist, IBC 293',
#  'PNU-22394',
#  'R(-)-2,10,11-trihydroxy-N-propyl-noraporphine',
#  'estriol',
#  'tyrphostin AG 835',
#  'butein',
#  'esculin',
#  'ticlopidine',
#  'cloxacillin',
#  'parbendazole',
#  'O-2050',
#  'tubocurarine chloride',
#  'celecoxib',
#  'NSC 663284',
#  'tyrphostin AG 82',
#  'ethisterone',
#  'prostaglandin A1',
#  '3-(4-(4-Chlorophenyl-4-hydroxypiperidino)methyl)indole',
#  'HA-1004',
#  '1-(1-naphthyl)piperazine',
#  'N-ArachidonylGABA',
#  'hispidin',
#  'BRD-K08438429',
#  'propanil',
#  'RS 100329',
#  'mibefradil',
#  'benzo(a)pyrene',
#  'N-DESMETHYLCLOZAPINE',
#  'meclofenoxate',
#  'sulfaphenazole',
#  'norfloxacin',
#  'benzbromarone',
#  'harmane',
#  'kaempherol',
#  'L-741,742',
#  'PAPP',
#  'bromocriptine',
#  'sulfathiazole',
#  'harmalol',
#  'cinanserin',
#  'carbonyl cyanide m-chlorophenyl hydrazone',
#  'fluperlapine',
#  'mocetinostat',
#  'diazepam',
#  'JWH-015',
#  '2-pyridylethylamine',
#  'U0126',
#  'ftorpropazine',
#  'ZM-241,385',
#  'mefexamide',
#  'pyrantel',
#  'RS 39604',
#  'benzthiazide',
#  'dioxybenzone',
#  'broxyquinoline',
#  'A-77636',
#  'ML047',
#  '1-(1,3-BENZODIOXOL-5-YLCARBONYL)PIPERIDINE',
#  'euparin',
#  'dinoprostone',
#  'carbacyclin',
#  'lysergol',
#  'apafant',
#  'ichthynone',
#  'ramelteon',
#  'flunarizine',
#  'DMeOB',
#  'cyclic PFT-alpha',
#  'T-0070907',
#  'tolazamide',
#  'vanoxerine',
#  'DCEBIO',
#  'prometryn',
#  '5-CT,DP',
#  'AG-370',
#  '6-chloromelatonin',
#  'denbufylline',
#  'phenacetin',
#  'bergenin',
#  'H-8',
#  'U0126',
#  'megestrol acetate',
#  'MK-212',
#  'dihomo-gamma-linolenic acid',
#  'phenamil',
#  'chloramphenicol',
#  'nilutamide',
#  'lavendustin A',
#  'GYKI-52466',
#  'deoxycorticosterone acetate',
#  'pirenperone',
#  'NS3694',
#  'butamben',
#  'lysergol',
#  'cilostamide',
#  'zuclopenthixol',
#  'clemastine',
#  'DMeOB',
#  'alpha-linolenic acid',
#  'ethionamide',
#  'GW 3965',
#  'cicloheximide',
#  'WAY 170523',
#  'hydroflumethiazide',
#  'astemizole',
#  'domperidone',
#  '8-cyclopentyl-1,3-dimethylxanthine',
#  '4-chlorophenylguanidine',
#  'ritanserin',
#  'cinanserin',
#  'sulfapyridine',
#  'coumafos',
#  'cyclobenzaprine',
#  'EO-1428',
#  'W-13',
#  'valsartan',
#  'proadifen',
#  'pramocaine',
#  'diphenhydramine',
#  'methapyrilene',
#  'dipyrocetyl',
#  'evoxine',
#  'duartin',
#  "8,2'-dimethoxyflavone",
#  'acetyltryptophan',
#  '7-methoxy-4H-chromen-4-one',
#  'bisindolylmaleimide IV',
#  'ketanserin',
#  'clomethiazole',
#  'E6 berbamine',
#  'epicatechin monogallate',
#  'tyramine',
#  'dorsomorphin',
#  'dosulepin',
#  'spiperone',
#  'CO 101244',
#  'hymecromone methyl ether',
#  'BU 226',
#  'SB-216763',
#  'chrysophanol',
#  'YC-1',
#  'alfaxalone',
#  'suloctidil',
#  'dexniguldipine',
#  'capsazepine',
#  'tetracaine',
#  'BP 554',
#  'tolazoline',
#  'valaciclovir',
#  'SCH-442,416',
#  'metyrapone',
#  'NBQX',
#  'piribedil',
#  'YM 298198, Desmethyl-',
#  "4',6-dimethoxyflavone",
#  'tyrphostin AG 18',
#  'Amino-1,8-naphthalimide [4-Amino-1,8-naphthalimide]',
#  'UCL 2077',
#  'Src kinase inhibitor I',
#  'metronidazole',
#  'apiin',
#  'CITCO',
#  '8-methoxymethyl-IBMX',
#  'remoxipride',
#  'MK2a inhibitor',
#  'R 59022',
#  'pefloxacin',
#  'WAY 629',
#  'RHC-80267',
#  'HBDDE',
#  'triprolidine',
#  'sulfaethidole',
#  'tripelannamine',
#  'crotamiton',
#  'indometacin',
#  'PRE-084',
#  'pentoxifylline',
#  'pentetrazol',
#  'tyrphostin AG 1295',
#  'esculetin',
#  'Ro 90-7501',
#  'emodin',
#  'propentofylline',
#  'ubenimex',
#  'ZM-306416',
#  'paracetamol',
#  '2-Phenylmelatonin',
#  'NO 711',
#  'flufenamic acid',
#  'capsazepine',
#  'Y-26763',
#  'valsartan',
#  'BP 554',
#  'RS 67333',
#  'o-3M3FBS',
#  'valaciclovir',
#  'pramocaine',
#  'acetylsalicylsalicylic acid',
#  'ketanserin',
#  '7-(chloroethyl)theophylline',
#  'R 59022',
#  '2-mercaptobenzothiazole',
#  'sulfadoxine',
#  'sulfaethidole',
#  'palmatine',
#  'calycanthine',
#  'SB-218795',
#  'sulfapyridine',
#  'coumafos',
#  'E 4031',
#  'NO 711',
#  'EO-1428',
#  'suloctidil',
#  'glimepiride',
#  "koparin 2'-methyl ether",
#  'byssochlamic acid',
#  'capsazepine',
#  'zolpidem',
#  'Y-26763',
#  'ZD 7114',
#  'diethylcarbamazine',
#  'diphenhydramine',
#  'dipyrocetyl',
#  'tyrphostin 51',
#  'prazosin',
#  'fenofibrate',
#  'estropipate',
#  'iodophenpropit',
#  'ICI 63197',
#  'apiin',
#  'SC-19220',
#  'acetohexamide',
#  'ozagrel',
#  'arctigenin',
#  'risperidone',
#  '8-methoxymethyl-IBMX',
#  'R 59022',
#  'CO 101244',
#  'SCH 28080',
#  'BMS 182874',
#  'pentetrazol',
#  'Ro 90-7501',
#  '5alpha-12-methoxy-4,4-bisnor-8,11,13-podocarpatrien-3-one',
#  'SB-216763',
#  'calycanthine',
#  'dephostatin',
#  'YC-1',
#  'azlocillin',
#  'GW-843682X',
#  'imatinib',
#  'MPEP',
#  'MNITMT',
#  'dihydrosamidin',
#  'kinetin',
#  'zoxazolamine',
#  'pifithrin-alpha',
#  'sodium phenylbutyrate',
#  'CI 966',
#  'palmidrol',
#  'CGS 20625',
#  'nifuroxazide',
#  'W-9',
#  'ML-9',
#  'todralazine',
#  'sulfadimethoxine',
#  'Cdk2/5 inhibitor',
#  'peucedanin',
#  'derrusnin',
#  'alizarin',
#  'phenylephrine',
#  'oxolinic acid',
#  '2-amino-4-methylpyridine',
#  'alpha-ergocryptine',
#  'brinzolamide',
#  'metaclopramide',
#  'isopilocarpine',
#  'fraxetin',
#  'nicergoline',
#  'benzanthrone',
#  'moxonidine',
#  'ACA',
#  'quipazine',
#  'GSK-3beta inhibitor VIII',
#  'fenobam',
#  'tyrphostin 63',
#  '4-IBP',
#  '6-benzylaminopurine',
#  'NSC 625987',
#  'JTE 907',
#  'methoxsalen',
#  'mycophenolic acid',
#  '3,4,5-trimethoxycinnamic acid',
#  'linoleamide',
#  'GP 1a',
#  'lawsone',
#  'ICI-162,846',
#  'W-9',
#  'flupentixol',
#  'quinidine gluconate',
#  'cefixime',
#  'BML-259',
#  'HA-100',
#  'isoginkgetin',
#  'bromopride',
#  'L-689,560',
#  'DCB',
#  'BW 373U86',
#  'procainamide',
#  'apomorphine hydrochloride',
#  'omacetaxine mepesuccinate',
#  'isotretinoin',
#  'alpha-yohimbine',
#  'lecanoric acid',
#  'quipazine',
#  'GSK-3 inhibitor II',
#  'genistin',
#  'piceid',
#  'DFB',
#  'VEGF receptor 2 kinase inhibitor IV',
#  'SR-2640',
#  'T-0156',
#  'etacrynic acid',
#  'arecaidine but-2-ynyl ester',
#  '7-desoxypurpurogallin-7-carboxylic acid, methyl ester, trimethyl ether',
#  'ZD 2079',
#  'monocrotaline',
#  'SIB 1893',
#  'naloxone',
#  'GR 46611',
#  'brimonidine',
#  'ponalrestat',
#  'aceclofenac',
#  'homopterocarpin',
#  'derrustone',
#  'quinapril',
#  'fenamisal',
#  'levobunolol',
#  'ARP 101',
#  '2-amino-4-methylpyridine',
#  'L-689,560',
#  'GS39783',
#  'hydroxytoluic acid',
#  'isopilocarpine',
#  'nimesulide',
#  'alpha-yohimbine',
#  'A 205804',
#  'talniflumate',
#  'MT-21',
#  'pyrazolanthrone',
#  'naringin',
#  '2-propyl-3-hydroxyethylenepyran-4-one',
#  'catechin pentabenzoate',
#  'oxybuprocaine',
#  'LE-135',
#  'AM-580',
#  'diclofenac',
#  'timolol',
#  'benzo(a)pyrene',
#  'deferoxamine',
#  'acetyltryptophanamide',
#  '5,7,8-trimethoxy-3-(4-methoxyphenyl)chromen-4-one',
#  'sulfasalazine',
#  'phenanthridone',
#  'BU 239',
#  'ER-27319',
#  'MEK1/2 inhibitor',
#  'nocodazole',
#  'sulfamonomethoxine',
#  '40 (DMCM)',
#  'minoxidil',
#  'GPR109b Agonist, IBC 293',
#  'R-96544',
#  'SEW2871',
#  'neocuproine',
#  'butein',
#  'kenpaullone',
#  'JNJ 10191584',
#  'DFB',
#  '3 (BCCE)',
#  '3-methoxycholanthrene',
#  '4-IBP',
#  'lidoflazine',
#  'farnesylthioacetic acid',
#  'fluorometholone',
#  'GP 1a',
#  'CCT018159',
#  'valerylsalicylic acid',
#  'zoxazolamine',
#  'flurofamide',
#  'almotriptan',
#  '2-(2-aminoethyl)benzenesulfonyl fluoride',
#  'palmidrol',
#  'ML-9',
#  'phorbol myristate acetate',
#  'todralazine',
#  '1-(2-methoxyphenyl)piperazine',
#  'trazodone',
#  '2-arachidonoylglycerol',
#  'Cdk2/5 inhibitor',
#  'HA-100',
#  'SSR 69071',
#  'cinchophen',
#  'triptophenolide',
#  'quinisocaine',
#  'phlorhizin',
#  'ZM336372',
#  'catechin tetramethylether',
#  'brinzolamide',
#  'AGGC',
#  'B-HT 920',
#  'fraxetin',
#  'SB-415286',
#  'nicergoline',
#  'metamizole sodium',
#  'hydroxyfasudil',
#  'mebendazole',
#  'BRD-K68617666',
#  'BRD-K76922696',
#  'BRD-K10540354',
#  'BRD-K77108448',
#  'BRD-K14732815',
#  'BRD-K58324650',
#  'BRD-K32577562',
#  'BRD-K09842906',
#  'BRD-K94876980',
#  'BRD-K98005735',
#  'BRD-K66032509',
#  'BRD-K91952416',
#  'BRD-K73775927',
#  'BRD-K71247208',
#  'BRD-K71243741',
#  'BRD-K18709210',
#  'BRD-K60578515',
#  'BRD-K16727544',
#  'BRD-K04757670',
#  'BRD-K78886448',
#  'BRD-K35826866',
#  'BRD-K29636267',
#  'BRD-K42605555',
#  'BRD-K18763924',
#  'BRD-K02946901',
#  'BRD-K70237115',
#  'BRD-K52115548',
#  'BRD-K28039328',
#  'BRD-K14863829',
#  'BRD-K56650430',
#  'BRD-K08558441',
#  'BRD-K87927290',
#  'BRD-K87191742',
#  'BRD-K13411423',
#  'BRD-K09250647',
#  'BRD-K37283718',
#  'BRD-K99387963',
#  'BRD-K13113551',
#  'BRD-K00717406',
#  'BRD-K24838542',
#  'BRD-K39668479',
#  'BRD-K91879432',
#  'BRD-K95574976',
#  'BRD-K02061146',
#  'BRD-K78639526',
#  'BRD-K54042694',
#  'BRD-K09842906',
#  'BRD-K42653521',
#  'BRD-K91085913',
#  'BRD-K42789863',
#  'BRD-K20331065',
#  'BRD-K86623758',
#  'BRD-K71563254',
#  'BRD-K53548223',
#  'BRD-K80723690',
#  'BRD-K94766933',
#  'BRD-K41009039',
#  'BRD-K34985075',
#  'BRD-K66941670',
#  'BRD-K33606137',
#  'BRD-K68512873',
#  'BRD-K05975035',
#  'BRD-K69536411',
#  'BRD-K71839680',
#  'BRD-K61087440',
#  'BRD-K21367867',
#  'BRD-K99377470',
#  'BRD-K50191826',
#  'BRD-K13113551',
#  'BRD-K30462643',
#  'BRD-K21215763',
#  'BRD-K51253991',
#  'BRD-K64992851',
#  'BRD-K43295075',
#  'BRD-K55053106',
#  'BRD-K72707702',
#  'BRD-K32577562',
#  'BRD-K54042694',
#  'BRD-K98271666',
#  'BRD-K48592348',
#  'BRD-K91866516',
#  'BRD-K44236678',
#  'BRD-K51411441',
#  'BRD-K29143088',
#  'BRD-K78015078',
#  'BRD-K29636267',
#  'BRD-K26631178',
#  'BRD-K67638302',
#  'BRD-K51757923',
#  'BRD-K90863245',
#  'BRD-K83013052',
#  'BRD-K80622681',
#  'BRD-K71839680',
#  'BRD-K19168437',
#  'BRD-K93819193',
#  'BRD-K44078665',
#  'BRD-K14907323',
#  'BRD-A30907050',
#  'BRD-K44812364',
#  'BRD-K98531780',
#  'BRD-A70929655',
#  'BRD-K64642958',
#  'BRD-K78971503',
#  'BRD-K62028970',
#  'BRD-K05016999',
#  'BRD-K38868564',
#  'BRD-A49904853',
#  'BRD-K20372010',
#  'BRD-K36707664',
#  'BRD-K78349294',
#  'BRD-K14254115',
#  'BRD-K30647015',
#  'BRD-K19635123',
#  'BRD-A93424839',
#  'BRD-K44620838',
#  'BRD-K06476085',
#  'BRD-K49039795',
#  'BRD-K14581814',
#  'BRD-K56060238',
#  'BRD-A32683230',
#  'BRD-K35074036',
#  'BRD-K57424282',
#  'BRD-K53002688',
#  'BRD-K45555856',
#  'BRD-A02763478',
#  'BRD-K07593260',
#  'BRD-A07531474',
#  'BRD-K92634926',
#  'BRD-K36132544',
#  'BRD-K71755682',
#  'BRD-K48987279',
#  'BRD-K82768815',
#  'BRD-K63779242',
#  'BRD-K75844451',
#  'BRD-K26231789',
#  'BRD-K43298189',
#  'BRD-K26184956',
#  'BRD-K80816131',
#  'BRD-K16190564',
#  'BRD-K59188100',
#  'BRD-K99800590',
#  'BRD-K08476323',
#  'BRD-K07300437',
#  'BRD-K84775364',
#  'BRD-K38282015',
#  'BRD-K74267000',
#  'BRD-K41875112',
#  'BRD-K38861721',
#  'BRD-K84118789',
#  'BRD-K78500251',
#  'BRD-K78789413',
#  'BRD-K66993610',
#  'BRD-K12384030',
#  'BRD-K11259871',
#  'BRD-K81568980',
#  'BRD-K67626198',
#  'BRD-K42126155',
#  'BRD-K08220319',
#  'BRD-K27352194',
#  'BRD-K81992781',
#  'BRD-K57497543',
#  'BRD-K12440228',
#  'BRD-K75206048',
#  'BRD-K64434200',
#  'BRD-K10048365',
#  'BRD-K36393312',
#  'BRD-K74537058',
#  'BRD-K01894374',
#  'BRD-K77892726',
#  'BRD-K07300437',
#  'BRD-K84761515',
#  'BRD-K77594363',
#  'BRD-K19474742',
#  'BRD-K27782186',
#  'BRD-K25600773',
#  'BRD-K28339544',
#  'BRD-K94616959',
#  'BRD-K59024795',
#  'BRD-K66735566',
#  'BRD-K88156935',
#  'BRD-K46149455',
#  'BRD-K11259871',
#  'BRD-K88590066',
#  'BRD-K19020285',
#  'BRD-K93830491',
#  'BRD-K36718828',
#  'BRD-K99702099',
#  'BRD-K31939603',
#  'BRD-K67626198',
#  'BRD-K18637162',
#  'BRD-K93335719',
#  'BRD-K37131263',
#  'BRD-K95114614',
#  'BRD-K66580188',
#  'BRD-K16966765',
#  'BRD-K82768815',
#  'BRD-K63779242',
#  'BRD-K99100679',
#  'BRD-K64434200',
#  'BRD-K28488100',
#  'BRD-K92398088',
#  'BRD-K11705648',
#  'BRD-K18984088',
#  'BRD-K33269038',
#  'BRD-K61168987',
#  'BRD-K52190624',
#  'BRD-K39099034',
#  'BRD-K07895476',
#  'BRD-K07300437',
#  'BRD-K60760423',
#  'BRD-K86288396',
#  'BRD-K66963756',
#  'BRD-K41875112',
#  'BRD-K14216332',
#  'BRD-K77541177',
#  'BRD-K53198140',
#  'BRD-K03191078',
#  'BRD-K41731186',
#  'BRD-K62202988',
#  'BRD-K88590066',
#  'BRD-K46082587',
#  ...]
# None

# %%
comp_list = pd.DataFrame()
for idx in hit_comp:
    value = x_val_meta.loc[idx, 'Metadata_broad_sample']
    name = chem_dat[chem_dat['BROAD_ID'] == value]

    comp_list = pd.concat([comp_list, name], ignore_index = True)



comp_list.to_excel('comp_list.xlsx')
